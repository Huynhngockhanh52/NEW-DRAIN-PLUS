# %%
import re
import sys
sys.path.append('../')
import os
import pandas as pd
from collections import Counter
import datetime

pd.set_option('display.max_rows', None)

SETTING_PARAMS = {
    'Apache': {
        'log_file': './logs/Apache/Apache_full.log',
        'log_template': './logs/Apache/Apache_full.log_templates.csv',
        'log_structure': './logs/Apache/Apache_full.log_structured.csv',
        'log_format': '\[<Time>\] \[<Level>\] <Content>',
        'filters': [],
        'regexs': [r'\/(?:\w+\/){2,}\w+\.\w+$'],    
    },
    'HealthApp':{
        'log_file': '../logs/HealthApp/HealthApp_full.log',
        'log_template': '../logs/HealthApp/HealthApp_full.log_templates.csv',
        'log_structure': '../logs/HealthApp/HealthApp_full.log_structured.csv',
        'log_format': '<Time>\|<Component>\|<Pid>\|<Content>',
        'filters': [],
        'regexs': [],  
    },
    'Mac': {
        'log_file': './logs/Mac/Mac_full.log',
        'log_template': './logs/Mac/Mac_full.log_templates.csv',
        'log_structure': './logs/Mac/Mac_full.log_structured.csv',
        'log_format': '<Month>  <Date> <Time> <User> <Component>\[<PID>\]( \(<Address>\))?: <Content>',
        'filters': [],
        'regexs': [r'([\w-]+\.){2,}[\w-]+'],  
    },
    'Linux': {
        'log_file': './logs/Linux/Linux_full.log',
        'log_template': './logs/Linux/Linux_full.log_templates.csv',
        'log_structure': './logs/Linux/Linux_full.log_structured.csv',
        'log_format': '<Month> <Date> <Time> <Level> <Component>(\[<PID>\])?: <Content>',
        'filters': [],
        'regexs': [r'(\d+\.){3}\d+', r'\d{2}:\d{2}:\d{2}'],  
    },
    'OpenSSH': {
        'log_file': './logs/OpenSSH/OpenSSH_full.log',
        'log_template': './logs/OpenSSH/OpenSSH_full.log_templates.csv',
        'log_structure': './logs/OpenSSH/OpenSSH_full.log_structured.csv',
        'log_format': '<Date> <Day> <Time> <Component> sshd\[<Pid>\]: <Content>',
        'filters': [],
        'regexs': [r"(\d+):"],    
    },
}

# %%
import ULP.ULP as ulp
import time
import importlib

import sys
sys.path.append('../../')

importlib.reload(ulp)
pd.set_option('display.max_colwidth', None) 

output_dir = '../res/ULP/'  
datasets = SETTING_PARAMS['HealthApp']
parser = ulp.LogParser(datasets['log_format'], indir="../logs/HealthApp/", outdir=output_dir, rex=datasets['regexs'])
parser.logname = 'HealthApp_full.log'

# start_timeBig = time.time()
# print("Parsing file: " + os.path.join(parser.path, datasets['log_file']))

# parser.load_data()
# print("SHAPE: ", parser.df_log.shape)
# parser.tokenize()

# parser.df_log["EventId"] = parser.df_log["event_label"].map(
#             lambda x: parser.remove_word_with_special(str(x))
#         )
# groups = parser.df_log.groupby("EventId")
# keys = groups.groups.keys()             # Lấy danh sách các EventId đã nhóm lại
# stock = pd.DataFrame()
# count = 0

# re_list2 = ["[ ]{1,}[-]*[0-9]+[ ]{1,}", ' "\d+" ']  # Các regex để tìm các từ biến động trong log
# generic_re = re.compile("|".join(re_list2))         # Biểu thức regex tổng hợp để tìm các từ biến động trong log

# for i in keys:
#     l = []
#     slc = groups.get_group(i)                       # Lấy nhóm log theo EventId

#     template = slc["event_label"][0:1].to_list()[0] # Lấy template đầu tiên trong nhóm
#     count += 1
#     if slc.size > 1:
#         l = parser.getDynamicVars2(slc.head(10))
#         pat = r"\b(?:{})\b".format("|".join(str(v) for v in l))
#         if len(l) > 0:
#             template = template.lower()
#             template = re.sub(pat, "<*>", template)

#     template = re.sub(generic_re, " <*> ", template)
#     slc["event_label"] = [template] * len(slc["event_label"].to_list())

#     stock = pd.concat([stock, slc])
#     stock = stock.sort_index()

# parser.df_log = stock

# parser.df_log["EventTemplate"] = parser.df_log["event_label"]
# if not os.path.exists(parser.savePath):
#     os.makedirs(parser.savePath)
# parser.df_log.to_csv(
#     os.path.join(parser.savePath, "ULP_structured.csv"), index=False
# )
# elapsed_timeBig = time.time() - start_timeBig
# print(f"Parsing done in {elapsed_timeBig} sec")
parser.parse(parser.logname)
# Out:
# Parsing file: ../logs/HealthApp/HealthApp_full.log
# Parsing done in 14.523539781570435 sec
# 0

# %%
from tqdm import tqdm

structured_df = pd.read_csv(datasets['log_structure']) 
unique_templates = structured_df['EventTemplate'].unique()
print(f"SHAPE: {structured_df.shape}")
print(f"SHAPE PARSER: {parser.df_log.shape}")

template_compare = {}
for template in tqdm(unique_templates, desc="Processing templates"):
    arr_index = structured_df[structured_df['EventTemplate'] == template].index.tolist()
    parse_template_series = parser.df_log.loc[arr_index, 'EventTemplate']
    parse_template_unique = parse_template_series.unique().tolist()

    hash_key = hash(template)
    template_compare[hash_key] = {
        'ground_truth': template,
        'parse': parse_template_unique,
        'index': arr_index,
        'length': len(template.strip().split()),
        'nums': len(arr_index)
    }
    
sorted_items = sorted(
        template_compare.items(),
        key=lambda item: (item[1]['length'], item[1]['ground_truth'])
    )

num_dif = 0
for idx, (key, value) in enumerate(sorted_items, 1):
    if len(value['parse']) != 1 or value['parse'][0] != value['ground_truth']:
        num_dif += 1
        print(f"No. {idx}")
        print(f"Length: {value['length']}, Nums: {value['nums']}")
        print(f"Ground truth  : {value['ground_truth']}")
        print(f"Parse templs  : {value['parse']}")
        print(f"Length parse: {len(value['parse'])}")
        print("-" * 40)
print(f"Total differences found: {num_dif}")
# Out:
# SHAPE: (212394, 4)
# SHAPE PARSER: (212394, 8)
# Processing templates: 100%|██████████| 156/156 [00:01<00:00, 105.78it/s]
# No. 1
# Length: 1, Nums: 10
# Ground truth  : FAILED_ERROR_DATA
# Parse templs  : ['[ closenotification... ] ']
# Length parse: 1
# ----------------------------------------
# No. 2
# Length: 1, Nums: 11
# Ground truth  : clear()
# Parse templs  : ['[ clear (  )  ] ']
# Length parse: 1
# ----------------------------------------
# No. 3
# Length: 1, Nums: 15
# Ground truth  : closeNotification...
# Parse templs  : ['[ closenotification... ] ']
# Length parse: 1
# ----------------------------------------
# No. 4
# Length: 1, Nums: 5
# Ground truth  : context=<*>
# Parse templs  : ['[ context = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 5
# Length: 1, Nums: 4
# Ground truth  : createHealthNotification()
# Parse templs  : ['[ createHealthNotification (  )  ] ']
# Length parse: 1
# ----------------------------------------
# No. 6
# Length: 1, Nums: 15
# Ground truth  : deleteHealthNotification()
# Parse templs  : ['[ deleteHealthNotification (  )  ] ']
# Length parse: 1
# ----------------------------------------
# No. 7
# Length: 1, Nums: 1
# Ground truth  : fetchPhoneDataClient
# Parse templs  : ['[ fetchPhoneDataClient ] ']
# Length parse: 1
# ----------------------------------------
# No. 8
# Length: 1, Nums: 5
# Ground truth  : getARDebugConfig
# Parse templs  : ['[ getARDebugConfig ] ']
# Length parse: 1
# ----------------------------------------
# No. 9
# Length: 1, Nums: 5
# Ground truth  : getDiffTotalCalories
# Parse templs  : ['[ getDiffTotalCalories ] ']
# Length parse: 1
# ----------------------------------------
# No. 10
# Length: 1, Nums: 5
# Ground truth  : getGoalNotificationShowStatus
# Parse templs  : ['[ getGoalNotificationShowStatus ] ']
# Length parse: 1
# ----------------------------------------
# No. 11
# Length: 1, Nums: 16
# Ground truth  : getStepCounterStatus
# Parse templs  : ['[ getStepCounterStatus ] ']
# Length parse: 1
# ----------------------------------------
# No. 12
# Length: 1, Nums: 5
# Ground truth  : getStepsNotificationShowStatus
# Parse templs  : ['[ getStepsNotificationShowStatus ] ']
# Length parse: 1
# ----------------------------------------
# No. 13
# Length: 1, Nums: 5
# Ground truth  : getStepsTarget
# Parse templs  : ['[ getStepsTarget ] ']
# Length parse: 1
# ----------------------------------------
# No. 14
# Length: 1, Nums: 5
# Ground truth  : getVersion
# Parse templs  : ['[ getVersion ] ']
# Length parse: 1
# ----------------------------------------
# No. 15
# Length: 1, Nums: 5
# Ground truth  : getWriteDBLastDataMinute
# Parse templs  : ['[ getWriteDBLastDataMinute ] ']
# Length parse: 1
# ----------------------------------------
# No. 16
# Length: 1, Nums: 11
# Ground truth  : initEnviroument
# Parse templs  : ['[ initEnviroument ] ']
# Length parse: 1
# ----------------------------------------
# No. 17
# Length: 1, Nums: 5
# Ground truth  : moveOldData()
# Parse templs  : ['[ moveOldData (  )  ] ']
# Length parse: 1
# ----------------------------------------
# No. 18
# Length: 1, Nums: 5
# Ground truth  : onCreate()
# Parse templs  : ['[ onCreate (  )  ] ']
# Length parse: 1
# ----------------------------------------
# No. 19
# Length: 1, Nums: 5
# Ground truth  : policy=<*>
# Parse templs  : ['[ policy = /system/emui/base:/system/emui/china:/vendor/etc:/odm/etc:/product/etc:/hw_odm:/hw_oem:/data/cust:/version/region_comm/china:/cust_spec ] ']
# Length parse: 1
# ----------------------------------------
# No. 20
# Length: 1, Nums: 11
# Ground truth  : reStartStepCounter
# Parse templs  : ['[ reStartStepCounter ] ']
# Length parse: 1
# ----------------------------------------
# No. 21
# Length: 1, Nums: 9
# Ground truth  : readXmlIfSupportEX
# Parse templs  : ['[ readXmlIfSupportEX ] ']
# Length parse: 1
# ----------------------------------------
# No. 22
# Length: 1, Nums: 20
# Ground truth  : registerDynamicBroadcastReceiver
# Parse templs  : ['[ registerDynamicBroadcastReceiver ] ']
# Length parse: 1
# ----------------------------------------
# No. 23
# Length: 1, Nums: 792
# Ground truth  : sendSyncFailedBroadcast
# Parse templs  : ['[ sendSyncFailedBroadcast ] ']
# Length parse: 1
# ----------------------------------------
# No. 24
# Length: 1, Nums: 5
# Ground truth  : setActionRestartSensorAlarm=<*>
# Parse templs  : ['[ setactionrestartsensoralarm = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 25
# Length: 1, Nums: 9
# Ground truth  : setDeviceClassType=<*>
# Parse templs  : ['[ setDeviceClassType = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 26
# Length: 1, Nums: 11
# Ground truth  : setDiffTotalSteps=<*>
# Parse templs  : ['[ setDiffTotalSteps = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 27
# Length: 1, Nums: 5
# Ground truth  : setGoalNotificationShowStatus=<*>
# Parse templs  : ['[ setGoalNotificationShowStatus = true ] ']
# Length parse: 1
# ----------------------------------------
# No. 28
# Length: 1, Nums: 5
# Ground truth  : setServiceRestartRecord=<*>
# Parse templs  : ['[ setservicerestartrecord = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 29
# Length: 1, Nums: 5
# Ground truth  : setStepCounterStatus=<*>
# Parse templs  : ['[ setStepCounterStatus = true ] ']
# Length parse: 1
# ----------------------------------------
# No. 30
# Length: 1, Nums: 27431
# Ground truth  : setTodayTotalDetailSteps=<*>
# Parse templs  : ['[ settodaytotaldetailsteps = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 31
# Length: 1, Nums: 436
# Ground truth  : setWriteDBLastDataMinute=<*>
# Parse templs  : ['[ setwritedblastdataminute = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 32
# Length: 1, Nums: 4
# Ground truth  : startNotification...
# Parse templs  : ['[ closenotification... ] ']
# Length parse: 1
# ----------------------------------------
# No. 33
# Length: 1, Nums: 9
# Ground truth  : supportPrivateStandStepcounter=<*>,supportStandStepCounter=<*>
# Parse templs  : ['[ supportPrivateStandStepcounter = true supportStandStepCounter = true ] ']
# Length parse: 1
# ----------------------------------------
# No. 34
# Length: 1, Nums: 4
# Ground truth  : upDateHealthNotification()|<*>|<*>|<*>
# Parse templs  : ['[ updatehealthnotification (  ) <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 35
# Length: 2, Nums: 5
# Ground truth  : SystemClock.elapsedRealtime(): <*>
# Parse templs  : ['[ systemclock.elapsedrealtime (  ) :  <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 36
# Length: 2, Nums: 27426
# Ground truth  : calculateAltitudeWithCache totalAltitude=<*>
# Parse templs  : ['[ calculateAltitudeWithCache  totalAltitude = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 37
# Length: 2, Nums: 27426
# Ground truth  : calculateCaloriesWithCache totalCalories=<*>
# Parse templs  : ['[ calculatecalorieswithcache  totalcalories = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 38
# Length: 2, Nums: 18
# Ground truth  : checkLocalDataValue <*>
# Parse templs  : ['[ checkLocalDataValue  false ] ']
# Length parse: 1
# ----------------------------------------
# No. 39
# Length: 2, Nums: 5
# Ground truth  : compareMidWareCacheAndLocalCache enter...
# Parse templs  : ['[ compareMidWareCacheAndLocalCache  enter... ] ']
# Length parse: 1
# ----------------------------------------
# No. 40
# Length: 2, Nums: 9
# Ground truth  : getCfgFile enter...
# Parse templs  : ['[ getCfgFile  enter... ] ']
# Length parse: 1
# ----------------------------------------
# No. 41
# Length: 2, Nums: 5
# Ground truth  : getDeviceShutDownBoolean shutDown=<*>
# Parse templs  : ['[ getDeviceShutDownBoolean  shutDown = false ] ']
# Length parse: 1
# ----------------------------------------
# No. 42
# Length: 2, Nums: 5
# Ground truth  : getDeviceShutDownTime shutDownTime=<*>
# Parse templs  : ['[ getDeviceShutDownTime  shutDownTime = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 43
# Length: 2, Nums: 5
# Ground truth  : getDiffTotalAltitude= <*>##<*>
# Parse templs  : ['[ getDiffTotalAltitude =   15139415093630.0 ] ']
# Length parse: 1
# ----------------------------------------
# No. 44
# Length: 2, Nums: 5
# Ground truth  : getDiffTotalCalories= <*>
# Parse templs  : ['[ getDiffTotalCalories =   151394150936038.0 ] ']
# Length parse: 1
# ----------------------------------------
# No. 45
# Length: 2, Nums: 32
# Ground truth  : getDiffTotalSteps= <*>
# Parse templs  : ['[ getdifftotalsteps =   <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 46
# Length: 2, Nums: 5
# Ground truth  : getFirstStartDaemonFromUI: <*>
# Parse templs  : ['[ getFirstStartDaemonFromUI:  true ] ']
# Length parse: 1
# ----------------------------------------
# No. 47
# Length: 2, Nums: 5
# Ground truth  : getGoalNotificationShowStatus= <*>
# Parse templs  : ['[ getGoalNotificationShowStatus =   true ] ']
# Length parse: 1
# ----------------------------------------
# No. 48
# Length: 2, Nums: 5
# Ground truth  : getLastSyncDBTime= <*>
# Parse templs  : ['[ getLastSyncDBTime = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 49
# Length: 2, Nums: 5
# Ground truth  : getMidWareCache mRemote=<*>
# Parse templs  : ['[ getMidWareCache  mRemote = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 50
# Length: 2, Nums: 5
# Ground truth  : getMidWareCache result=<*>
# Parse templs  : ['[ getMidWareCache  result = true ] ']
# Length parse: 1
# ----------------------------------------
# No. 51
# Length: 2, Nums: 5
# Ground truth  : getServiceRestartRecord= <*>
# Parse templs  : ['[ getservicerestartrecord =   <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 52
# Length: 2, Nums: 16
# Ground truth  : getStepCounterStatus= <*>
# Parse templs  : ['[ getStepCounterStatus =   true ] ']
# Length parse: 1
# ----------------------------------------
# No. 53
# Length: 2, Nums: 5
# Ground truth  : getStepsNotificationShowStatus= <*>
# Parse templs  : ['[ getStepsNotificationShowStatus =   false ] ']
# Length parse: 1
# ----------------------------------------
# No. 54
# Length: 2, Nums: 5
# Ground truth  : getStepsTarget= <*>
# Parse templs  : ['[ getStepsTarget = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 55
# Length: 2, Nums: 32
# Ground truth  : getTodayBasicStandardSteps= <*>
# Parse templs  : ['[ gettodaybasicstandardsteps =   <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 56
# Length: 2, Nums: 206
# Ground truth  : getTodaySportData mStepsRecordManager=<*>
# Parse templs  : ['[ getTodaySportData  mStepsRecordManager = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 57
# Length: 2, Nums: 5
# Ground truth  : getVersion= <*>
# Parse templs  : ['[ getVersion =   Athene3 ] ']
# Length parse: 1
# ----------------------------------------
# No. 58
# Length: 2, Nums: 5
# Ground truth  : getWriteDBLastDataMinute= <*>
# Parse templs  : ['[ getwritedblastdataminute =   <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 59
# Length: 2, Nums: 5
# Ground truth  : initCacheFromFile enter...
# Parse templs  : ['[ initCacheFromFile  enter... ] ']
# Length parse: 1
# ----------------------------------------
# No. 60
# Length: 2, Nums: 5
# Ground truth  : initDataManager enter...
# Parse templs  : ['[ initDataManager  enter... ] ']
# Length parse: 1
# ----------------------------------------
# No. 61
# Length: 2, Nums: 1
# Ground truth  : initDiffCaloriesfromFile mCaloriesDiff=<*>
# Parse templs  : ['[ initDiffCaloriesfromFile  mCaloriesDiff = 38.0 ] ']
# Length parse: 1
# ----------------------------------------
# No. 62
# Length: 2, Nums: 5
# Ground truth  : initExtendStepCounter <*>
# Parse templs  : ['[ initExtendStepCounter <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 63
# Length: 2, Nums: 227
# Ground truth  : isScreenOn <*>
# Parse templs  : ['[ isScreenOn  true ] ', '[ isScreenOn  false ] ']
# Length parse: 2
# ----------------------------------------
# No. 64
# Length: 2, Nums: 11
# Ground truth  : next day:<*>
# Parse templs  : ['[ next  day:steps0mlastreport7214 ] ']
# Length parse: 1
# ----------------------------------------
# No. 65
# Length: 2, Nums: 30161
# Ground truth  : onStandStepChanged <*>
# Parse templs  : ['[ onstandstepchanged  <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 66
# Length: 2, Nums: 8602
# Ground truth  : processHandleBroadcastAction action:<*>
# Parse templs  : ['[ processhandlebroadcastaction  action:<*>screen_on ] ']
# Length parse: 1
# ----------------------------------------
# No. 67
# Length: 2, Nums: 9
# Ground truth  : readXmlIfSupportEX result=<*>
# Parse templs  : ['[ readXmlIfSupportEX  result = true ] ']
# Length parse: 1
# ----------------------------------------
# No. 68
# Length: 2, Nums: 4
# Ground truth  : rebuild notification
# Parse templs  : ['[ rebuild  notification ] ']
# Length parse: 1
# ----------------------------------------
# No. 69
# Length: 2, Nums: 10
# Ground truth  : registerLogCallback <*>
# Parse templs  : ['[ registerLogCallback  <*> ] ', '[ registerLogCallback  <*>  cb:<*> ] ']
# Length parse: 2
# ----------------------------------------
# No. 70
# Length: 2, Nums: 16
# Ground truth  : registersensorsuccess: <*>
# Parse templs  : ['[ registersensorsuccess:  true ] ']
# Length parse: 1
# ----------------------------------------
# No. 71
# Length: 2, Nums: 10
# Ground truth  : setDeviceShutDownValue shutDownTime=<*>,isShutDown=<*>
# Parse templs  : ['[ setDeviceShutDownValue  shutDownTime = <*> isShutDown = false ] ']
# Length parse: 1
# ----------------------------------------
# No. 72
# Length: 2, Nums: 15
# Ground truth  : setGoalNotifiShownRecord <*>
# Parse templs  : ['[ setgoalnotifishownrecord  <*>  false ] ', '[ setgoalnotifishownrecord  <*>  true ] ']
# Length parse: 2
# ----------------------------------------
# No. 73
# Length: 2, Nums: 5
# Ground truth  : startStepCounter enter...
# Parse templs  : ['[ startStepCounter  enter... ] ']
# Length parse: 1
# ----------------------------------------
# No. 74
# Length: 2, Nums: 5
# Ground truth  : startStepCounterInter stand
# Parse templs  : ['[ startStepCounterInter  stand ] ']
# Length parse: 1
# ----------------------------------------
# No. 75
# Length: 2, Nums: 9
# Ground truth  : supportStandStepCounter <*>
# Parse templs  : ['[ supportStandStepCounter  true ] ']
# Length parse: 1
# ----------------------------------------
# No. 76
# Length: 2, Nums: 1
# Ground truth  : switchTrackMonitor <*>
# Parse templs  : ['[ switchTrackMonitor  false ] ']
# Length parse: 1
# ----------------------------------------
# No. 77
# Length: 2, Nums: 11
# Ground truth  : theDayChanged <*>
# Parse templs  : ['[ thedaychanged  <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 78
# Length: 2, Nums: 651
# Ground truth  : timeStamp back,extendReportTimeStamp=<*>
# Parse templs  : ['[ timestamp  back extendreporttimestamp = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 79
# Length: 2, Nums: 1920
# Ground truth  : upLoadOneMinuteDataToEngine time=<*>
# Parse templs  : ['[ uploadoneminutedatatoengine  time = <*> <*> <*> <*> 20002 ] ']
# Length parse: 1
# ----------------------------------------
# No. 80
# Length: 3, Nums: 185
# Ground truth  : <*> block report
# Parse templs  : ['[ FAILED_SCREEN_OFF  block  report ] ']
# Length parse: 1
# ----------------------------------------
# No. 81
# Length: 3, Nums: 307
# Ground truth  : Alarm uploadStaticsToDB totalSteps=<*>
# Parse templs  : ['[ alarm  uploadstaticstodb  totalsteps = 7163calories:153367floor:240distance:5112 ] ']
# Length parse: 1
# ----------------------------------------
# No. 82
# Length: 3, Nums: 5
# Ground truth  : MyServiceConn connect <*>
# Parse templs  : ['[ MyServiceConn  connect  <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 83
# Length: 3, Nums: 23539
# Ground truth  : REPORT : <*>
# Parse templs  : ['[ report  :  <*>  <*>  <*> <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 84
# Length: 3, Nums: 1617
# Ground truth  : flush sensor data
# Parse templs  : ['[ flush  sensor  data ] ']
# Length parse: 1
# ----------------------------------------
# No. 85
# Length: 3, Nums: 437
# Ground truth  : flushTempCacheToDB by <*>
# Parse templs  : ['[ flushTempCacheToDB  by  stand ] ', '[ flushTempCacheToDB  by  ext ] ']
# Length parse: 2
# ----------------------------------------
# No. 86
# Length: 3, Nums: 27447
# Ground truth  : getTodayTotalDetailSteps = <*>
# Parse templs  : ['[ gettodaytotaldetailsteps   =   <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 87
# Length: 3, Nums: 3239
# Ground truth  : onReceive action: <*>
# Parse templs  : ['[ onreceive  action:  <*>screen_on ] ']
# Length parse: 1
# ----------------------------------------
# No. 88
# Length: 3, Nums: 16
# Ground truth  : setBasicStandardSteps basicStandardStep=<*> restartSteps=<*>
# Parse templs  : ['[ setbasicstandardsteps  basicstandardstep = <*>  restartsteps = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 89
# Length: 3, Nums: 1
# Ground truth  : setFirstStartDaemonFromUI success: <*>
# Parse templs  : ['[ setFirstStartDaemonFromUI  success:  true ] ']
# Length parse: 1
# ----------------------------------------
# No. 90
# Length: 3, Nums: 5
# Ground truth  : target init: <*>
# Parse templs  : ['[ target  init:  target10000 ] ']
# Length parse: 1
# ----------------------------------------
# No. 91
# Length: 3, Nums: 212
# Ground truth  : uploadStaticsToDB failed message=<*>
# Parse templs  : ['[ uploadStaticsToDB  failed  message = true ] ']
# Length parse: 1
# ----------------------------------------
# No. 92
# Length: 3, Nums: 5
# Ground truth  : userInfo changed detail
# Parse templs  : ['[ userInfo  changed  detail ] ']
# Length parse: 1
# ----------------------------------------
# No. 93
# Length: 3, Nums: 437
# Ground truth  : writeDataToDB size <*>
# Parse templs  : ['[ writedatatodb  size  <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 94
# Length: 4, Nums: 436
# Ground truth  : InsertEvent success begin:<*> end:<*>
# Parse templs  : ['[ insertevent  success  <*>  <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 95
# Length: 4, Nums: 3156
# Ground truth  : getBinderPackageName packageName = <*>
# Parse templs  : ['[ getBinderPackageName  packageName   =   <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 96
# Length: 4, Nums: 15
# Ground truth  : getMidWareStepCountService: isSystemApp = <*>
# Parse templs  : ['[ getMidWareStepCountService:  isSystemApp   =   true ] ']
# Length parse: 1
# ----------------------------------------
# No. 97
# Length: 4, Nums: 68
# Ground truth  : getStringHuid() who is <*>
# Parse templs  : ['[ getStringHuid (  )   who  is  <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 98
# Length: 4, Nums: 9
# Ground truth  : getUserPreference key = <*>
# Parse templs  : ['[ getuserpreference  key   =   custom.userpreference_heartzone_config ] ']
# Length parse: 1
# ----------------------------------------
# No. 99
# Length: 4, Nums: 1
# Ground truth  : initDiffAltitude from File mAltitudeDiff=<*>
# Parse templs  : ['[ initDiffAltitude  from  File  mAltitudeDiff = 0.0 ] ']
# Length parse: 1
# ----------------------------------------
# No. 100
# Length: 4, Nums: 5
# Ground truth  : initStepCounter : deviceType <*>
# Parse templs  : ['[ initStepCounter  :  deviceType <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 101
# Length: 4, Nums: 1
# Ground truth  : initTrackDistancefromFile from File mTrackDistance=<*>
# Parse templs  : ['[ initTrackDistancefromFile  from  File  mTrackDistance = 0.0 ] ']
# Length parse: 1
# ----------------------------------------
# No. 102
# Length: 4, Nums: 792
# Ground truth  : needAutoSync autoSyncSwitch is <*>
# Parse templs  : ['[ needAutoSync  autoSyncSwitch  is  open ] ']
# Length parse: 1
# ----------------------------------------
# No. 103
# Length: 4, Nums: 7237
# Ground truth  : new date =<*>, type=<*>,old=<*>
# Parse templs  : ['[ new  date   = <*> type = <*> <*> old = <*> ] ', '[ new  date   = <*> type = <*> <*> old = null ] ']
# Length parse: 2
# ----------------------------------------
# No. 104
# Length: 4, Nums: 744
# Ground truth  : saveHealthDetailData() deviceID = <*>,clientID=<*>,id=<*>
# Parse templs  : ['[ saveHealthDetailData (  )   deviceID   = <*> clientID = <*> id = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 105
# Length: 4, Nums: 744
# Ground truth  : startListenerChange subscribeList = [<*>]
# Parse templs  : ['[ startListenerChange  subscribeList   =    [ <*> ]  ] ']
# Length parse: 1
# ----------------------------------------
# No. 106
# Length: 4, Nums: 5
# Ground truth  : startStepCounterInter mStandStepCounter = <*>
# Parse templs  : ['[ startStepCounterInter  mStandStepCounter   =   <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 107
# Length: 4, Nums: 5
# Ground truth  : the first init <*>
# Parse templs  : ['[ the  first  init  mlastreporttimestamp1514100674406 ] ']
# Length parse: 1
# ----------------------------------------
# No. 108
# Length: 5, Nums: 5
# Ground truth  : MyGetDetailDataCallback onResult bundle == <*>
# Parse templs  : ['[ MyGetDetailDataCallback  onResult  bundle   =  =   null ] ']
# Length parse: 1
# ----------------------------------------
# No. 109
# Length: 5, Nums: 792
# Ground truth  : ifCanSync not! no cloud version
# Parse templs  : ['[ ifCanSync  not  no  cloud  version ] ']
# Length parse: 1
# ----------------------------------------
# No. 110
# Length: 5, Nums: 792
# Ground truth  : initDataPrivacy the dataPrivacy is <*>
# Parse templs  : ['[ initDataPrivacy  the  dataPrivacy  is  true ] ']
# Length parse: 1
# ----------------------------------------
# No. 111
# Length: 5, Nums: 5
# Ground truth  : initSyncModel current SyncModel is <*>
# Parse templs  : ['[ initSyncModel  current  SyncModel  is <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 112
# Length: 5, Nums: 792
# Ground truth  : initUserPrivacy the userPrivacy is <*>
# Parse templs  : ['[ initUserPrivacy  the  userPrivacy  is  true ] ']
# Length parse: 1
# ----------------------------------------
# No. 113
# Length: 5, Nums: 744
# Ground truth  : insertHiHealthData() end totalTime = <*>
# Parse templs  : ['[ inserthihealthdata (  )   end  totaltime   =   <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 114
# Length: 5, Nums: 5
# Ground truth  : onStartCommand Intent { cmp=<*> }
# Parse templs  : ['[ onStartCommand  Intent    cmp = <*>/.manager.DaemonService   ] ']
# Length parse: 1
# ----------------------------------------
# No. 115
# Length: 5, Nums: 16
# Ground truth  : reload : <*> restar <*>
# Parse templs  : ['[ reload  :  <*>  restar <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 116
# Length: 5, Nums: 42
# Ground truth  : screen status unknown,think screen <*>
# Parse templs  : ['[ screen  status  unknown think  screen  on ] ']
# Length parse: 1
# ----------------------------------------
# No. 117
# Length: 5, Nums: 5
# Ground truth  : start compare with midware counter
# Parse templs  : ['[ start  compare  with  midware  counter ] ']
# Length parse: 1
# ----------------------------------------
# No. 118
# Length: 5, Nums: 9
# Ground truth  : support extand step counter!,return <*>
# Parse templs  : ['[ support  extand  step  counter return  true ] ']
# Length parse: 1
# ----------------------------------------
# No. 119
# Length: 6, Nums: 11
# Ground truth  : <*> datas is null or empty
# Parse templs  : ['[ getTodayNoSyncTotalValue  datas  is  null  or  empty ] ']
# Length parse: 1
# ----------------------------------------
# No. 120
# Length: 6, Nums: 437
# Ground truth  : InsertCallBack() onSuccess type = <*> data=<*>
# Parse templs  : ['[ InsertCallBack (  )   onSuccess  type   = <*> data = true ] ']
# Length parse: 1
# ----------------------------------------
# No. 121
# Length: 6, Nums: 21
# Ground truth  : aggregateHiHealthDataEx() checkAppType <*> appID = <*>
# Parse templs  : ['[ aggregateHiHealthDataEx (  )   checkAppType <*> appID   = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 122
# Length: 6, Nums: 744
# Ground truth  : bulkSaveDetailHiHealthData() size = <*>,totalTime = <*>
# Parse templs  : ['[ bulksavedetailhihealthdata (  )   size   =   <*> totaltime   =   <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 123
# Length: 6, Nums: 705
# Ground truth  : checkInsertStatus stepStatSum or calorieStatSum is enough
# Parse templs  : ['[ checkInsertStatus  stepStatSum  or  calorieStatSum  is  enough ] ']
# Length parse: 1
# ----------------------------------------
# No. 124
# Length: 6, Nums: 685
# Ground truth  : checkInsertStatus stepSum or calorieSum is enough
# Parse templs  : ['[ checkInsertStatus  stepSum  or  calorieSum  is  enough ] ']
# Length parse: 1
# ----------------------------------------
# No. 125
# Length: 6, Nums: 744
# Ground truth  : insertHiHealthData() checkAppType <*> appID = <*>
# Parse templs  : ['[ insertHiHealthData (  )   checkAppType <*> appID   = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 126
# Length: 6, Nums: 437
# Ground truth  : saveRealTimeHealthDatasStat() size = <*>,totalTime = <*>
# Parse templs  : ['[ saverealtimehealthdatasstat (  )   size   = <*> totaltime   =   <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 127
# Length: 6, Nums: 705
# Ground truth  : startInsertSportSync start auto sync,app is <*>
# Parse templs  : ['[ startInsertSportSync  start  auto  sync app  is <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 128
# Length: 6, Nums: 3
# Ground truth  : subscribeHiHealthData() checkAppType <*> appID = <*>
# Parse templs  : ['[ subscribeHiHealthData (  )   checkAppType <*> appID   = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 129
# Length: 6, Nums: 307
# Ground truth  : uploadStaticsToDB() onResult type = <*> obj=<*>
# Parse templs  : ['[ uploadstaticstodb (  )   onresult  type   =   <*>  obj = true ] ']
# Length parse: 1
# ----------------------------------------
# No. 130
# Length: 7, Nums: 21
# Ground truth  : aggregateHiHealthData() time = <*> totalTime = <*>
# Parse templs  : ['[ aggregatehihealthdata (  )   time   =   <*>   totaltime   =   <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 131
# Length: 7, Nums: 39
# Ground truth  : checkSportDataNum setp and calories is too less
# Parse templs  : ['[ checkSportDataNum  setp  and  calories  is  too  less ] ']
# Length parse: 1
# ----------------------------------------
# No. 132
# Length: 7, Nums: 5
# Ground truth  : getIntercepterDistance from Prefence success and intercepterDistanceStr= <*>
# Parse templs  : ['[ getIntercepterDistance  from  Prefence  success  and  intercepterDistanceStr =   15139415093640.0 ] ']
# Length parse: 1
# ----------------------------------------
# No. 133
# Length: 7, Nums: 15
# Ground truth  : getMidWareStepCountService: pkgName = <*>, service = <*>
# Parse templs  : ['[ getMidWareStepCountService:  pkgName   =   <*>   service   =   <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 134
# Length: 7, Nums: 10
# Ground truth  : initBinder() app = <*>, packageName = <*>
# Parse templs  : ['[ initBinder (  )   app   = <*> packageName   =   <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 135
# Length: 7, Nums: 1
# Ground truth  : insert conflict event timeBegin <*> timeEnd <*>
# Parse templs  : ['[ insert  conflict  event  timeBegin <*> timeEnd <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 136
# Length: 7, Nums: 705
# Ground truth  : startInsertSportSync first <*> steps sync,do all sync
# Parse templs  : ['[ startInsertSportSync  first <*> steps  sync do  all  sync ] ']
# Length parse: 1
# ----------------------------------------
# No. 137
# Length: 7, Nums: 705
# Ground truth  : stepSyncOrNot appSynTimes is <*>, statsyncTimes is <*>
# Parse templs  : ['[ stepSyncOrNot  appSynTimes  is <*> statsyncTimes  is <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 138
# Length: 8, Nums: 7
# Ground truth  : fetchDataSourceByType type = <*>,timeInterval = HiTimeInterval{startTime=<*>, endTime=<*>, timeZone=<*>}
# Parse templs  : ['[ fetchDataSourceByType  type   = <*> timeInterval   =   HiTimeIntervalstartTime = <*>  <*>   endTime = <*>  <*>   timeZone = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 139
# Length: 8, Nums: 744
# Ground truth  : getAppContext() isAppValid health or wear, packageName = <*>
# Parse templs  : ['[ getAppContext (  )   isAppValid  health  or  wear   packageName   =   <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 140
# Length: 8, Nums: 212
# Ground truth  : insertHiHealthData() bulkSaveDetailHiHealthData fail errorCode = <*>,errorMessage = <*>
# Parse templs  : ['[ insertHiHealthData (  )   bulkSaveDetailHiHealthData  fail  errorCode   = <*> errorMessage   =   ERR_DATA_INSERT ] ']
# Length parse: 1
# ----------------------------------------
# No. 141
# Length: 8, Nums: 5
# Ground truth  : onBind intent = Intent { act=<*> pkg=<*> }
# Parse templs  : ['[ onBind  intent   =   Intent    act = <*>  pkg = <*>   ] ']
# Length parse: 1
# ----------------------------------------
# No. 142
# Length: 8, Nums: 1
# Ground truth  : onStartCommand Intent { pkg=<*> cmp=<*> (has extras) }
# Parse templs  : ['[ onStartCommand  Intent    pkg = <*>  cmp = <*>/.manager.DaemonService   ( has  extras )    ] ']
# Length parse: 1
# ----------------------------------------
# No. 143
# Length: 8, Nums: 27
# Ground truth  : readHiHealthData() end time = <*> totalTime = <*>
# Parse templs  : ['[ readhihealthdata (  )   end  time   =   <*>   totaltime   =   <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 144
# Length: 8, Nums: 288
# Ground truth  : saveHealthDetailData() saveOneDetailData fail hiHealthData = <*>,type = <*>
# Parse templs  : ['[ savehealthdetaildata (  )   saveonedetaildata  fail  hihealthdata   =   <*> type   =   <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 145
# Length: 9, Nums: 21
# Ground truth  : aggregateHiHealthData aggregateOption is HiAggregateOption{startTime=<*>, endTime=<*>, type=<*>, alignType=<*>, aggregateType=<*>, groupUnitType=<*>}
# Parse templs  : ['[ aggregatehihealthdata  aggregateoption  is  hiaggregateoptionstarttime = <*>   endtime = <*>   type =  [ <*>   <*> ]    aligntype = <*> aggregatetype = <*>   groupunittype = <*> ] ', '[ aggregateHiHealthData  aggregateOption  is  HiAggregateOptionstartTime = <*> endTime = <*> type =  [ <*> 2009 <*> 2011 <*> 2013 <*> 2015 ]    alignType = <*> aggregateType = <*> groupUnitType = <*> ] ', '[ aggregatehihealthdata  aggregateoption  is  hiaggregateoptionstarttime = <*> endtime = <*>   type =  [ <*> 42005 <*> ]    aligntype = <*> aggregatetype = <*> groupunittype = <*> ] ', '[ aggregateHiHealthData  aggregateOption  is  HiAggregateOptionstartTime = <*> endTime = <*> type =  [ <*> 44103 <*> 44104 <*> 44203 <*> 44106 <*> 44001 <*> 44003 <*> ]    alignType = <*> aggregateType = <*> groupUnitType = <*> ] ']
# Length parse: 4
# ----------------------------------------
# No. 146
# Length: 9, Nums: 7
# Ground truth  : getHealthClientListByTime() dataClientIDs is null timeInterval = HiTimeInterval{startTime=<*>, endTime=<*>, timeZone=<*>}
# Parse templs  : ['[ getHealthClientListByTime (  )   dataClientIDs  is  null  timeInterval   =   HiTimeIntervalstartTime = <*>  <*>   endTime = <*>  <*>   timeZone = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 147
# Length: 9, Nums: 1172
# Ground truth  : saveStatData() type =<*>,time = <*>,statClient = <*>,who is <*>
# Parse templs  : ['[ savestatdata (  )   type   = <*> time   =   <*> statclient   = <*> who  is <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 148
# Length: 10, Nums: 792
# Ground truth  : initDataPrivacy the dataPrivacy switch is <*>, start push health data!
# Parse templs  : ['[ initDataPrivacy  the  dataPrivacy  switch  is  open   start  push  health  data ] ']
# Length parse: 1
# ----------------------------------------
# No. 149
# Length: 10, Nums: 792
# Ground truth  : initUserPrivacy the userPrivacy switch is <*>, start push user data!
# Parse templs  : ['[ initUserPrivacy  the  userPrivacy  switch  is  open   start  push  user  data ] ']
# Length parse: 1
# ----------------------------------------
# No. 150
# Length: 11, Nums: 21
# Ground truth  : aggregateHiHealthData() checkAppType <*> appID = <*> id = <*> time= <*>
# Parse templs  : ['[ aggregatehihealthdata (  )   checkapptype <*> appid   = <*> id   = <*> time =   <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 151
# Length: 12, Nums: 705
# Ground truth  : checkFirstSyncByType no such data in db ,type is <*> deviceCode is <*>
# Parse templs  : ['[ checkFirstSyncByType  no  such  data  in  db   type  is <*> deviceCode  is <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 152
# Length: 12, Nums: 27
# Ground truth  : readHiHealthData() checkAppType <*> appID = <*> id = <*> time = <*>
# Parse templs  : ['[ readhihealthdata (  )   checkapptype <*> appid   = <*> id   = <*> time   =   <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 153
# Length: 12, Nums: 27
# Ground truth  : readHiHealthData() readOption = HiDataReadOption{startTime=<*>, endTime=<*>, type=<*>, count = <*>, sortOrder=<*>, readType=<*>, alignType=<*>}
# Parse templs  : ['[ readhihealthdata (  )   readoption   =   hidatareadoptionstarttime = <*>   endtime = <*>   type =  [ <*> 44004 ]    count   = <*> sortorder = <*> readtype = <*> aligntype = <*> ] ', '[ readhihealthdata (  )   readoption   =   hidatareadoptionstarttime = <*>   endtime = <*> type =  [ <*> ]    count   = <*> sortorder = <*> readtype = <*> aligntype = <*> ] ']
# Length parse: 2
# ----------------------------------------
# No. 154
# Length: 14, Nums: 11
# Ground truth  : checkCurrentDay a new day comes , reset basicSyncCondition, currentDay is <*> oldDay is <*>
# Parse templs  : ['[ checkcurrentday  a  new  day  comes     reset  basicsynccondition   currentday  is  <*>  oldday  is  <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 155
# Length: 14, Nums: 744
# Ground truth  : insertHiHealthData() size = <*>,app = <*>,One Data Type = <*>,packageName = <*>,writeStatType = <*>
# Parse templs  : ['[ inserthihealthdata (  )   size   =   <*> app   = <*> one  data  type   =   <*> packagename   =   <*> writestattype   = <*> ] ']
# Length parse: 1
# ----------------------------------------
# No. 156
# Length: 14, Nums: 792
# Ground truth  : startSync hiSyncOption = HiSyncOption{syncAction=<*>, syncMethod=<*>, syncScope=<*>, syncDataType=<*>, syncModel=<*>, pushAction=<*>},app = <*> who = <*>
# Parse templs  : ['[ startsync  hisyncoption   =   hisyncoptionsyncaction = <*> syncmethod = <*> syncscope = <*> syncdatatype = <*> syncmodel = <*> pushaction = <*> app   = <*> who   = <*> ] ']
# Length parse: 1
# ----------------------------------------
# Total differences found: 156
