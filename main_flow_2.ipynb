# %% [markdown]
# #### **0. CHUẨN BỊ**
#
# ##### **0.1. CẤU HÌNH CÁC THAM SỐ**

# %%
import re
import sys
sys.path.append('../')
import os
import pandas as pd
from collections import Counter, defaultdict
import datetime
from tqdm import tqdm
import string
from copy import deepcopy

import hashlib
import time

pd.set_option('display.max_rows', None)

# %% [markdown]
# ##### **0.2. CLASS**

# %%
class LogCluster:
    def __init__(self, keyGroup, logTemplate, tokens, length, logIDL=None):
        self.keyGroup = keyGroup
        self.logTemplate = logTemplate
        self.tokens = tokens
        self.length = length
        self.logIDL = logIDL if logIDL is not None else []
        # self.static_tokenL = static_tokenL if static_tokenL is not None else {}
    def __str__(self):
        # static_str = "Cover Tokens: {\n"
        # for k, v in self.static_tokenL.items():
        #     static_str += f"  {k}: {v},\n"
        # static_str += "}"
        return (
            f"Key: {self.keyGroup}\n"
            f"Template: {self.logTemplate}\n"
            f"Tokens: {self.tokens}\n"
            f"Length: {self.length}\n"
            f"Len LogIDs: {len(self.logIDL)}\n"
            # f"{static_str}\n"
        )

# %% [markdown]
# ##### **0.3. CÁC PHƯƠNG THỨC ĐỌC DỮ LIỆU**

# %%
# ================================= READ DATA ================================= #
def log_to_dataframe(log_file, regex, headers):
    """ Phương thức chuyển đổi file log thành dataframe
    """ 
    log_messages = []
    linecount = 0
    with open(log_file, 'r', encoding="utf8") as fin:
        for line in fin.readlines():
            try:
                match = regex.search(line.strip())
                message = [match.group(header) for header in headers]
                log_messages.append(message)
                linecount += 1
            except Exception as e:
                pass
    logdf = pd.DataFrame(log_messages, columns=headers)
    logdf.insert(0, 'LineId', None)
    logdf['LineId'] = [i + 1 for i in range(linecount)]
    return logdf

def generate_logformat_regex(logformat):
    """ Phương thức tạo regex từ logformat, biểu thức định dạng của một event log: 
    Ex: 'log_format': '<Date> <Time> <Pid> <Level> <Component>: <Content>'
    """
    headers = []
    splitters = re.split(r'(<[^<>]+>)', logformat)
    regex = ''
    for k in range(len(splitters)):
        if k % 2 == 0:
            splitter = re.sub(' +', '\\\s+', splitters[k])
            regex += splitter
        else:
            header = splitters[k].strip('<').strip('>')
            regex += '(?P<%s>.*?)' % header
            headers.append(header)
    regex = re.compile('^' + regex + '$')
    return headers, regex

def load_data(logfile, logformat):
    """ Phương thức trả về một dataframe từ một file log chỉ định
    """
    log_headers, log_regex = generate_logformat_regex(logformat)
    logs_df = log_to_dataframe(logfile, log_regex, log_headers)
    return logs_df

# %% [markdown]
# #### **1. CÁC PHƯƠNG THỨC SỬ DỤNG**
#
# ##### **1.1. TIỀN XỬ LÝ MỨC TOKEN**

# %%
# ============================ CLUSTRING TOKENs =========================== #
def hasNumbers(s):
    return any(char.isdigit() for char in s)

def isDynamicToken(token: str, special_tokens: set) -> bool:
    """ Kiểm tra xem token có phải là token động hay không """

    # 1. Kiểm tra nếu token.lower() nằm trong special_tokens
    if token.lower() in special_tokens:             
        return True

    # 2. Kiểm tra nếu toàn bộ token là số HEX hợp lệ (ít nhất 8 chữ số hex)
    if re.fullmatch(r'0x[0-9a-fA-F]+', token) or re.fullmatch(r'[0-9a-fA-F]{8,}', token):
        return True

    # 3. Kiểm tra nếu token là số (có thể âm, có thể thập phân)
    if re.fullmatch(r'-?\d+(\.\d+)?', token):
        return True

    return False

# %% [markdown]
# ##### **1.2. TIỀN XỬ LÝ MỨC SUBTOKEN**

# %%
# ============================ CLUSTRING SUB_TOKENs =========================== #
def splitSubToken(s, seps):
    placeholder = "__WILDCARD__"
    s = s.replace("<*>", placeholder)

    pattern = '|'.join(re.escape(sep) for sep in seps)

    tokensL = re.split(f'({pattern})', s)
    tokensL = [tok.replace(placeholder, "<*>") for tok in tokensL if tok.strip() != '']

    return tokensL

def processingSubToken(tok):
    # 1. Kiểm tra nếu toàn bộ token là số HEX hợp lệ (ít nhất 8 chữ số hex)
    if re.fullmatch(r'0x[0-9a-fA-F]+', tok) or re.fullmatch(r'[0-9a-fA-F]{8,}', tok):
        return True
    
    if not hasNumbers(tok):
        return False

    # 2. Kiểm tra nếu token là số (có thể âm, có thể thập phân)
    if re.fullmatch(r'-?\d+(\.\d+)?', tok):
        return True

    # 3. Token hợp lệ tĩnh dạng chữ + số, không có ký tự đặc biệt
    if re.fullmatch(r'[a-zA-Z]+[0-9]+', tok):
        return False  # không phải động

    return True
        
def mergeSpecialTok(token_str, seps):
    """ Gộp các chuỗi "<*>" liên tiếp hoặc ngăn cách bằng các ký tự đặc biệt.
    Sau đó tách lại thành danh sách token, bảo toàn chuỗi "<*>".
    """
    sep_pattern = '|'.join(re.escape(sep) for sep in seps)
    
    prev = None
    while token_str != prev:
        prev = token_str
        # Gộp mẫu: <*> + (các ký tự phân tách giống nhau) + <*>
        token_str = re.sub(rf'(<\*>)(({sep_pattern})\3*)(<\*>)', r'<*>', token_str)
        
        # Gộp nhiều <*><*> liên tiếp:
        token_str = re.sub(r'(<\*>)+', r'<*>', token_str)

    return token_str

# %% [markdown]
# ##### **1.3. TẠO DATAFRAME TỪ DỮ LIỆU**

# %%
# ========================= PROCESSING LOGS 2 DATAFRAME ========================= #
def processLine(line, regexs, punctuationL, special_tokens=set()):
    """ Phương thức hỗ trợ xử lý từng dòng log """
    special_set = set(tok.lower() for tok in special_tokens)
    
    tokensL = str(line["Content"]).strip().split()
    
    new_tokens = []
    idx_dynamic_token = []
    static_tokenL = []
    
    for idx_tok, token in enumerate(tokensL):
        # 1. Xử lý token với các regex đã cho
        for pattern, *replacement in regexs:
            replacement = replacement[0] if replacement else "<*>"
            token = re.sub(pattern, replacement, token)
        
        # 2. Nếu tồn tại ký tự đặc biệt trong token, thì xử lý qua phương thức splitSubToken
        sub_tokensL = splitSubToken(token, punctuationL)
        for idx_sub, sub_token in enumerate(sub_tokensL):
            if sub_token in special_set:
                sub_tokensL[idx_sub] = "<*>"
                continue
            
            if processingSubToken(sub_token):
                sub_tokensL[idx_sub] = "<*>"
        
        if len(sub_tokensL) <= 1:
            new_tokens.append(sub_tokensL[0])
        else:
            new_tokens.append("<*>")
            idx_dynamic_token.append(idx_tok)
            static_tokenL.append(sub_tokensL)
    
    # print("NEW TOKENS is: ")
    # print(new_tokens)
    # print("DYNAMIC IDX TOKEN is: ")
    # print(idx_dynamic_token)
    # print("STATIC TOKENS is:")
    # print(static_tokenL)
    
    groupTem_str = f"{' '.join(new_tokens)} : {len(new_tokens)} : {' '.join(str(idx) for idx in idx_dynamic_token)} : {' '.join([str(len(i)) for i in static_tokenL])}"

    return pd.Series({
        'GroupTemplate': hashlib.md5(groupTem_str.encode('utf-8')).hexdigest(),
        'GroupTokens': new_tokens,
        'idxDynamicTok': idx_dynamic_token,
        'StaticTokList': static_tokenL,
        'EventTemplate': f"{' '.join(new_tokens)}",
    })
    
def regexAndCreateDf(datasets, special_tokens=['true', 'false'], punctuationL = set('(),<>:;{}[]~=')):
    logs_df = load_data(datasets['log_file'], datasets['log_format'])

    # ================================ PROCESSING TOKEN AND SUBTOKEN ================================ #
    parse_df = logs_df.copy()
    parse_df['GroupTemplate'] = ""                                  # Lưu template sử dụng để nhóm
    parse_df['GroupTokens'] = [[] for _ in range(len(parse_df))]    # Lưu list token của Group Teplate
    parse_df['idxDynamicTok'] = [[] for _ in range(len(parse_df))]  # Lưu vị trí token động
    parse_df['StaticTokList'] = [[] for _ in range(len(parse_df))]  # Lưu list token tĩnh theo vị trí tương ứng
    parse_df['EventTemplate'] = ""                                  # Template cuối cùng sau khi xử lý


    tqdm.pandas(desc="Tiền xử lý ở mức TOKEN!")
    special_set = set(s.lower() for s in special_tokens)
    
    results = parse_df.progress_apply(
            lambda row: processLine(row, datasets['token_regexs'], punctuationL, special_set),
            axis=1
        )

    for col in results.columns:
        parse_df[col] = results[col]
    
    return parse_df

# %% [markdown]
# ##### **1.4. TẠO CÁC PHÂN CỤM CHO DỮ LIỆU**

# %%
# ================================ TẠO CÁC NHÓM GROUP ================================ #
def generateStaticSubToken(group_staticL, n_merge=3):
    generalized = deepcopy(group_staticL)
    
    for layer_idx in range(len(group_staticL[0])):
        # Lấy toàn bộ layer (dòng dọc) tại vị trí layer_idx
        columns = list(zip(*[row[layer_idx] for row in group_staticL]))
        # columns[i] là cột thứ i trong layer layer_idx
        for subtok_idx, subtok_col in enumerate(columns):
            unique_sub = set(subtok_col)
            if len(unique_sub) >= n_merge or (len(unique_sub) > 1 and "<*>" in unique_sub): 
                for row in generalized:
                    row[layer_idx][subtok_idx] = "<*>"
    
    return generalized

def createGroupClust(parse_df, punctuationL, n_merge = 3, merge_special=False): 
    log_clusters_list = []                                          # List lưu trữ các nhóm log logCluster

    unique_groups = parse_df.groupby("GroupTemplate")
    print(len(unique_groups)) # in ra số nhóm chưa xử lý

    for key, group_val in unique_groups:
        first_row = group_val.iloc[0]
        tokens = first_row['GroupTokens']
        
        if len(first_row["idxDynamicTok"]) != 0:                    # Ktra có token động chưa xử lý hay không?
            group_staticL = group_val['StaticTokList'].to_list()
            group_idL = group_val.index.tolist()
            
            process_staticL = generateStaticSubToken(group_staticL, n_merge)
            temp = defaultdict(list)
            for i, row in enumerate(process_staticL):
                row_key = str(row)
                temp[row_key].append(group_idL[i])
            
            # Trả về danh sách các nhóm với LineID
            result = []
            for key, ids in temp.items():
                group_template = eval(key)  # Chuyển lại thành list gốc
                for idx, val in enumerate(first_row["idxDynamicTok"]):
                    if merge_special:
                        tokens[val] = mergeSpecialTok("".join(group_template[idx]), punctuationL)
                    else:
                        tokens[val] = "".join(group_template[idx])
                    
                logTemplate = " ".join(tokens)
                cluster = LogCluster(
                    keyGroup= hashlib.md5(logTemplate.encode('utf-8')).hexdigest(),
                    logTemplate=logTemplate,
                    tokens=tokens.copy(),
                    length=len(tokens),
                    logIDL=ids.copy(),
                )
                log_clusters_list.append(cluster)            
        else:
            # Nếu trong đó không có token động nào thì: 
            logTemplate = " ".join(tokens)
            cluster = LogCluster(
                    keyGroup= hashlib.md5(logTemplate.encode('utf-8')).hexdigest(),
                    logTemplate=logTemplate,
                    tokens=tokens.copy(),
                    length=len(tokens),
                    logIDL=group_val.index.tolist(),
                )
            log_clusters_list.append(cluster)  
            
    return log_clusters_list

# %% [markdown]
# ##### **1.5. NHÓM CÁC PHÂN CỤM**

# %%
# ======================================= TẠO CLASS ======================================= #
class MergeGroupTemplate:
    def __init__(self, st=0.6, n_merge=3, template_gr=None, punctuationL=set()):
        self.ST = st
        self.N_MERGE = n_merge
        self.TEMPLATE_GR = template_gr if template_gr is not None else []
        self.punctuationL = punctuationL
    
    def similarySeq(self, seq1, seq2):
        """ So sánh độ tương đồng giữa các token của 2 nhóm cluster dựa trên ý tưởng của Drain"""
        assert len(seq1) == len(seq2)
        simTokens = 0
        numOfPar = 0

        for token1, token2 in zip(seq1, seq2):
            if token1 == "<*>":
                numOfPar += 1
                continue
            if token1 == token2:
                simTokens += 1

        retVal = float(simTokens) / len(seq1)

        return retVal, numOfPar
    
    def fastMatchCLuster(self, seqGroupL, seq):
        choose_group = None
        maxSim = -1
        maxNumOfPara = -1
        maxGroup = None

        for gr in seqGroupL:
                curSim, curNumOfPara = self.similarySeq(gr[0].tokens, seq.tokens)
                if curSim > maxSim or (curSim == maxSim and curNumOfPara > maxNumOfPara):
                    maxSim = curSim
                    maxNumOfPara = curNumOfPara
                    maxGroup = gr
                    
                if maxSim >= self.ST:
                    choose_group = maxGroup
        return choose_group

    def findGeneralToken(self, strings):
        def wildcard2Regex(pattern_str):
            # Tách theo wildcard rồi escape từng phần
            parts = pattern_str.split('<*>')
            regex = '.*'.join(re.escape(p) for p in parts)
            return '^' + regex + '$'

        strings = list(strings)

        for candidate in strings:
            regex = wildcard2Regex(candidate)
            if all(re.fullmatch(regex, s) for s in strings if s != candidate):
                return candidate

        return None    
    
    def generalizeGroup(self, group):
        """Tạo pattern chung bằng cách đếm số lượng token khác nhau tại mỗi vị trí"""
        
        mask_positions = defaultdict(str)               # Danh sách các vị trí cần thay thế bằng <*>    
        tokensL = [s.tokens for s in group]
        
        for idx, col in enumerate(zip(*tokensL)):
            unique_token = set(col)
            if len(unique_token) > 1:
                if "<*>" in unique_token:
                    mask_positions[idx] = "<*>"
                else:
                    common_token = self.findGeneralToken(unique_token)
                    if common_token is not None:
                        mask_positions[idx] = common_token
                    else:
                        if len(unique_token) >= self.N_MERGE:
                            sub_tokensL = [splitSubToken(token, self.punctuationL) for token in unique_token]
                            unique_len = set(len(sub_token) for sub_token in sub_tokensL)
                            if len(unique_len) > 1:
                                mask_positions[idx] = "<*>"
                            else:
                                replace_str = []
                                for sub_idx, col_sub in enumerate(zip(*sub_tokensL)):
                                    unique_sub = set(col_sub)
                                    if len(unique_sub) > 1:
                                        replace_str.append("<*>")
                                    else:
                                        replace_str.append(next(iter(unique_sub)))
                                replace_str = "".join(replace_str)
                                while "<*><*>" in replace_str:
                                    replace_str = replace_str.replace("<*><*>", "<*>")
                                mask_positions[idx] = replace_str
            
        # Tạo pattern chung
        for seq in group:
            seq.tokens = [mask_positions[i] if i in mask_positions else token for i, token in enumerate(seq.tokens)]
            seq.logTemplate = " ".join(seq.tokens)

        # Gom nhóm lại theo pattern
        pattern_dict = defaultdict(list)
        for seq in group:
            key = tuple(seq.tokens)
            pattern_dict[key].append(seq)

        result = []
        for key, values in pattern_dict.items():
            if len(values) != 1: 
                logIDL = []
                for x in values:
                    logIDL.extend(x.logIDL)
                values[0].logIDL = logIDL
            result.append(values[0])
        return result
    
    def mergeGroup(self, printL=False):
        grouped_by_length = defaultdict(list)
        [grouped_by_length[t.length].append(t) for t in self.TEMPLATE_GR]
        
        newClusterGroupsL = []
        
        # Nhóm theo chiều dài:
        for length, groups_len in grouped_by_length.items():
            groupsSimTemL = []
            for log_clust in groups_len:
                matched_gr = self.fastMatchCLuster(groupsSimTemL, log_clust)
                if matched_gr is not None:
                    matched_gr.append(log_clust)
                else:
                    groupsSimTemL.append([log_clust])
            for group in groupsSimTemL:
                if len(group) == 1:
                    newClusterGroupsL.extend(group)
                else:
                    refined_groups = self.generalizeGroup(group)
                    newClusterGroupsL.extend(refined_groups)
        
        self.TEMPLATE_GR = newClusterGroupsL

        if printL:
            self.printList()
        
        return newClusterGroupsL
    
    def printList(self):
        print(len(self.TEMPLATE_GR))
        # df = pd.read_csv(datasets['log_template'])
        # print(len(df))

        sorted_list = sorted(self.TEMPLATE_GR, key=lambda log: (log.length, log.logTemplate))
        for e in sorted_list:
            print(f"{e.length:3} {e.logTemplate}")
# ======================================= END CLASS ======================================= #

# %% [markdown]
# #### **2. LÀM VIỆC CHÍNH**
#
# ##### **2.0. PARAMETER DATASET**

# %%
SETTING_PARAMS_TEST = {
    'Apache': {
        'log_file': './logs2k/Apache/Apache_2k.log',
        'log_template': './logs2k/Apache/Apache_2k.log_templates.csv',
        'log_structure': './logs2k/Apache/Apache_2k.log_structured_corrected.csv',
        'log_format': '\[<Time>\] \[<Level>\] <Content>',
        'token_regexs': [
            [r'\/(?:\w+\/){2,}\w+\.\w+$', "<*>"],
            [r'\/(?:[^\/\s]+\/)*[^\/\s]*', "<*>"],
            [r'(?:[0-9a-fA-F]{2,}:){3,}[0-9a-fA-F]{2,}', "<*>"],
        ],    
    },
    'BGL': {
        'log_file': './logs2k/BGL/BGL_2k.log',
        'log_template': './logs2k/BGL/BGL_2k.log_templates.csv',
        'log_structure': './logs2k/BGL/BGL_2k.log_structured_corrected.csv',
        'log_format': '<Label> <Timestamp> <Date> <Node> <Time> <NodeRepeat> <Type> <Component> <Level> <Content>',
        'token_regexs': [
            [r"core\.\d+", "core.<*>"],
            [r'(?:[0-9a-fA-F]{2,}:){3,}[0-9a-fA-F]{2,}', "<*>"],
            [r'(\.{2,})\d+', r'\1<*>']
        ],    
    },
    'Hadoop': {
        'log_file': './logs2k/Hadoop/Hadoop_2k.log',
        'log_template': './logs2k/Hadoop/Hadoop_2k.log_templates.csv',
        'log_structure': './logs2k/Hadoop/Hadoop_2k.log_structured_corrected.csv',
        'log_format': '<Date> <Time> <Level> \[<Process>\] <Component>: <Content>',
        'token_regexs': [
            [r'\[.*?(_.*?)+\]', "<*>"],
        ],    
    },
    'HDFS': {
        'log_file': './logs2k/HDFS/HDFS_2k.log',
        'log_template': './logs2k/HDFS/HDFS_2k.log_templates.csv',
        'log_structure': './logs2k/HDFS/HDFS_2k.log_structured_corrected.csv',
        'log_format': '<Date> <Time> <Pid> <Level> <Component>: <Content>',
        'token_regexs': [
            [r'blk_-?\d+', "<*>"],
            [r'[/]?(\d+\.){3}\d+(:\d+)?', "<*>"], 
        ],    
    },
    'HealthApp':{
        'log_file': './logs2k/HealthApp/HealthApp_2k.log',
        'log_template': './logs2k/HealthApp/HealthApp_2k.log_templates.csv',
        'log_structure': './logs2k/HealthApp/HealthApp_2k.log_structured_corrected.csv',
        'log_format': '<Time>\|<Component>\|<Pid>\|<Content>',
        'token_regexs': [],  
    },
    'HPC':{
        'log_file': './logs2k/HPC/HPC_2k.log',
        'log_template': './logs2k/HPC/HPC_2k.log_templates.csv',
        'log_structure': './logs2k/HPC/HPC_2k.log_structured_corrected.csv',
        'log_format': '<LogId> <Node> <Component> <State> <Time> <Flag> <Content>',
        'token_regexs': [
            [r'=\d+', "<*>"],
        ],  
    },
    'Linux': {
        'log_file': './logs2k/Linux/Linux_2k.log',
        'log_template': './logs2k/Linux/Linux_2k.log_templates.csv',
        'log_structure': './logs2k/Linux/Linux_2k.log_structured_corrected.csv',
        'log_format': '<Month> <Date> <Time> <Level> <Component>(\[<PID>\])?: <Content>',
        'token_regexs': [
            [r'(\d+\.){3}\d+', "<*>"],
            [r'\d{2}:\d{2}:\d{2}', "<*>"],
        ],  
    },
    'Mac': {
        'log_file': './logs2k/Mac/Mac_2k.log',
        'log_template': './logs2k/Mac/Mac_2k.log_templates.csv',
        'log_structure': './logs2k/Mac/Mac_2k.log_structured_corrected.csv',
        'log_format': '<Month>  <Date> <Time> <User> <Component>\[<PID>\]( \(<Address>\))?: <Content>',
        'token_regexs': [
            [r'([\w-]+\.){2,}[\w-]+', "<*>"],
            [r'https?:\/\/(?:[^\/\s]+\/?)*', "<*>"],
            [r'\S*\/(?:[^\/\s]+\/){1,}[^\/\s]*', "<*>"],
        ],  
    },
    'OpenSSH': {
        'log_file': './logs2k/OpenSSH/OpenSSH_2k.log',
        'log_template': './logs2k/OpenSSH/OpenSSH_2k.log_templates.csv',
        'log_structure': './logs2k/OpenSSH/OpenSSH_2k.log_structured_corrected.csv',
        'log_format': '<Date> <Day> <Time> <Component> sshd\[<Pid>\]: <Content>',
        'token_regexs': [
            [r"(\d+):", "<*>"],
        ],    
    },
    'OpenStack': {
        'log_file': './logs2k/OpenStack/OpenStack_2k.log',
        'log_template': './logs2k/OpenStack/OpenStack_2k.log_templates.csv',
        'log_structure': './logs2k/OpenStack/OpenStack_2k.log_structured_corrected.csv',
        'log_format': '<Logrecord> <Date> <Time> <Pid> <Level> <Component> \[<ADDR>\] <Content>',
        'token_regexs': [
            # [r'HTTP\/\d+\.\d+', "<*>"],
            [r'\/(?:\w+\/){2,}\w+\.\w+$', "<*>"],
            ["(\w+-\w+-\w+-\w+-\w+)", "<*>"],
        ],    
    },
    'Proxifier': {
        'log_file': './logs2k/Proxifier/Proxifier_2k.log',
        'log_template': './logs2k/Proxifier/Proxifier_2k.log_templates.csv',
        'log_structure': './logs2k/Proxifier/Proxifier_2k.log_structured_corrected.csv',
        'log_format': '\[<Time>\] <Program> - <Content>',
        'token_regexs': [
            [r'<\d+\ssec', "<*>"],
            [r'([\w-]+\.)+[\w-]+(:\d+)?', "<*>"],
            [r'\d{2}:\d{2}(:\d{2})*', "<*>"],
            [r'[KGTM]B', "<*>"], 
        ],
    },
    'Spark': {
        'log_file': './logs2k/Spark/Spark_2k.log',
        'log_template': './logs2k/Spark/Spark_2k.log_templates.csv',
        'log_structure': './logs2k/Spark/Spark_2k.log_structured_corrected.csv',
        'log_format': '<Date> <Time> <Level> <Component>: <Content>',
        'token_regexs': [],    
    },
    'Thunderbird': {
        'log_file': './logs2k/Thunderbird/Thunderbird_2k.log',
        'log_template': './logs2k/Thunderbird/Thunderbird_2k.log_templates.csv',
        'log_structure': './logs2k/Thunderbird/Thunderbird_2k.log_structured_corrected.csv',
        'log_format': '<Label> <Timestamp> <Date> <User> <Month> <Day> <Time> <Location> <Component>(\[<PID>\])?: <Content>',
        'token_regexs': [
            [r'(\d+\.){3}\d+', "<*>"],
        ],
    },  
    'Zookeeper': {
        'log_file': './logs2k/Zookeeper/Zookeeper_2k.log',
        'log_template': './logs2k/Zookeeper/Zookeeper_2k.log_templates.csv',
        'log_structure': './logs2k/Zookeeper/Zookeeper_2k.log_structured_corrected.csv',
        'log_format': '<Date> <Time> - <Level>  \[<Node>:<Component>@<Id>\] - <Content>',
        'filters': [],
        'token_regexs': [
            # [r"(/|)(\d+\.){3}\d+(:\d+)?", "<*>"],
        ],    
    },
}

# %% [markdown]
# ##### **2.1. LUỒNG LÀM VIỆC**

# %%
DICT_SPECIAL_TOKEN = ['true', 'false', 'null', 'root']
PUNCTUATIONL = '(){}[]=:;,#$@'

N_MERGE = 4
ST = 0.6

def mainDrainDS(SETTING_PARAMS, SPECIAL_TOKENS=[], PUNCTUATION_CHAR=set(), N_MERGE=3, ST=0.6):
    for name_dataset, dataset in SETTING_PARAMS.items():
        print('\n================ Processing on %s =====================' % name_dataset)
        start_time = time.time()
        # ============== PROCESSING 0 ================ #
        parse_df = regexAndCreateDf(dataset, special_tokens=SPECIAL_TOKENS, punctuationL = PUNCTUATION_CHAR)

        # ============== CREATE GROUP =============== #
        log_clusters_list = createGroupClust(parse_df, PUNCTUATION_CHAR, n_merge=N_MERGE, merge_special=False)

        # ============== MERGE TEMPLATE ============= #
        # Sử dụng ý tưởng giống như Drain, như sau:
        merge_group = MergeGroupTemplate(st=ST, n_merge=N_MERGE, template_gr=log_clusters_list, punctuationL=PUNCTUATION_CHAR)
        new_groupL = merge_group.mergeGroup(printL=False)
        print("NUM of GROUP: ", len(new_groupL))

        for item in merge_group.TEMPLATE_GR:
            parse_df.loc[item.logIDL, "EventTemplate"] = item.logTemplate
        parse_df.to_csv(os.path.join("./res/DrainDS/", name_dataset+"_structured.csv"), index=False)
        elapsed_time = time.time() - start_time
        print(f"Hoàn thành xong {name_dataset}: ", elapsed_time)
        print("-"*80)

mainDrainDS(SETTING_PARAMS_TEST, SPECIAL_TOKENS=['true', 'false'], PUNCTUATION_CHAR = set(PUNCTUATIONL), N_MERGE=N_MERGE, ST=ST)
# Out:
# ================ Processing on Apache =====================
# Tiền xử lý ở mức TOKEN!:   0%|          | 0/2000 [00:00<?, ?it/s]
# Tiền xử lý ở mức TOKEN!: 100%|██████████| 2000/2000 [00:00<00:00, 5229.66it/s]
# 6
# NUM of GROUP:  6
# Hoàn thành xong Apache:  0.4128873348236084
# --------------------------------------------------------------------------------
#
# ================ Processing on BGL =====================
# Tiền xử lý ở mức TOKEN!: 100%|██████████| 2000/2000 [00:00<00:00, 5819.63it/s]
# 142
# NUM of GROUP:  125
# Hoàn thành xong BGL:  0.41586995124816895
# --------------------------------------------------------------------------------
#
# ================ Processing on Hadoop =====================
# Tiền xử lý ở mức TOKEN!: 100%|██████████| 2000/2000 [00:00<00:00, 5036.52it/s]
# 118
# NUM of GROUP:  116
# Hoàn thành xong Hadoop:  0.4848666191101074
# --------------------------------------------------------------------------------
#
# ================ Processing on HDFS =====================
# Tiền xử lý ở mức TOKEN!: 100%|██████████| 2000/2000 [00:00<00:00, 4877.30it/s]
# 17
# NUM of GROUP:  16
# Hoàn thành xong HDFS:  0.4479045867919922
# --------------------------------------------------------------------------------
#
# ================ Processing on HealthApp =====================
# Tiền xử lý ở mức TOKEN!: 100%|██████████| 2000/2000 [00:00<00:00, 6043.89it/s]
# 69
# NUM of GROUP:  73
# Hoàn thành xong HealthApp:  0.3854060173034668
# --------------------------------------------------------------------------------
#
# ================ Processing on HPC =====================
# Tiền xử lý ở mức TOKEN!: 100%|██████████| 2000/2000 [00:00<00:00, 7191.22it/s]
# 88
# NUM of GROUP:  45
# Hoàn thành xong HPC:  0.3232598304748535
# --------------------------------------------------------------------------------
#
# ================ Processing on Linux =====================
# Tiền xử lý ở mức TOKEN!: 100%|██████████| 2000/2000 [00:00<00:00, 5307.45it/s]
# 135
# NUM of GROUP:  126
# Hoàn thành xong Linux:  0.4990389347076416
# --------------------------------------------------------------------------------
#
# ================ Processing on Mac =====================
# Tiền xử lý ở mức TOKEN!: 100%|██████████| 2000/2000 [00:00<00:00, 4373.53it/s]
# 339
# NUM of GROUP:  338
# Hoàn thành xong Mac:  0.6145362854003906
# --------------------------------------------------------------------------------
#
# ================ Processing on OpenSSH =====================
# Tiền xử lý ở mức TOKEN!: 100%|██████████| 2000/2000 [00:00<00:00, 4750.75it/s]
# 189
# NUM of GROUP:  27
# Hoàn thành xong OpenSSH:  0.4850800037384033
# --------------------------------------------------------------------------------
#
# ================ Processing on OpenStack =====================
# Tiền xử lý ở mức TOKEN!: 100%|██████████| 2000/2000 [00:00<00:00, 4626.20it/s]
# 59
# NUM of GROUP:  56
# Hoàn thành xong OpenStack:  0.5150375366210938
# --------------------------------------------------------------------------------
#
# ================ Processing on Proxifier =====================
# Tiền xử lý ở mức TOKEN!: 100%|██████████| 2000/2000 [00:00<00:00, 4269.94it/s]
# 16
# NUM of GROUP:  15
# Hoàn thành xong Proxifier:  0.5092763900756836
# --------------------------------------------------------------------------------
#
# ================ Processing on Spark =====================
# Tiền xử lý ở mức TOKEN!: 100%|██████████| 2000/2000 [00:00<00:00, 5831.83it/s]
# 36
# NUM of GROUP:  34
# Hoàn thành xong Spark:  0.3963284492492676
# --------------------------------------------------------------------------------
#
# ================ Processing on Thunderbird =====================
# Tiền xử lý ở mức TOKEN!: 100%|██████████| 2000/2000 [00:00<00:00, 5620.03it/s]
# 221
# NUM of GROUP:  194
# Hoàn thành xong Thunderbird:  0.5008676052093506
# --------------------------------------------------------------------------------
#
# ================ Processing on Zookeeper =====================
# Tiền xử lý ở mức TOKEN!: 100%|██████████| 2000/2000 [00:00<00:00, 5959.04it/s]
# 53
# NUM of GROUP:  53
# Hoàn thành xong Zookeeper:  0.3886864185333252
# --------------------------------------------------------------------------------

# %% [markdown]
# ##### **2.2. ĐÁNH GIÁ BENCHMARK**

# %%
from tqdm import tqdm

from evaluation.settings import benchmark_settings
from evaluation.utils.common import common_args
from evaluation.utils.evaluator_main import *
from evaluation.utils.postprocess import post_average

from evaluation.utils.GA_calculator import evaluate
from evaluation.utils.template_level_analysis import evaluate_template_level
from evaluation.utils.PA_calculator import calculate_parsing_accuracy

import importlib
import evaluation.utils.evaluator_main as evaluator_main
importlib.reload(evaluator_main)

file_path = './benchmark/parsing_accuracy.csv'
if os.path.exists(file_path):
    os.remove(file_path)
result_file = evaluator_main.prepare_results(output_dir="./benchmark")
for name_dataset, dataset_setting in SETTING_PARAMS_TEST.items():
    print('\n================ Evaluation on %s =====================' % name_dataset)
    groundtruth = pd.read_csv(dataset_setting["log_structure"], dtype=str)
    
    parsedresult = os.path.join("./res/DrainDS/", name_dataset + "_structured.csv")
    parsedresult = pd.read_csv(parsedresult, dtype=str)
    parsedresult.fillna("", inplace=True)
    
    tqdm.pandas()
    print("Start to align with null values")
    groundtruth['EventTemplate'] = groundtruth.progress_apply(align_with_null_values, axis=1)
    groundtruth['EventTemplate'] = groundtruth['EventTemplate'].map(correct_template_general)
    parsedresult['EventTemplate'] = parsedresult.progress_apply(align_with_null_values, axis=1)
    
    filter_templates = None
    
    # =============== BENCHMARK GA =============== #
    start_time = time.time()
    GA, FGA = evaluate(groundtruth, parsedresult, filter_templates)

    GA_end_time = time.time() - start_time
#     print('Grouping Accuracy calculation done. [Time taken: {:.3f}]'.format(GA_end_time))
    
    start_time = time.time()
    PA = calculate_parsing_accuracy(groundtruth, parsedresult, filter_templates)
        
    PA_end_time = time.time() - start_time
#     print('Parsing Accuracy calculation done. [Time taken: {:.3f}]'.format(PA_end_time))

    # # =============== BENCHMARK TEMPLATE-LEVEL-ACCURACY =============== #
    start_time = time.time()
    identified_templates, ground_templates, FTA, PTA, RTA = evaluate_template_level(name_dataset, groundtruth, parsedresult, filter_templates)
    
    TA_end_time = time.time() - start_time
#     print('Template-level accuracy calculation done. [Time taken: {:.3f}]'.format(TA_end_time))

    result = name_dataset + ',' + \
            str(identified_templates) + ',' + \
            str(ground_templates) + ',' + \
            "{:.3f}".format(GA) + ',' + \
            "{:.3f}".format(PA) + ',' + \
            "{:.3f}".format(FGA) + ',' + \
            "{:.3f}".format(PTA) + ',' + \
            "{:.3f}".format(RTA) + ',' + \
            "{:.3f}".format(FTA) + '\n'

    with open(os.path.join("./benchmark", result_file), 'a') as summary_file:
        summary_file.write(result)

result_df = pd.read_csv("./benchmark/parsing_accuracy.csv")
print(result_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 20
#      18     os.remove(file_path)
#      19 result_file = evaluator_main.prepare_results(output_dir="./benchmark")
# ---> 20 for name_dataset, dataset_setting in SETTING_PARAMS_TEST.items():
#      21     print('\n================ Evaluation on %s =====================' % name_dataset)
#      22     groundtruth = pd.read_csv(dataset_setting["log_structure"], dtype=str)
#
# NameError: name 'SETTING_PARAMS_TEST' is not defined

# %% [markdown]
# ##### **2.4. BẢNG ĐIỂM**

# %%
result_df = pd.read_csv("./benchmark/parsing_accuracy.csv")
# Chỉ chọn các cột số để tính trung bình và độ lệch chuẩn
numeric_cols = result_df.select_dtypes(include='number').columns

# Tính trung bình
avg_row = result_df[numeric_cols].mean().round(3)
avg_row['Dataset'] = 'Average'
avg_row['parse_gr'] = ''
avg_row['truth_gr'] = ''

# Tính độ lệch chuẩn
std_row = result_df[numeric_cols].std().round(3)
std_row['Dataset'] = 'Std'
std_row['parse_gr'] = ''
std_row['truth_gr'] = ''

# Thêm hai dòng mới vào DataFrame
result_df = pd.concat([result_df, pd.DataFrame([avg_row, std_row])], ignore_index=True)
print(result_df)
# Out:
#         Dataset parse_gr truth_gr     GA     PA    FGA    PTA    RTA    FTA
# 0        Apache        6        6  1.000  0.570  1.000  0.500  0.500  0.500
# 1           BGL      125      120  0.991  0.972  0.947  0.824  0.858  0.841
# 2        Hadoop      116      114  0.993  0.469  0.974  0.716  0.728  0.722
# 3          HDFS       16       14  0.998  0.941  0.867  0.812  0.929  0.867
# 4     HealthApp       73       75  0.998  0.666  0.959  0.836  0.813  0.824
# 5           HPC       45       46  0.925  0.656  0.835  0.556  0.543  0.549
# 6         Linux      132      119  0.541  0.354  0.869  0.705  0.782  0.741
# 7           Mac      338      341  0.948  0.595  0.954  0.621  0.616  0.619
# 8       OpenSSH       27       26  0.999  0.761  0.943  0.556  0.577  0.566
# 9     OpenStack       56       43  0.480  0.394  0.768  0.518  0.674  0.586
# 10    Proxifier       15        8  0.526  0.526  0.609  0.467  0.875  0.609
# 11        Spark       34       36  0.923  0.881  0.829  0.588  0.556  0.571
# 12  Thunderbird      194      149  0.959  0.876  0.764  0.485  0.631  0.548
# 13    Zookeeper       53       50  0.995  0.677  0.951  0.698  0.740  0.718
# 14      Average                    0.877  0.667  0.876  0.634  0.702  0.662
# 15          Std                    0.198  0.199  0.108  0.130  0.137  0.122

# %% [markdown]
# ##### **2.5. SO SÁNH LỖI SAI**

# %%
def compare_templates(datasets, parse_df):
    structured_df = pd.read_csv(datasets['log_structure']) 
    unique_templates = structured_df['EventTemplate'].unique()
    print(f"SHAPE: {structured_df.shape}")
    print(f"SHAPE PARSER: {parse_df.shape}")
    print(f"Num of truth templates: {len(unique_templates)}")

    template_compare = {}
    for template in unique_templates:
        arr_index = structured_df[structured_df['EventTemplate'] == template].index.tolist()
        parse_template_series = parse_df.loc[arr_index, 'EventTemplate']
        parse_template_unique = parse_template_series.unique().tolist()
        content_list = structured_df.loc[arr_index[:3], 'Content'].tolist()
        content_str = "[\n\t" + "\n\t".join(content_list) + "\n]"

        hash_key = hash(template)
        template_compare[hash_key] = {
            'ground_truth': template,
            'parse': parse_template_unique,
            'content_lst': content_str,
            'index': arr_index,
            'length': len(template.strip().split()),
            'nums': len(arr_index),
        }
        
    sorted_items = sorted(
            template_compare.items(),
            key=lambda item: (item[1]['length'], item[1]['ground_truth'])
        )

    num_dif = 0
    for idx, (key, value) in enumerate(sorted_items, 1):
        if len(value['parse']) != 1 or value['parse'][0] != value['ground_truth']:
            num_dif += 1
            print(f"No. {idx}")
            print(f"Length: {value['length']}, Nums: {value['nums']}")
            print(f"Ground truth  : {value['ground_truth']}")
            print(f"Parse templs  : {value['parse']}")
            print(f"Content List: {value['content_lst']}")
            print(f"Length parse: {len(value['parse'])}")
            print("-" * 40)
    print(f"Total differences found: {num_dif}")
    
result_path_dir = "./res/DrainDS/"
choose_dataset = ["Apache", "BGL", "Hadoop", "HDFS", "HealthApp", "HPC", "Linux", "Mac", "OpenSSH", "OpenStack", "Proxifier", "Spark", "Thunderbird", "Zookeeper"]
for name_dataset, dataset_setting in SETTING_PARAMS_TEST.items():
    if name_dataset not in choose_dataset:
        continue
    print("="*40 + f" COMPARE {name_dataset} " + "="*40)
    parsedresult = os.path.join(result_path_dir, name_dataset + "_structured.csv")
    parsedresult = pd.read_csv(parsedresult, dtype=str)
    parsedresult.fillna("", inplace=True)
    
    truth_template = pd.read_csv(dataset_setting["log_structure"], dtype=str)
    unique_templates = truth_template['EventTemplate'].unique()
    
    compare_templates(dataset_setting, parsedresult)
    print("="*45 + " END " + "="*45 + "\n")
# Out:
# ======================================== COMPARE Apache ========================================
# SHAPE: (2000, 6)
# SHAPE PARSER: (2000, 9)
# Num of truth templates: 6
# No. 3
# Length: 7, Nums: 12
# Ground truth  : jk2_init() Can't find child <*> in scoreboard
# Parse templs  : ["<*>() Can't find child <*> in scoreboard"]
# Content List: [
# 	jk2_init() Can't find child 1566 in scoreboard
# 	jk2_init() Can't find child 1567 in scoreboard
# 	jk2_init() Can't find child 2082 in scoreboard
# ]
# Length parse: 1
# ----------------------------------------
# No. 6
# Length: 8, Nums: 836
# Ground truth  : jk2_init() Found child <*> in scoreboard slot <*>
# Parse templs  : ['<*>() Found child <*> in scoreboard slot <*>']
# Content List: [
# 	jk2_init() Found child 6725 in scoreboard slot 10
# 	jk2_init() Found child 6726 in scoreboard slot 8
# 	jk2_init() Found child 6728 in scoreboard slot 6
# ]
# Length parse: 1
# ----------------------------------------
# Total differences found: 2
# ============================================= END =============================================
#
# ======================================== COMPARE BGL ========================================
# SHAPE: (2000, 13)
# SHAPE PARSER: (2000, 16)
# Num of truth templates: 120
# No. 1
# Length: 1, Nums: 1
# Ground truth  : fpr29=<*>
# Parse templs  : ['fpr29=<*> <*> <*> <*>']
# Content List: [
# 	fpr29=0xffffffff ffffffff ffffffff ffffffff
# ]
# Length parse: 1
# ----------------------------------------
# No. 46
# Length: 5, Nums: 1
# Ground truth  : guaranteed data cache block touch........<*>
# Parse templs  : ['guaranteed data cache block <*>']
# Content List: [
# 	guaranteed data cache block touch........1
# ]
# Length parse: 1
# ----------------------------------------
# No. 47
# Length: 5, Nums: 2
# Ground truth  : guaranteed instruction cache block touch.<*>
# Parse templs  : ['guaranteed instruction cache block <*>']
# Content List: [
# 	guaranteed instruction cache block touch.0
# 	guaranteed instruction cache block touch.0
# ]
# Length parse: 1
# ----------------------------------------
# No. 62
# Length: 7, Nums: 1
# Ground truth  : size of scratchpad portion of L3.........<*> (<*>)
# Parse templs  : ['size of scratchpad portion of <*> (<*>)']
# Content List: [
# 	size of scratchpad portion of L3.........0 (0M)
# ]
# Length parse: 1
# ----------------------------------------
# No. 68
# Length: 9, Nums: 2
# Ground truth  : Lustre mount FAILED : <*> : block_id : location
# Parse templs  : ['Lustre mount FAILED : bglio78 : block_id : location', 'Lustre mount FAILED : bglio617 : block_id : location']
# Content List: [
# 	Lustre mount FAILED : bglio78 : block_id : location
# 	Lustre mount FAILED : bglio617 : block_id : location
# ]
# Length parse: 2
# ----------------------------------------
# No. 72
# Length: 9, Nums: 1
# Ground truth  : rts tree/torus link training failed: wanted: <*> got: <*>
# Parse templs  : ['rts tree/torus link training failed: wanted: B C X+ X- Y+ Y- Z+ Z- got: B C X- Y- Z+ Z-']
# Content List: [
# 	rts tree/torus link training failed: wanted: B C X+ X- Y+ Y- Z+ Z- got: B C X- Y- Z+ Z-
# ]
# Length parse: 1
# ----------------------------------------
# No. 73
# Length: 10, Nums: 5
# Ground truth  : Ido chip status changed: <*> ip=<*> v=<*> t=<*> status=M <*>
# Parse templs  : ['Ido chip status changed: <*> ip=<*> v=<*> t=<*> status=M <*> Jul <*> <*>:<*>:<*> PDT <*>', 'Ido chip status changed: <*> ip=<*> v=<*> t=<*> status=M <*> Aug <*> <*>:<*>:<*> PDT <*>', 'Ido chip status changed: <*> ip=<*> v=<*> t=<*> status=M <*> Sep <*> <*>:<*>:<*> PDT <*>']
# Content List: [
# 	Ido chip status changed: FF:F2:9F:16:E2:23:00:0D:60:E9:1D:DC ip=10.0.0.151 v=9 t=4 status=M Fri Jul 01 08:16:53 PDT 2005
# 	Ido chip status changed: FF:F2:9F:16:EB:27:00:0D:60:E9:14:D8 ip=10.0.2.192 v=13 t=4 status=M Thu Aug 04 15:29:45 PDT 2005
# 	Ido chip status changed: FF:F2:9F:15:7E:6E:00:0D:60:EA:81:91 ip=10.0.1.155 v=13 t=1 status=M Thu Aug 04 15:31:25 PDT 2005
# ]
# Length parse: 3
# ----------------------------------------
# No. 75
# Length: 10, Nums: 2
# Ground truth  : NFS Mount failed on <*>, slept <*> seconds, retrying (<*>)
# Parse templs  : ['NFS Mount failed on bglio716, slept <*> seconds, retrying (<*>)', 'NFS Mount failed on bglio91, slept <*> seconds, retrying (<*>)']
# Content List: [
# 	NFS Mount failed on bglio716, slept 15 seconds, retrying (1)
# 	NFS Mount failed on bglio91, slept 15 seconds, retrying (1)
# ]
# Length parse: 2
# ----------------------------------------
# No. 112
# Length: 19, Nums: 9
# Ground truth  : Node card VPD check: <*> node in processor card slot <*> do not match. VPD ecid <*>, found <*>
# Parse templs  : ['Node card VPD check: U11 node in processor card slot <*> do not match. VPD ecid <*>, found <*>', 'Node card VPD check: U01 node in processor card slot <*> do not match. VPD ecid <*>, found <*>']
# Content List: [
# 	Node card VPD check: U11 node in processor card slot J16 do not match. VPD ecid 04DF80A7942FFFFF0C081AE08CD2, found 0000000000000000000000000000
# 	Node card VPD check: U01 node in processor card slot J14 do not match. VPD ecid 074C04C10F7BFFFF08051AE08ED2, found 04C180A5D12FFFFF05081BD088E2
# 	Node card VPD check: U11 node in processor card slot J18 do not match. VPD ecid 04CC81389C2FFFFF03071B7048DF, found 04D780871F2FFFFF08031BD046E2
# ]
# Length parse: 2
# ----------------------------------------
# No. 113
# Length: 19, Nums: 1
# Ground truth  : ciod: In packet from node <*> (<*>), message code <*> is not <*> or <*> (softheader=<*> <*> <*> <*>)
# Parse templs  : ['ciod: In packet from node <*> (<*>:<*>), message code <*> is not <*> or <*> (softheader=<*> <*> <*> <*>)']
# Content List: [
# 	ciod: In packet from node 91.0 (R62-M1-Nf-C:J03-U11), message code 2 is not 3 or 4294967295 (softheader=003b005b 00030000 00000001 00000000)
# ]
# Length parse: 1
# ----------------------------------------
# Total differences found: 10
# ============================================= END =============================================
#
# ======================================== COMPARE Hadoop ========================================
# SHAPE: (2000, 9)
# SHAPE PARSER: (2000, 12)
# Num of truth templates: 114
# No. 1
# Length: 1, Nums: 1
# Ground truth  : jetty-<*>
# Parse templs  : ['<*>']
# Content List: [
# 	jetty-6.1.26
# ]
# Length parse: 1
# ----------------------------------------
# No. 19
# Length: 4, Nums: 3
# Ground truth  : Default file system [hdfs://<*>:<*>]
# Parse templs  : ['Default file system [hdfs:<*>:<*>]']
# Content List: [
# 	Default file system [hdfs://msra-sa-41:9000]
# 	Default file system [hdfs://msra-sa-41:9000]
# 	Default file system [hdfs://msra-sa-41:9000]
# ]
# Length parse: 1
# ----------------------------------------
# No. 22
# Length: 4, Nums: 1
# Ground truth  : Extract jar:file:<*> to <*>
# Parse templs  : ['Extract jar:file:/D:<*> to C:<*>']
# Content List: [
# 	Extract jar:file:/D:/hadoop-2.6.0-localbox/share/hadoop/yarn/hadoop-yarn-common-2.6.0-SNAPSHOT.jar!/webapps/mapreduce to C:\Users\msrabi\AppData\Local\Temp\Jetty_0_0_0_0_62267_mapreduce____.8n7xum\webapp
# ]
# Length parse: 1
# ----------------------------------------
# No. 25
# Length: 4, Nums: 1
# Ground truth  : Instantiated MRClientService at MININT-<*>/<*>:<*>
# Parse templs  : ['Instantiated MRClientService at <*>:<*>']
# Content List: [
# 	Instantiated MRClientService at MININT-FNANLI5.fareast.corp.microsoft.com/10.86.169.121:62260
# ]
# Length parse: 1
# ----------------------------------------
# No. 32
# Length: 4, Nums: 39
# Ground truth  : Resolved <*> to <*>
# Parse templs  : ['Resolved <*> to /default-rack']
# Content List: [
# 	Resolved MSRA-SA-39.fareast.corp.microsoft.com to /default-rack
# 	Resolved MSRA-SA-41.fareast.corp.microsoft.com to /default-rack
# 	Resolved MSRA-SA-39.fareast.corp.microsoft.com to /default-rack
# ]
# Length parse: 1
# ----------------------------------------
# No. 34
# Length: 4, Nums: 2
# Ground truth  : adding path spec: <*>
# Parse templs  : ['adding path spec: /mapreduce/*', 'adding path spec: /ws/*']
# Content List: [
# 	adding path spec: /mapreduce/*
# 	adding path spec: /ws/*
# ]
# Length parse: 2
# ----------------------------------------
# No. 35
# Length: 4, Nums: 1
# Ground truth  : loaded properties from hadoop-metrics2.properties
# Parse templs  : ['loaded properties from <*>']
# Content List: [
# 	loaded properties from hadoop-metrics2.properties
# ]
# Length parse: 1
# ----------------------------------------
# No. 36
# Length: 5, Nums: 2
# Ground truth  : <*> failures on node MININT-<*>
# Parse templs  : ['<*> failures on node <*>']
# Content List: [
# 	1 failures on node MININT-FNANLI5.fareast.corp.microsoft.com
# 	2 failures on node MININT-FNANLI5.fareast.corp.microsoft.com
# ]
# Length parse: 1
# ----------------------------------------
# No. 37
# Length: 5, Nums: 1
# Ground truth  : Added global filter 'safety' (class=org.apache.hadoop.http.HttpServer2$QuotingInputFilter)
# Parse templs  : ["Added global filter 'safety' (class=<*>$QuotingInputFilter)"]
# Content List: [
# 	Added global filter 'safety' (class=org.apache.hadoop.http.HttpServer2$QuotingInputFilter)
# ]
# Length parse: 1
# ----------------------------------------
# No. 40
# Length: 5, Nums: 1
# Ground truth  : Connecting to ResourceManager at <*>/<*>:<*>
# Parse templs  : ['Connecting to ResourceManager at <*>:<*>']
# Content List: [
# 	Connecting to ResourceManager at msra-sa-41/10.190.173.170:8030
# ]
# Length parse: 1
# ----------------------------------------
# No. 45
# Length: 5, Nums: 1
# Ground truth  : OutputCommitter set in config <*>
# Parse templs  : ['OutputCommitter set in config null']
# Content List: [
# 	OutputCommitter set in config null
# ]
# Length parse: 1
# ----------------------------------------
# No. 55
# Length: 6, Nums: 1
# Ground truth  : Adding protocol org.apache.hadoop.mapreduce.v2.api.MRClientProtocolPB to the server
# Parse templs  : ['Adding protocol <*> to the server']
# Content List: [
# 	Adding protocol org.apache.hadoop.mapreduce.v2.api.MRClientProtocolPB to the server
# ]
# Length parse: 1
# ----------------------------------------
# No. 56
# Length: 6, Nums: 1
# Ground truth  : DFSOutputStream ResponseProcessor exception for block BP-<*>:<*>
# Parse templs  : ['DFSOutputStream ResponseProcessor exception for block <*>:<*>']
# Content List: [
# 	DFSOutputStream ResponseProcessor exception  for block BP-1347369012-10.190.173.170-1444972147527:blk_1073743512_2731
# ]
# Length parse: 1
# ----------------------------------------
# No. 59
# Length: 6, Nums: 9
# Ground truth  : Registering class org.apache.hadoop.mapreduce.<*> for class org.apache.hadoop.mapreduce.<*>
# Parse templs  : ['Registering class <*> for class <*>']
# Content List: [
# 	Registering class org.apache.hadoop.mapreduce.jobhistory.EventType for class org.apache.hadoop.mapreduce.jobhistory.JobHistoryEventHandler
# 	Registering class org.apache.hadoop.mapreduce.v2.app.job.event.JobEventType for class org.apache.hadoop.mapreduce.v2.app.MRAppMaster$JobEventDispatcher
# 	Registering class org.apache.hadoop.mapreduce.v2.app.job.event.TaskEventType for class org.apache.hadoop.mapreduce.v2.app.MRAppMaster$TaskEventDispatcher
# ]
# Length parse: 1
# ----------------------------------------
# No. 62
# Length: 6, Nums: 1
# Ground truth  : Web app <*> started at <*>
# Parse templs  : ['Web app /mapreduce started at <*>']
# Content List: [
# 	Web app /mapreduce started at 62267
# ]
# Length parse: 1
# ----------------------------------------
# No. 78
# Length: 7, Nums: 476
# Ground truth  : Address change detected. Old: <*>/<*>:<*> New: <*>:<*>
# Parse templs  : ['Address change detected. Old: <*>:<*> New: <*>:<*>']
# Content List: [
# 	Address change detected. Old: msra-sa-41/10.190.173.170:9000 New: msra-sa-41:9000
# 	Address change detected. Old: msra-sa-41/10.190.173.170:9000 New: msra-sa-41:9000
# 	Address change detected. Old: msra-sa-41/10.190.173.170:9000 New: msra-sa-41:9000
# ]
# Length parse: 1
# ----------------------------------------
# No. 80
# Length: 7, Nums: 1
# Ground truth  : MRAppMaster launching normal, non-uberized, multi-container job <*>.
# Parse templs  : ['MRAppMaster launching normal, non-uberized, multi-container job <*>']
# Content List: [
# 	MRAppMaster launching normal, non-uberized, multi-container job job_1445144423722_0020.
# ]
# Length parse: 1
# ----------------------------------------
# No. 88
# Length: 8, Nums: 1
# Ground truth  : Event Writer setup for JobId: <*>, File: hdfs://<*>
# Parse templs  : ['Event Writer setup for JobId: <*>, File: hdfs:<*>:<*>']
# Content List: [
# 	Event Writer setup for JobId: job_1445144423722_0020, File: hdfs://msra-sa-41:9000/tmp/hadoop-yarn/staging/msrabi/.staging/job_1445144423722_0020/job_1445144423722_0020_1.jhist
# ]
# Length parse: 1
# ----------------------------------------
# No. 92
# Length: 8, Nums: 10
# Ground truth  : TaskAttempt: [<*>] using containerId: [<*> on NM: [<*>:<*>]
# Parse templs  : ['TaskAttempt: <*> using containerId: [<*> on NM: [<*>:<*>]']
# Content List: [
# 	TaskAttempt: [attempt_1445144423722_0020_m_000000_0] using containerId: [container_1445144423722_0020_01_000002 on NM: [04DN8IQ.fareast.corp.microsoft.com:54883]
# 	TaskAttempt: [attempt_1445144423722_0020_m_000001_0] using containerId: [container_1445144423722_0020_01_000003 on NM: [MININT-FNANLI5.fareast.corp.microsoft.com:52368]
# 	TaskAttempt: [attempt_1445144423722_0020_m_000002_0] using containerId: [container_1445144423722_0020_01_000004 on NM: [MININT-FNANLI5.fareast.corp.microsoft.com:52368]
# ]
# Length parse: 1
# ----------------------------------------
# No. 97
# Length: 9, Nums: 1
# Ground truth  : The job-jar file on the remote FS is hdfs://<*>
# Parse templs  : ['The job-jar file on the remote FS is <*>']
# Content List: [
# 	The job-jar file on the remote FS is hdfs://msra-sa-41:9000/tmp/hadoop-yarn/staging/msrabi/.staging/job_1445144423722_0020/job.jar
# ]
# Length parse: 1
# ----------------------------------------
# No. 99
# Length: 10, Nums: 13
# Ground truth  : Processing the event EventType: <*> for container <*> taskAttempt <*>
# Parse templs  : ['Processing the event EventType: CONTAINER_REMOTE_LAUNCH for container <*> taskAttempt <*>', 'Processing the event EventType: CONTAINER_REMOTE_CLEANUP for container <*> taskAttempt <*>']
# Content List: [
# 	Processing the event EventType: CONTAINER_REMOTE_LAUNCH for container container_1445144423722_0020_01_000002 taskAttempt attempt_1445144423722_0020_m_000000_0
# 	Processing the event EventType: CONTAINER_REMOTE_LAUNCH for container container_1445144423722_0020_01_000003 taskAttempt attempt_1445144423722_0020_m_000001_0
# 	Processing the event EventType: CONTAINER_REMOTE_LAUNCH for container container_1445144423722_0020_01_000004 taskAttempt attempt_1445144423722_0020_m_000002_0
# ]
# Length parse: 2
# ----------------------------------------
# No. 102
# Length: 12, Nums: 1
# Ground truth  : Error Recovery for block BP-<*>:<*> in pipeline <*>:<*>, <*>:<*>: bad datanode <*>:<*>
# Parse templs  : ['Error Recovery for block <*>:<*> in pipeline <*>:<*>, <*>:<*>: bad datanode <*>:<*>']
# Content List: [
# 	Error Recovery for block BP-1347369012-10.190.173.170-1444972147527:blk_1073743512_2731 in pipeline 10.86.169.121:50010, 10.190.173.170:50010: bad datanode 10.190.173.170:50010
# ]
# Length parse: 1
# ----------------------------------------
# No. 103
# Length: 12, Nums: 1
# Ground truth  : Input size for job <*> = <*>. Number of splits = <*>
# Parse templs  : ['Input size for job <*> = <*> Number of splits = <*>']
# Content List: [
# 	Input size for job job_1445144423722_0020 = 1256521728. Number of splits = 10
# ]
# Length parse: 1
# ----------------------------------------
# No. 108
# Length: 13, Nums: 326
# Ground truth  : Failed to renew lease for [<*>] for <*> seconds. Will retry shortly ...
# Parse templs  : ['Failed to renew lease for <*> for <*> seconds. Will retry shortly ...']
# Content List: [
# 	Failed to renew lease for [DFSClient_NONMAPREDUCE_1537864556_1] for 30 seconds.  Will retry shortly ...
# 	Failed to renew lease for [DFSClient_NONMAPREDUCE_1537864556_1] for 31 seconds.  Will retry shortly ...
# 	Failed to renew lease for [DFSClient_NONMAPREDUCE_1537864556_1] for 32 seconds.  Will retry shortly ...
# ]
# Length parse: 1
# ----------------------------------------
# No. 109
# Length: 15, Nums: 146
# Ground truth  : Retrying connect to server: <*>:<*>. Already tried <*> time(s); retry policy is RetryUpToMaximumCountWithFixedSleep(maxRetries=<*>, sleepTime=<*> MILLISECONDS)
# Parse templs  : ['Retrying connect to server: <*>:<*> Already tried <*> time(s); retry policy is RetryUpToMaximumCountWithFixedSleep(maxRetries=<*>, sleepTime=<*> MILLISECONDS)']
# Content List: [
# 	Retrying connect to server: msra-sa-41:8030. Already tried 0 time(s); retry policy is RetryUpToMaximumCountWithFixedSleep(maxRetries=10, sleepTime=1000 MILLISECONDS)
# 	Retrying connect to server: msra-sa-41:8030. Already tried 0 time(s); retry policy is RetryUpToMaximumCountWithFixedSleep(maxRetries=10, sleepTime=1000 MILLISECONDS)
# 	Retrying connect to server: msra-sa-41:8030. Already tried 0 time(s); retry policy is RetryUpToMaximumCountWithFixedSleep(maxRetries=10, sleepTime=1000 MILLISECONDS)
# ]
# Length parse: 1
# ----------------------------------------
# No. 112
# Length: 32, Nums: 4
# Ground truth  : Diagnostics report from <*>: Error: java.net.NoRouteToHostException: No Route to Host from MININT-<*>/<*> to <*>:<*> failed on socket timeout exception: java.net.NoRouteToHostException: No route to host: no further information; For more details see: http://wiki.apache.org/hadoop/NoRouteToHost
# Parse templs  : ['Diagnostics <*> from <*>: Error: java.net.NoRouteToHostException: No Route to Host from <*> to <*>:<*> failed on socket timeout exception: java.net.NoRouteToHostException: No route to host: no further information; For more details see: http://wiki.apache.org/hadoop/NoRouteToHost']
# Content List: [
# 	Diagnostics report from attempt_1445144423722_0020_m_000002_0: Error: java.net.NoRouteToHostException: No Route to Host from  MININT-FNANLI5/127.0.0.1 to msra-sa-41:9000 failed on socket timeout exception: java.net.NoRouteToHostException: No route to host: no further information; For more details see:  http://wiki.apache.org/hadoop/NoRouteToHost
# 	Diagnostics report from attempt_1445144423722_0020_m_000002_0: Error: java.net.NoRouteToHostException: No Route to Host from  MININT-FNANLI5/127.0.0.1 to msra-sa-41:9000 failed on socket timeout exception: java.net.NoRouteToHostException: No route to host: no further information; For more details see:  http://wiki.apache.org/hadoop/NoRouteToHost
# 	Diagnostics report from attempt_1445144423722_0020_m_000001_0: Error: java.net.NoRouteToHostException: No Route to Host from  MININT-FNANLI5/127.0.0.1 to msra-sa-41:9000 failed on socket timeout exception: java.net.NoRouteToHostException: No route to host: no further information; For more details see:  http://wiki.apache.org/hadoop/NoRouteToHost
# ]
# Length parse: 1
# ----------------------------------------
# No. 113
# Length: 32, Nums: 2
# Ground truth  : Task: <*> - exited : java.net.NoRouteToHostException: No Route to Host from MININT-<*>/<*> to <*>:<*> failed on socket timeout exception: java.net.NoRouteToHostException: No route to host: no further information; For more details see: http://wiki.apache.org/hadoop/NoRouteToHost
# Parse templs  : ['Task: <*> - exited : java.net.NoRouteToHostException: No Route to Host from <*> to <*>:<*> failed on socket timeout exception: java.net.NoRouteToHostException: No route to host: no further information; For more details see: http://wiki.apache.org/hadoop/NoRouteToHost']
# Content List: [
# 	Task: attempt_1445144423722_0020_m_000002_0 - exited : java.net.NoRouteToHostException: No Route to Host from  MININT-FNANLI5/127.0.0.1 to msra-sa-41:9000 failed on socket timeout exception: java.net.NoRouteToHostException: No route to host: no further information; For more details see:  http://wiki.apache.org/hadoop/NoRouteToHost
# 	Task: attempt_1445144423722_0020_m_000001_0 - exited : java.net.NoRouteToHostException: No Route to Host from  MININT-FNANLI5/127.0.0.1 to msra-sa-41:9000 failed on socket timeout exception: java.net.NoRouteToHostException: No route to host: no further information; For more details see:  http://wiki.apache.org/hadoop/NoRouteToHost
# ]
# Length parse: 1
# ----------------------------------------
# Total differences found: 27
# ============================================= END =============================================
#
# ======================================== COMPARE HDFS ========================================
# SHAPE: (2000, 9)
# SHAPE PARSER: (2000, 12)
# Num of truth templates: 14
# No. 4
# Length: 6, Nums: 80
# Ground truth  : <*>:<*> Served block <*> to <*>
# Parse templs  : ['<*> Served block <*> to <*>']
# Content List: [
# 	10.251.194.213:50010 Served block blk_-7724713468912166542 to /10.251.203.80
# 	10.251.91.229:50010 Served block blk_-3358448553918665902 to /10.251.91.229
# 	10.251.39.192:50010 Served block blk_-5341992729755584578 to /10.251.39.192
# ]
# Length parse: 1
# ----------------------------------------
# No. 5
# Length: 6, Nums: 5
# Ground truth  : BLOCK* ask <*>:<*> to delete <*>
# Parse templs  : ['BLOCK* ask <*> to delete <*>', 'BLOCK* ask <*> to delete <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*>', 'BLOCK* ask <*> to delete <*> <*> <*> <*> <*> <*> <*> <*> <*>']
# Content List: [
# 	BLOCK* ask 10.250.18.114:50010 to delete  blk_-5140072410813878235
# 	BLOCK* ask 10.251.122.79:50010 to delete  blk_8048594464172649365
# 	BLOCK* ask 10.250.17.177:50010 to delete  blk_-8570780307468499817 blk_-9122557405432088649 blk_-4393063808227796056 blk_8767569714374844347 blk_7079754042611867581 blk_7608961006114219538 blk_-5017273584996436939 blk_-6537833125980536955 blk_7610838808763810123 blk_3300803097775546532 blk_-5120750586032922592 blk_1577274266662884430 blk_765879159867598347 blk_-9076085976403711202 blk_-3198963348573340497 blk_-4645750029177277209 blk_-5136142986912961316 blk_5677959846373741243 blk_2107477892986152528 blk_-4235116161537008844 blk_6082535783543982566 blk_-4809870147222033236 blk_8818706925296961012 blk_-5203577173046267127 blk_189089569009261656 blk_446299976487589160 blk_-3916247521166632303 blk_-3324962406687427922 blk_-1807424528783081572 blk_-6858401049333055963 blk_6036564204960295926 blk_-8140723044408248078 blk_-3800132731140204959 blk_1716344083117307767 blk_-5194808114606613364 blk_-5473871016976323232 blk_2920934363167004552 blk_8736689095894369097 blk_-7642734632751940776 blk_3408482260833769309 blk_118013751374560901 blk_7963891081239759520 blk_3813114133944383323 blk_3042818489384932576 blk_-4570173726231458270 blk_-1564644006975920581 blk_338095650783321996 blk_3150135312641203550 blk_4285859645577726288 blk_3438772130782939627 blk_2634772258588877972 blk_-6795664812575964130 blk_3923069610304693233 blk_-1782996202120067721 blk_2004418049430157212 blk_1932147224007687756 blk_-582901062969027153 blk_5072240701440032119 blk_-7919006477393039068 blk_-7318022361288598312 blk_-6974693594143537436 blk_-5435767047126325206 blk_-5805500288959332434 blk_-7109885589081848850 blk_2161580591957523893 blk_7240227881194993860 blk_-8298405680648445349 blk_-4253026248821272215 blk_8377661448601579317 blk_8029153852899017155 blk_-8754388319080705916 blk_-7844092300527332901 blk_710178463364063355 blk_-5136849989188547884 blk_8393887138377503163 blk_-6950176077776664217 blk_-6488701068659548195 blk_2537458728254532453 blk_364441107933628577 blk_6207861897580168557 blk_8814943807366894581 blk_-4150682644311695471 blk_9174833667156726933 blk_649427218152856001 blk_-7403541028238011236 blk_-334982586592048773 blk_61908781908925992 blk_6385574357371832424 blk_-66376131060945541 blk_1372596948297458670 blk_-3389135155401857220 blk_-6035411221441929663 blk_-5127580069634421247 blk_-5685246533892022418 blk_4977937528993040451 blk_5680538862600094527 blk_-8378747462487962732 blk_425101290285860876 blk_6306622708327890839 blk_-1067866602168873257
# ]
# Length parse: 3
# ----------------------------------------
# No. 7
# Length: 7, Nums: 80
# Ground truth  : <*>:<*>:Got exception while serving <*> to <*>:
# Parse templs  : ['<*>:Got exception while serving <*> to <*>:']
# Content List: [
# 	10.251.30.85:50010:Got exception while serving blk_-2918118818249673980 to /10.251.90.64:
# 	10.251.126.255:50010:Got exception while serving blk_8376667364205250596 to /10.251.91.159:
# 	10.251.123.132:50010:Got exception while serving blk_3763728533434719668 to /10.251.38.214:
# ]
# Length parse: 1
# ----------------------------------------
# No. 8
# Length: 7, Nums: 292
# Ground truth  : Receiving block <*> src: <*>:<*> dest: <*>:<*>
# Parse templs  : ['Receiving block <*> src: <*> dest: <*>']
# Content List: [
# 	Receiving block blk_5792489080791696128 src: /10.251.30.6:33145 dest: /10.251.30.6:50010
# 	Receiving block blk_1724757848743533110 src: /10.251.111.130:49851 dest: /10.251.111.130:50010
# 	Receiving block blk_-5623176793330377570 src: /10.251.75.228:53725 dest: /10.251.75.228:50010
# ]
# Length parse: 1
# ----------------------------------------
# No. 10
# Length: 9, Nums: 1
# Ground truth  : <*>:<*> Starting thread to transfer block <*> to <*>:<*>
# Parse templs  : ['<*> Starting thread to transfer block <*> to <*>']
# Content List: [
# 	10.250.15.198:50010 Starting thread to transfer block blk_4292382298896622412 to 10.250.15.240:50010
# ]
# Length parse: 1
# ----------------------------------------
# No. 11
# Length: 9, Nums: 224
# Ground truth  : BLOCK* NameSystem.delete: <*> is added to invalidSet of <*>:<*>
# Parse templs  : ['BLOCK* NameSystem.delete: <*> is added to invalidSet of <*>']
# Content List: [
# 	BLOCK* NameSystem.delete: blk_2568309208894455676 is added to invalidSet of 10.251.31.160:50010
# 	BLOCK* NameSystem.delete: blk_-1233005817943453613 is added to invalidSet of 10.251.75.49:50010
# 	BLOCK* NameSystem.delete: blk_-8736461628840265232 is added to invalidSet of 10.251.195.70:50010
# ]
# Length parse: 1
# ----------------------------------------
# No. 12
# Length: 9, Nums: 1
# Ground truth  : BLOCK* ask <*>:<*> to replicate <*> to datanode(s) <*>:<*>
# Parse templs  : ['BLOCK* ask <*> to replicate <*> to datanode(s) <*>']
# Content List: [
# 	BLOCK* ask 10.250.14.38:50010 to replicate blk_-7571492020523929240 to datanode(s) 10.251.122.38:50010
# ]
# Length parse: 1
# ----------------------------------------
# No. 13
# Length: 10, Nums: 2
# Ground truth  : Received block <*> src: <*>:<*> dest: <*>:<*> of size <*>
# Parse templs  : ['Received block <*> src: <*> dest: <*> of size <*>']
# Content List: [
# 	Received block blk_-4411589101766563890 src: /10.250.14.38:37362 dest: /10.250.14.38:50010 of size 67108864
# 	Received block blk_1473949624670719319 src: /10.251.29.239:35617 dest: /10.251.29.239:50010 of size 67108864
# ]
# Length parse: 1
# ----------------------------------------
# No. 14
# Length: 11, Nums: 314
# Ground truth  : BLOCK* NameSystem.addStoredBlock: blockMap updated: <*>:<*> is added to <*> size <*>
# Parse templs  : ['BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>']
# Content List: [
# 	BLOCK* NameSystem.addStoredBlock: blockMap updated: 10.251.73.220:50010 is added to blk_7128370237687728475 size 67108864
# 	BLOCK* NameSystem.addStoredBlock: blockMap updated: 10.251.43.115:50010 is added to blk_3050920587428079149 size 67108864
# 	BLOCK* NameSystem.addStoredBlock: blockMap updated: 10.251.203.80:50010 is added to blk_7888946331804732825 size 67108864
# ]
# Length parse: 1
# ----------------------------------------
# Total differences found: 9
# ============================================= END =============================================
#
# ======================================== COMPARE HealthApp ========================================
# SHAPE: (2000, 7)
# SHAPE PARSER: (2000, 10)
# Num of truth templates: 75
# No. 1
# Length: 1, Nums: 1
# Ground truth  : <*>|<*>|<*>|<*>
# Parse templs  : ['<*>']
# Content List: [
# 	tryToReloadTodayBasicSteps1514044800223|3786|0|0
# ]
# Length parse: 1
# ----------------------------------------
# No. 2
# Length: 1, Nums: 1
# Ground truth  : clear()
# Parse templs  : ['<*>(<*>']
# Content List: [
# 	clear()
# ]
# Length parse: 1
# ----------------------------------------
# No. 4
# Length: 1, Nums: 1
# Ground truth  : deleteHealthNotification()
# Parse templs  : ['<*>(<*>']
# Content List: [
# 	deleteHealthNotification()
# ]
# Length parse: 1
# ----------------------------------------
# No. 9
# Length: 1, Nums: 1
# Ground truth  : setDiffTotalSteps=<*>
# Parse templs  : ['<*>=<*>']
# Content List: [
# 	setDiffTotalSteps=0
# ]
# Length parse: 1
# ----------------------------------------
# No. 10
# Length: 1, Nums: 241
# Ground truth  : setTodayTotalDetailSteps=<*>
# Parse templs  : ['setTodayTotalDetailSteps=<*>##<*>##<*>##<*>##<*>##<*>']
# Content List: [
# 	setTodayTotalDetailSteps=1514038440000##7007##548365##8661##12361##27173954
# 	setTodayTotalDetailSteps=1514038440000##7008##548365##8661##12456##27174269
# 	setTodayTotalDetailSteps=1514038440000##7009##548365##8661##12551##27174951
# ]
# Length parse: 1
# ----------------------------------------
# No. 11
# Length: 1, Nums: 1
# Ground truth  : setWriteDBLastDataMinute=<*>
# Parse templs  : ['<*>=<*>']
# Content List: [
# 	setWriteDBLastDataMinute=25233979
# ]
# Length parse: 1
# ----------------------------------------
# No. 17
# Length: 2, Nums: 6
# Ground truth  : getTodaySportData mStepsRecordManager=<*>
# Parse templs  : ['getTodaySportData mStepsRecordManager=com.huawei.health.g.c@<*>']
# Content List: [
# 	getTodaySportData mStepsRecordManager=com.huawei.health.g.c@8a2a501
# 	getTodaySportData mStepsRecordManager=com.huawei.health.g.c@8a2a501
# 	getTodaySportData mStepsRecordManager=com.huawei.health.g.c@8a2a501
# ]
# Length parse: 1
# ----------------------------------------
# No. 30
# Length: 3, Nums: 1
# Ground truth  : flush2DB result success
# Parse templs  : ['<*> result success']
# Content List: [
# 	flush2DB result success
# ]
# Length parse: 1
# ----------------------------------------
# No. 66
# Length: 8, Nums: 2
# Ground truth  : getAppContext() isAppValid health or wear, packageName = <*>
# Parse templs  : ['getAppContext() isAppValid health or wear, packageName = com.huawei.health']
# Content List: [
# 	getAppContext() isAppValid health or wear, packageName = com.huawei.health
# 	getAppContext() isAppValid health or wear, packageName = com.huawei.health
# ]
# Length parse: 1
# ----------------------------------------
# No. 74
# Length: 14, Nums: 2
# Ground truth  : insertHiHealthData() size = <*>,app = <*>,One Data Type = <*>,packageName = <*>,writeStatType = <*>
# Parse templs  : ['insertHiHealthData() size = <*>,app = <*>,One Data Type = <*>,packageName = com.huawei.health,writeStatType = <*>']
# Content List: [
# 	insertHiHealthData() size = 4,app = 1,One Data Type = 40002,packageName = com.huawei.health,writeStatType = 0
# 	insertHiHealthData() size = 20,app = 1,One Data Type = 2,packageName = com.huawei.health,writeStatType = 0
# ]
# Length parse: 1
# ----------------------------------------
# Total differences found: 10
# ============================================= END =============================================
#
# ======================================== COMPARE HPC ========================================
# SHAPE: (2000, 10)
# SHAPE PARSER: (2000, 13)
# Num of truth templates: 46
# No. 2
# Length: 1, Nums: 292
# Ground truth  : ambient=<*>
# Parse templs  : ['ambient<*>']
# Content List: [
# 	ambient=30
# 	ambient=30
# 	ambient=31
# ]
# Length parse: 1
# ----------------------------------------
# No. 18
# Length: 3, Nums: 4
# Ground truth  : Targeting domains:node-<*> nodes:node-<*>
# Parse templs  : ['Targeting domains:<*> and nodes:node-[<*> <*> <*>]', 'Targeting domains:<*> and nodes:<*>', 'Targeting domains:node-D[<*> <*>] and nodes:node-[<*> <*>]']
# Content List: [
# 	Targeting domains:node-D7 and nodes:node-[224\ 228\ 232]
# 	Targeting domains:node-D0 and nodes:node-0
# 	Targeting domains:node-D[0\ 5] and nodes:node-[27\ 191]
# ]
# Length parse: 3
# ----------------------------------------
# No. 19
# Length: 3, Nums: 67
# Ground truth  : boot (command <*>)
# Parse templs  : ['<*> (command <*>)']
# Content List: [
# 	boot  (command 1911)
# 	boot  (command 1910)
# 	boot  (command 1978)
# ]
# Length parse: 1
# ----------------------------------------
# No. 20
# Length: 3, Nums: 2
# Ground truth  : bootGenvmunix (command <*>)
# Parse templs  : ['<*> (command <*>)']
# Content List: [
# 	bootGenvmunix  (command 1903)
# 	bootGenvmunix  (command 4185)
# ]
# Length parse: 1
# ----------------------------------------
# No. 21
# Length: 3, Nums: 2
# Ground truth  : clusterAddMember (command <*>)
# Parse templs  : ['<*> (command <*>)']
# Content List: [
# 	clusterAddMember  (command 1902)
# 	clusterAddMember  (command 1900)
# ]
# Length parse: 1
# ----------------------------------------
# No. 22
# Length: 3, Nums: 3
# Ground truth  : halt (command <*>)
# Parse templs  : ['<*> (command <*>)']
# Content List: [
# 	halt  (command 1982)
# 	halt  (command 2221)
# 	halt  (command 2992)
# ]
# Length parse: 1
# ----------------------------------------
# No. 23
# Length: 3, Nums: 5
# Ground truth  : psu failure\ ambient=<*>
# Parse templs  : ['psu failure\\ ambient<*>']
# Content List: [
# 	psu failure\ ambient=28
# 	psu failure\ ambient=28
# 	psu failure\ ambient=28
# ]
# Length parse: 1
# ----------------------------------------
# No. 24
# Length: 3, Nums: 1
# Ground truth  : risBoot (command <*>)
# Parse templs  : ['<*> (command <*>)']
# Content List: [
# 	risBoot  (command 1903)
# ]
# Length parse: 1
# ----------------------------------------
# No. 25
# Length: 3, Nums: 66
# Ground truth  : wait (command <*>)
# Parse templs  : ['<*> (command <*>)']
# Content List: [
# 	wait  (command 1975)
# 	wait  (command 1973)
# 	wait  (command 2057)
# ]
# Length parse: 1
# ----------------------------------------
# No. 31
# Length: 6, Nums: 4
# Ground truth  : Link error on broadcast tree Interconnect-<*>:<*>:<*>:<*>
# Parse templs  : ['Link error on broadcast tree <*>:<*>:<*>:<*>']
# Content List: [
# 	Link error on broadcast tree Interconnect-0T00:00:2:1
# 	Link error on broadcast tree Interconnect-1T00:00:3:6
# 	Link error on broadcast tree Interconnect-1T00:00:2:0
# ]
# Length parse: 1
# ----------------------------------------
# No. 33
# Length: 8, Nums: 5
# Ground truth  : Targeting domains:node-<*> and nodes:node-[<*>-<*>] child of command <*>
# Parse templs  : ['Targeting domains:<*> and nodes:node-[<*>] child of command <*>']
# Content List: [
# 	Targeting domains:node-D3 and nodes:node-[104-127] child of command 1963
# 	Targeting domains:node-D4 and nodes:node-[136-159] child of command 1964
# 	Targeting domains:node-D4 and nodes:node-[128-135] child of command 2401
# ]
# Length parse: 1
# ----------------------------------------
# No. 36
# Length: 9, Nums: 1
# Ground truth  : ServerFileSystem: An ServerFileSystem domain panic has occurred on <*>
# Parse templs  : ['ServerFileSystem: An ServerFileSystem domain panic has occurred on storage442']
# Content List: [
# 	ServerFileSystem: An ServerFileSystem domain panic has occurred on storage442
# ]
# Length parse: 1
# ----------------------------------------
# No. 39
# Length: 11, Nums: 36
# Ground truth  : ClusterFileSystem: ServerFileSystem domain <*> is no longer served by node node-<*>
# Parse templs  : ['ClusterFileSystem: ServerFileSystem domain <*> is no longer served by node <*>']
# Content List: [
# 	ClusterFileSystem: ServerFileSystem domain cluster_root_backup is no longer served by node node-96
# 	ClusterFileSystem: ServerFileSystem domain root_domain is no longer served by node node-160
# 	ClusterFileSystem: ServerFileSystem domain root3_domain is no longer served by node node-128
# ]
# Length parse: 1
# ----------------------------------------
# No. 40
# Length: 11, Nums: 12
# Ground truth  : Component State Change: Component <*> is in the unavailable state (HWID=<*>)
# Parse templs  : ['Component State Change: Component <*> is in the unavailable state (HWID<*>)']
# Content List: [
# 	Component State Change: Component \042SCSI-WWID:01000010:6005-08b4-0001-00c6-0006-3000-003d-0000\042 is in the unavailable state (HWID=1973)
# 	Component State Change: Component \042alt0\042 is in the unavailable state (HWID=3180)
# 	Component State Change: Component \042alt0\042 is in the unavailable state (HWID=5089)
# ]
# Length parse: 1
# ----------------------------------------
# No. 41
# Length: 14, Nums: 2
# Ground truth  : NIFF: node node-<*> detected a failed network connection on network <*> via interface alt0
# Parse templs  : ['NIFF: node <*> detected a failed network connection on network <*> via interface alt0']
# Content List: [
# 	NIFF: node node-69 detected a failed network connection on network 5.5.224.0 via interface alt0
# 	NIFF: node node-162 detected a failed network connection on network 5.5.224.0 via interface alt0
# ]
# Length parse: 1
# ----------------------------------------
# No. 42
# Length: 14, Nums: 4
# Ground truth  : inconsistent nodesets node-<*> <*> <ok> node-<*> <*> <ok> node-<*> <*> <ok> node-<*> <*> <*>
# Parse templs  : ['inconsistent nodesets <*> <*> <ok> <*> <*> <ok> <*> <*> <ok> <*> <*> <ok>', 'inconsistent nodesets <*> <*> <ok> <*> <*> <ok> <*> <*> <ok> <*> <*> <ok> <*> <*> <ok> <*> <*> <ok> <*> <*> <ok> <*> <*> <ok> <*> <*> <ok> <*> <*> <ok> <*> <*> <ok> <*> <*> <ok> <*> <*> <ok>', 'inconsistent nodesets <*> <*> <ok> <*> <*> <ok> <*> <*> <ok> <*> <*> <ok> <*> <*> <ok>']
# Content List: [
# 	inconsistent nodesets node-160 0x0001edfe <ok> node-161 0x1001fdfe <ok> node-162 0x1001fdfe <ok> node-163 0x1001fdfe <ok>
# 	inconsistent nodesets node-32 0x00000002 <ok> node-34 0x000001fe <ok> node-33 0x000001fe <ok> node-35 0x000001fe <ok>
# 	inconsistent nodesets node-1 0x000001fc <ok> node-2 0x000001fc <ok> node-7 0x000001fc <ok> node-4 0x000001fc <ok> node-6 0x000001fc <ok> node-5 0x000001fc <ok> node-3 0x000001fc <ok> node-14 0x0003fdfc <ok> node-13 0x0003fdfc <ok> node-12 0x0003fdfc <ok> node-10 0x0003fdfc <ok> node-16 0x0003fdfc <ok> node-15 0x0003fdfc <ok>
# ]
# Length parse: 3
# ----------------------------------------
# No. 44
# Length: 15, Nums: 44
# Ground truth  : NIFF: node node-<*> has detected an available network connection on network <*> via interface alt0
# Parse templs  : ['NIFF: node <*> has detected an available network connection on network <*> via interface alt0']
# Content List: [
# 	NIFF: node node-148 has detected an available network connection on network 5.5.226.0 via interface alt0
# 	NIFF: node node-26 has detected an available network connection on network 5.5.226.0 via interface alt0
# 	NIFF: node node-120 has detected an available network connection on network 5.5.226.0 via interface alt0
# ]
# Length parse: 1
# ----------------------------------------
# No. 45
# Length: 15, Nums: 45
# Ground truth  : NIFF: node node-<*> has detected an available network connection on network <*> via interface ee0
# Parse templs  : ['NIFF: node <*> has detected an available network connection on network <*> via interface ee0']
# Content List: [
# 	NIFF: node node-129 has detected an available network connection on network 10.128.0.0 via interface ee0
# 	NIFF: node node-24 has detected an available network connection on network 10.128.0.0 via interface ee0
# 	NIFF: node node-232 has detected an available network connection on network 10.128.0.0 via interface ee0
# ]
# Length parse: 1
# ----------------------------------------
# No. 46
# Length: 15, Nums: 2
# Ground truth  : NIFF: node node-<*> has detected an available network connection on network <*> via interface scip0
# Parse templs  : ['NIFF: node <*> has detected an available network connection on network <*> via interface scip0']
# Content List: [
# 	NIFF: node node-130 has detected an available network connection on network 10.96.0.0 via interface scip0
# 	NIFF: node node-144 has detected an available network connection on network 10.96.0.0 via interface scip0
# ]
# Length parse: 1
# ----------------------------------------
# Total differences found: 19
# ============================================= END =============================================
#
# ======================================== COMPARE Linux ========================================
# SHAPE: (2000, 10)
# SHAPE PARSER: (2000, 13)
# Num of truth templates: 118
# No. 19
# Length: 3, Nums: 1
# Ground truth  : hcid startup succeeded
# Parse templs  : ['<*> startup succeeded']
# Content List: [
# 	hcid startup succeeded
# ]
# Length parse: 1
# ----------------------------------------
# No. 20
# Length: 3, Nums: 1
# Ground truth  : irqbalance startup succeeded
# Parse templs  : ['<*> startup succeeded']
# Content List: [
# 	irqbalance startup succeeded
# ]
# Length parse: 1
# ----------------------------------------
# No. 22
# Length: 3, Nums: 1
# Ground truth  : klogd startup succeeded
# Parse templs  : ['<*> startup succeeded']
# Content List: [
# 	klogd startup succeeded
# ]
# Length parse: 1
# ----------------------------------------
# No. 24
# Length: 3, Nums: 1
# Ground truth  : portmap startup succeeded
# Parse templs  : ['<*> startup succeeded']
# Content List: [
# 	portmap startup succeeded
# ]
# Length parse: 1
# ----------------------------------------
# No. 25
# Length: 3, Nums: 1
# Ground truth  : rpc.idmapd startup succeeded
# Parse templs  : ['<*> startup succeeded']
# Content List: [
# 	rpc.idmapd startup succeeded
# ]
# Length parse: 1
# ----------------------------------------
# No. 26
# Length: 3, Nums: 1
# Ground truth  : rpc.statd startup succeeded
# Parse templs  : ['<*> startup succeeded']
# Content List: [
# 	rpc.statd startup succeeded
# ]
# Length parse: 1
# ----------------------------------------
# No. 28
# Length: 3, Nums: 1
# Ground truth  : sdpd startup succeeded
# Parse templs  : ['<*> startup succeeded']
# Content List: [
# 	sdpd startup succeeded
# ]
# Length parse: 1
# ----------------------------------------
# No. 29
# Length: 3, Nums: 1
# Ground truth  : syslogd startup succeeded
# Parse templs  : ['<*> startup succeeded']
# Content List: [
# 	syslogd startup succeeded
# ]
# Length parse: 1
# ----------------------------------------
# No. 31
# Length: 4, Nums: 1
# Ground truth  : <*> LOGIN ON tty2
# Parse templs  : ['ROOT LOGIN ON tty2']
# Content List: [
# 	ROOT LOGIN ON tty2
# ]
# Length parse: 1
# ----------------------------------------
# No. 42
# Length: 4, Nums: 1
# Ground truth  : Transparent bridge - <*>
# Parse templs  : ['Transparent bridge - <*>:<*>:<*>']
# Content List: [
# 	Transparent bridge - 0000:00:1e.0
# ]
# Length parse: 1
# ----------------------------------------
# No. 45
# Length: 4, Nums: 4
# Ground truth  : creating device node '<*>'
# Parse templs  : ['creating device node <*>']
# Content List: [
# 	creating device node '/udev/vcs2'
# 	creating device node '/udev/vcsa2'
# 	creating device node '/udev/vcs2'
# ]
# Length parse: 1
# ----------------------------------------
# No. 46
# Length: 4, Nums: 1
# Ground truth  : imps2: Auto-detected intellimouse PS/<*>
# Parse templs  : ['imps2: Auto-detected intellimouse <*>']
# Content List: [
# 	imps2: Auto-detected intellimouse PS/2
# ]
# Length parse: 1
# ----------------------------------------
# No. 47
# Length: 4, Nums: 4
# Ground truth  : removing device node '<*>'
# Parse templs  : ['removing device node <*>']
# Content List: [
# 	removing device node '/udev/vcsa2'
# 	removing device node '/udev/vcs2'
# 	removing device node '/udev/vcs2'
# ]
# Length parse: 1
# ----------------------------------------
# No. 49
# Length: 5, Nums: 3
# Ground truth  : BIOS-e820: <*> - <*> (reserved)
# Parse templs  : ['<*>: <*> - <*> (reserved)']
# Content List: [
# 	BIOS-e820: 00000000000f0000 - 0000000000100000 (reserved)
# 	BIOS-e820: 0000000007eae000 - 0000000008000000 (reserved)
# 	BIOS-e820: 00000000ffb00000 - 0000000100000000 (reserved)
# ]
# Length parse: 1
# ----------------------------------------
# No. 50
# Length: 5, Nums: 2
# Ground truth  : BIOS-e820: <*> - <*> (usable)
# Parse templs  : ['<*>: <*> - <*> (usable)']
# Content List: [
# 	BIOS-e820: 0000000000000000 - 00000000000a0000 (usable)
# 	BIOS-e820: 0000000000100000 - 0000000007eae000 (usable)
# ]
# Length parse: 1
# ----------------------------------------
# No. 68
# Length: 5, Nums: 1
# Ground truth  : mapped 4G/4G trampoline to <*>.
# Parse templs  : ['mapped <*> trampoline to <*>']
# Content List: [
# 	mapped 4G/4G trampoline to ffff3000.
# ]
# Length parse: 1
# ----------------------------------------
# No. 81
# Length: 6, Nums: 909
# Ground truth  : connection from <*> (<*>) at <*>:<*>:<*>
# Parse templs  : ['connection from <*> (<*>) at Fri Jun <*> <*> <*>', 'connection from <*> (<*>) at Sat Jun <*> <*> <*>', 'connection from <*> () at Mon Jun <*> <*> <*>', 'connection from <*> () at Wed Jun <*> <*> <*>', 'connection from <*> () at Fri Jun <*> <*> <*>', 'connection from <*> () at Sat Jun <*> <*> <*>', 'connection from <*> () at Fri Jul <*> <*> <*>', 'connection from <*> (<*>) at Sun Jul <*> <*> <*>', 'connection from <*> (<*>) at Mon Jul <*> <*> <*>', 'connection from <*> () at Tue Jul <*> <*> <*>', 'connection from <*> () at Wed Jul <*> <*> <*>', 'connection from <*> () at Thu Jul <*> <*> <*>', 'connection from <*> () at Sat Jul <*> <*> <*>', 'connection from <*> (host<*>.maximumasp.com) at Sat Jul <*> <*> <*>', 'connection from <*> () at Sun Jul <*> <*> <*>', 'connection from <*> () at Mon Jul <*> <*> <*>']
# Content List: [
# 	connection from 24.54.76.216 (24-54-76-216.bflony.adelphia.net) at Fri Jun 17 07:07:00 2005
# 	connection from 24.54.76.216 (24-54-76-216.bflony.adelphia.net) at Fri Jun 17 07:07:00 2005
# 	connection from 24.54.76.216 (24-54-76-216.bflony.adelphia.net) at Fri Jun 17 07:07:00 2005
# ]
# Length parse: 16
# ----------------------------------------
# No. 86
# Length: 7, Nums: 1
# Ground truth  : Intel machine check reporting enabled on CPU#<*>.
# Parse templs  : ['Intel machine check reporting enabled on CPU#<*>']
# Content List: [
# 	Intel machine check reporting enabled on CPU#0.
# ]
# Length parse: 1
# ----------------------------------------
# No. 87
# Length: 7, Nums: 1
# Ground truth  : Kernel command line: ro <*>=LABEL=/ rhgb quiet
# Parse templs  : ['Kernel command line: ro root=LABEL=/ rhgb quiet']
# Content List: [
# 	Kernel command line: ro root=LABEL=/ rhgb quiet
# ]
# Length parse: 1
# ----------------------------------------
# No. 91
# Length: 7, Nums: 1
# Ground truth  : klogd <*>, log source = <*> started.
# Parse templs  : ['klogd <*>, log source = /proc/kmsg started.']
# Content List: [
# 	klogd 1.4.1, log source = /proc/kmsg started.
# ]
# Length parse: 1
# ----------------------------------------
# No. 94
# Length: 8, Nums: 1
# Ground truth  : PCI: Using IRQ router PIIX/ICH [<*>/<*>] at <*>
# Parse templs  : ['PCI: Using IRQ router PIIX/ICH [<*>] at <*>:<*>:<*>']
# Content List: [
# 	PCI: Using IRQ router PIIX/ICH [8086/2410] at 0000:00:1f.0
# ]
# Length parse: 1
# ----------------------------------------
# No. 95
# Length: 8, Nums: 1
# Ground truth  : authentication failure; logname= uid=<*> euid=<*> tty=:<*> ruser= rhost=
# Parse templs  : ['authentication failure; logname= uid=<*> euid=<*> tty=:<*> ruser= rhost=<*>']
# Content List: [
# 	authentication failure; logname= uid=0 euid=0 tty=:0 ruser= rhost=
# ]
# Length parse: 1
# ----------------------------------------
# No. 108
# Length: 9, Nums: 351
# Ground truth  : authentication failure; logname= uid=<*> euid=<*> tty=NODEVssh ruser= rhost=<*> user=<*>
# Parse templs  : ['authentication failure; logname= uid=<*> euid=<*> tty=NODEVssh ruser= rhost=<*> user=root']
# Content List: [
# 	authentication failure; logname= uid=0 euid=0 tty=NODEVssh ruser= rhost=220-135-151-1.hinet-ip.hinet.net  user=root
# 	authentication failure; logname= uid=0 euid=0 tty=NODEVssh ruser= rhost=220-135-151-1.hinet-ip.hinet.net  user=root
# 	authentication failure; logname= uid=0 euid=0 tty=NODEVssh ruser= rhost=220-135-151-1.hinet-ip.hinet.net  user=root
# ]
# Length parse: 1
# ----------------------------------------
# No. 114
# Length: 10, Nums: 1
# Ground truth  : User unknown timed out after <*> seconds at <*>:<*>:<*> <*>
# Parse templs  : ['User unknown timed out after <*> seconds at Sat Jun <*> <*> <*>']
# Content List: [
# 	User unknown timed out after 900 seconds at Sat Jun 18 02:23:10 2005
# ]
# Length parse: 1
# ----------------------------------------
# No. 118
# Length: 15, Nums: 1
# Ground truth  : Linux version <*> (bhcompile@bugs.build.redhat.com) (gcc version <*> (Red Hat Linux <*>)) #<*> <*>:<*>:<*> EDT <*>
# Parse templs  : ['Linux version <*> (bhcompile@bugs.build.redhat.com) (gcc version <*> <*> (Red Hat Linux <*>)) #<*> Sat May <*> <*> EDT <*>']
# Content List: [
# 	Linux version 2.6.5-1.358 (bhcompile@bugs.build.redhat.com) (gcc version 3.3.3 20040412 (Red Hat Linux 3.3.3-7)) #1 Sat May 8 09:04:50 EDT 2004
# ]
# Length parse: 1
# ----------------------------------------
# Total differences found: 25
# ============================================= END =============================================
#
# ======================================== COMPARE Mac ========================================
# SHAPE: (2000, 11)
# SHAPE PARSER: (2000, 14)
# Num of truth templates: 341
# No. 1
# Length: 1, Nums: 15
# ...
# ]
# Length parse: 1
# ----------------------------------------
# No. 114
# Length: 7, Nums: 1
# Ground truth  : Unknown cmd fd(<*>) cmd(<*>){<*>} arg(<*>) on <*>
# Parse templs  : ['Unknown cmd fd(<*>) cmd(<*>){<*>} arg(<*>) on /dev/sda']
# Content List: [
# 	Unknown cmd fd(5) cmd(80081272){00} arg(ffffda44) on /dev/sda
# ]
# Length parse: 1
# ----------------------------------------
# No. 117
# Length: 7, Nums: 2
# Ground truth  : not allocating divert_blk for non-ethernet device <*>
# Parse templs  : ['not allocating divert_blk for non-ethernet device lo', 'not allocating divert_blk for non-ethernet device sit0']
# Content List: [
# 	not allocating divert_blk for non-ethernet device lo
# 	not allocating divert_blk for non-ethernet device sit0
# ]
# Length parse: 2
# ----------------------------------------
# No. 119
# Length: 7, Nums: 19
# Ground truth  : session opened for user <*> by (uid=<*>)
# Parse templs  : ['session opened for user root by (uid=<*>)']
# Content List: [
# 	session opened for user root by (uid=0)
# 	session opened for user root by (uid=0)
# 	session opened for user root by (uid=0)
# ]
# Length parse: 1
# ----------------------------------------
# No. 120
# Length: 8, Nums: 3
# Ground truth  : DHCPREQUEST for <*> (<*>) from <*> via eth1
# Parse templs  : ['DHCPREQUEST for <*> (<*>) from <*>:<*>:<*>:e3:ba:c3 via eth1']
# Content List: [
# 	DHCPREQUEST for 10.100.4.251 (10.100.0.250) from 00:11:43:e3:ba:c3 via eth1
# 	DHCPREQUEST for 10.100.4.251 (10.100.0.250) from 00:11:43:e3:ba:c3 via eth1
# 	DHCPREQUEST for 10.100.4.251 (10.100.0.250) from 00:11:43:e3:ba:c3 via eth1
# ]
# Length parse: 1
# ----------------------------------------
# No. 131
# Length: 9, Nums: 34
# Ground truth  : Warning: we failed to resolve data source name <*>
# Parse templs  : ['Warning: we failed to resolve data source name an14 an15 an16 an17 an18 an19 an20 an21 an22 an23 an24 an25 an26 an27 an28 an29 an30 an31 an32 an33 an34 an35 an36 an37 an38 an39 an40 an41 an42 an43 an44 an45 an46 an47 an48 an49 an50 an51 an52 an53 an54 an55 an56 an57 an58 an59 an60 an61 an62 an63 an64 an65 an66 an67 an68 an69 an70 an71 an72 an73 an74 an75 an76 an77 an78 an79 an80 an81 an82 an83 an84 an85 an86 an87 an88 an89 an90 an91 an92 an93 an94 an95 an96 an97 an98 an99 an100 an101 an102 an103 an104 an105 an106 an107 an108 an109 an110 an111 an112 an113 an114 an115 an116 an117 an118 an119 an120 an121 an122 an123 an124 an125 an126 an127 an128', 'Warning: we failed to resolve data source name an142 an143 an144 an145 an146 an147 an148 an149 an150 an151 an152 an153 an154 an155 an156 an157 an158 an159 an160 an161 an162 an163 an164 an165 an166 an167 an168 an169 an170 an171 an172 an173 an174 an175 an176 an177 an178 an179 an180 an181 an182 an183 an184 an185 an186 an187 an188 an189 an190 an191 an192 an193 an194 an195 an196 an197 an198 an199 an200 an201 an202 an203 an204 an205 an206 an207 an208 an209 an210 an211 an212 an213 an214 an215 an216 an217 an218 an219 an220 an221 an222 an223 an224 an225 an226 an227 an228 an229 an230 an231 an232 an233 an234 an235 an236 an237 an238 an239 an240 an241 an242 an243 an244 an245 an246 an247 an248 an249 an250 an251 an252 an253 an254 an255 an256', 'Warning: we failed to resolve data source name an270 an271 an272 an273 an274 an275 an276 an277 an278 an279 an280 an281 an282 an283 an284 an285 an286 an287 an288 an289 an290 an291 an292 an293 an294 an295 an296 an297 an298 an299 an300 an301 an302 an303 an304 an305 an306 an307 an308 an309 an310 an311 an312 an313 an314 an315 an316 an317 an318 an319 an320 an321 an322 an323 an324 an325 an326 an327 an328 an329 an330 an331 an332 an333 an334 an335 an336 an337 an338 an339 an340 an341 an342 an343 an344 an345 an346 an347 an348 an349 an350 an351 an352 an353 an354 an355 an356 an357 an358 an359 an360 an361 an362 an363 an364 an365 an366 an367 an368 an369 an370 an371 an372 an373 an374 an375 an376 an377 an378 an379 an380 an381 an382 an383 an384', 'Warning: we failed to resolve data source name an398 an399 an400 an401 an402 an403 an404 an405 an406 an407 an408 an409 an410 an411 an412 an413 an414 an415 an416 an417 an418 an419 an420 an421 an422 an423 an424 an425 an426 an427 an428 an429 an430 an431 an432 an433 an434 an435 an436 an437 an438 an439 an440 an441 an442 an443 an444 an445 an446 an447 an448 an449 an450 an451 an452 an453 an454 an455 an456 an457 an458 an459 an460 an461 an462 an463 an464 an465 an466 an467 an468 an469 an470 an471 an472 an473 an474 an475 an476 an477 an478 an479 an480 an481 an482 an483 an484 an485 an486 an487 an488 an489 an490 an491 an492 an493 an494 an495 an496 an497 an498 an499 an500 an501 an502 an503 an504 an505 an506 an507 an508 an509 an510 an511 an512', 'Warning: we failed to resolve data source name an526 an527 an528 an529 an530 an531 an532 an533 an534 an535 an536 an537 an538 an539 an540 an541 an542 an543 an544 an545 an546 an547 an548 an549 an550 an551 an552 an553 an554 an555 an556 an557 an558 an559 an560 an561 an562 an563 an564 an565 an566 an567 an568 an569 an570 an571 an572 an573 an574 an575 an576 an577 an578 an579 an580 an581 an582 an583 an584 an585 an586 an587 an588 an589 an590 an591 an592 an593 an594 an595 an596 an597 an598 an599 an600 an601 an602 an603 an604 an605 an606 an607 an608 an609 an610 an611 an612 an613 an614 an615 an616 an617 an618 an619 an620 an621 an622 an623 an624 an625 an626 an627 an628 an629 an630 an631 an632 an633 an634 an635 an636 an637 an638 an639 an640', 'Warning: we failed to resolve data source name an654 an655 an656 an657 an658 an659 an660 an661 an662 an663 an664 an665 an666 an667 an668 an669 an670 an671 an672 an673 an674 an675 an676 an677 an678 an679 an680 an681 an682 an683 an684 an685 an686 an687 an688 an689 an690 an691 an692 an693 an694 an695 an696 an697 an698 an699 an700 an701 an702 an703 an704 an705 an706 an7 ...
# Content List: [
# 	Warning: we failed to resolve data source name an14 an15 an16 an17 an18 an19 an20 an21 an22 an23 an24 an25 an26 an27 an28 an29 an30 an31 an32 an33 an34 an35 an36 an37 an38 an39 an40 an41 an42 an43 an44 an45 an46 an47 an48 an49 an50 an51 an52 an53 an54 an55 an56 an57 an58 an59 an60 an61 an62 an63 an64 an65 an66 an67 an68 an69 an70 an71 an72 an73 an74 an75 an76 an77 an78 an79 an80 an81 an82 an83 an84 an85 an86 an87 an88 an89 an90 an91 an92 an93 an94 an95 an96 an97 an98 an99 an100 an101 an102 an103 an104 an105 an106 an107 an108 an109 an110 an111 an112 an113 an114 an115 an116 an117 an118 an119 an120 an121 an122 an123 an124 an125 an126 an127 an128
# 	Warning: we failed to resolve data source name an14 an15 an16 an17 an18 an19 an20 an21 an22 an23 an24 an25 an26 an27 an28 an29 an30 an31 an32 an33 an34 an35 an36 an37 an38 an39 an40 an41 an42 an43 an44 an45 an46 an47 an48 an49 an50 an51 an52 an53 an54 an55 an56 an57 an58 an59 an60 an61 an62 an63 an64 an65 an66 an67 an68 an69 an70 an71 an72 an73 an74 an75 an76 an77 an78 an79 an80 an81 an82 an83 an84 an85 an86 an87 an88 an89 an90 an91 an92 an93 an94 an95 an96 an97 an98 an99 an100 an101 an102 an103 an104 an105 an106 an107 an108 an109 an110 an111 an112 an113 an114 an115 an116 an117 an118 an119 an120 an121 an122 an123 an124 an125 an126 an127 an128
# 	Warning: we failed to resolve data source name an142 an143 an144 an145 an146 an147 an148 an149 an150 an151 an152 an153 an154 an155 an156 an157 an158 an159 an160 an161 an162 an163 an164 an165 an166 an167 an168 an169 an170 an171 an172 an173 an174 an175 an176 an177 an178 an179 an180 an181 an182 an183 an184 an185 an186 an187 an188 an189 an190 an191 an192 an193 an194 an195 an196 an197 an198 an199 an200 an201 an202 an203 an204 an205 an206 an207 an208 an209 an210 an211 an212 an213 an214 an215 an216 an217 an218 an219 an220 an221 an222 an223 an224 an225 an226 an227 an228 an229 an230 an231 an232 an233 an234 an235 an236 an237 an238 an239 an240 an241 an242 an243 an244 an245 an246 an247 an248 an249 an250 an251 an252 an253 an254 an255 an256
# ]
# Length parse: 33
# ----------------------------------------
# No. 132
# Length: 9, Nums: 1
# Ground truth  : Warning: we failed to resolve trusted host name <*>
# Parse templs  : ['Warning: we failed to resolve trusted host name dadmin3 dadmin4']
# Content List: [
# 	Warning: we failed to resolve trusted host name dadmin3 dadmin4
# ]
# Length parse: 1
# ----------------------------------------
# No. 135
# Length: 10, Nums: 15
# Ground truth  : DHCPDISCOVER from <*> via eth1: network A_net: no free leases
# Parse templs  : ['DHCPDISCOVER from <*>:<*>:<*>:e3:ba:c3 via eth1: network A_net: no free leases']
# Content List: [
# 	DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1: network A_net: no free leases
# 	DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1: network A_net: no free leases
# 	DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1: network A_net: no free leases
# ]
# Length parse: 1
# ----------------------------------------
# No. 139
# Length: 11, Nums: 1
# Ground truth  : Cannot open file <*> for writing (No such file or directory)
# Parse templs  : ['Cannot open file /dev/logsurfer for writing (No such file or directory)']
# Content List: [
# 	Cannot open file /dev/logsurfer for writing (No such file or directory)
# ]
# Length parse: 1
# ----------------------------------------
# No. 140
# Length: 11, Nums: 9
# Ground truth  : DHCPREQUEST for <*> (<*>) from <*> via eth1: unknown lease <*>.
# Parse templs  : ['DHCPREQUEST for <*> (<*>) from <*>:<*>:<*>:e3:ba:c3 via eth1: unknown lease <*>.']
# Content List: [
# 	DHCPREQUEST for 10.100.4.251 (10.100.0.250) from 00:11:43:e3:ba:c3 via eth1: unknown lease 10.100.4.251.
# 	DHCPREQUEST for 10.100.4.251 (10.100.0.250) from 00:11:43:e3:ba:c3 via eth1: unknown lease 10.100.4.251.
# 	DHCPREQUEST for 10.100.4.251 (10.100.0.250) from 00:11:43:e3:ba:c3 via eth1: unknown lease 10.100.4.251.
# ]
# Length parse: 1
# ----------------------------------------
# No. 141
# Length: 11, Nums: 11
# Ground truth  : PCI interrupt <*> -> GSI <*> (level, low) -> IRQ <*>
# Parse templs  : ['PCI interrupt <*>:<*>:<*>[A] -> GSI <*> (level, low) -> IRQ <*>']
# Content List: [
# 	PCI interrupt 0000:00:02.0[A] -> GSI 16 (level, low) -> IRQ 169
# 	PCI interrupt 0000:00:04.0[A] -> GSI 16 (level, low) -> IRQ 169
# 	PCI interrupt 0000:00:05.0[A] -> GSI 16 (level, low) -> IRQ 169
# ]
# Length parse: 1
# ----------------------------------------
# No. 142
# Length: 12, Nums: 1
# Ground truth  : Device: <*>, Temperature changed <*> Celsius to <*> Celsius since last report
# Parse templs  : ['Device: /dev/sda, Temperature changed <*> Celsius to <*> Celsius since last report']
# Content List: [
# 	Device: /dev/sda, Temperature changed -2 Celsius to 26 Celsius since last report
# ]
# Length parse: 1
# ----------------------------------------
# No. 145
# Length: 13, Nums: 1
# Ground truth  : PCI Interrupt Link [<*>] (IRQs <*> <*> <*> <*> <*> <*> <*> <*>)
# Parse templs  : ['PCI Interrupt Link [LNKB] (IRQs <*> <*> <*> <*> <*> <*> <*> <*>)']
# Content List: [
# 	PCI Interrupt Link [LNKB] (IRQs 3 4 5 6 7 10 *11 12)
# ]
# Length parse: 1
# ----------------------------------------
# No. 146
# Length: 14, Nums: 2
# Ground truth  : PCI Interrupt Link [<*>] (IRQs <*> <*> <*> <*> <*> <*> <*> <*>) <*>
# Parse templs  : ['PCI Interrupt Link [LNKA] (IRQs <*> <*> <*> <*> <*> <*> <*> <*>) <*>', 'PCI Interrupt Link [LNKC] (IRQs <*> <*> <*> <*> <*> <*> <*> <*>) <*>']
# Content List: [
# 	PCI Interrupt Link [LNKA] (IRQs 3 4 5 6 7 10 11 12) *14
# 	PCI Interrupt Link [LNKC] (IRQs 3 4 5 6 7 10 11 12) *15
# ]
# Length parse: 2
# ----------------------------------------
# No. 148
# Length: 16, Nums: 10
# Ground truth  : <*>: to=<*>, ctladdr=<*> (0/0), delay=<*>:<*>:<*>, xdelay=<*>:<*>:<*>, mailer=relay, pri=<*>, relay=[<*>] [<*>], dsn=<*>, stat=Deferred: Connection refused by [<*>]
# Parse templs  : ['<*>: to=root, ctladdr=root (<*>), delay=<*>:<*>:<*>, xdelay=<*>:<*>:<*>, mailer=relay, pri=<*>, relay=[<*>] [<*>], dsn=<*>, stat=Deferred: Connection refused by [<*>]']
# Content List: [
# 	jA9J1UvC004306: to=root, ctladdr=root (0/0), delay=00:00:01, xdelay=00:00:00, mailer=relay, pri=659060, relay=[127.0.0.1] [127.0.0.1], dsn=4.0.0, stat=Deferred: Connection refused by [127.0.0.1]
# 	jA9J1Wd7019391: to=root, ctladdr=root (0/0), delay=00:00:02, xdelay=00:00:00, mailer=relay, pri=1624553, relay=[127.0.0.1] [127.0.0.1], dsn=4.0.0, stat=Deferred: Connection refused by [127.0.0.1]
# 	jA9J1WSU011176: to=root, ctladdr=root (0/0), delay=00:00:03, xdelay=00:00:00, mailer=relay, pri=1623894, relay=[127.0.0.1] [127.0.0.1], dsn=4.0.0, stat=Deferred: Connection refused by [127.0.0.1]
# ]
# Length parse: 1
# ----------------------------------------
# No. 149
# Length: 19, Nums: 11
# Ground truth  : RRD_update (<*>): illegal attempt to update using time <*> when last update time is <*> (minimum one second step)
# Parse templs  : ['RRD_update (/var/lib/ganglia/rrds/C <*>): illegal attempt to update using time <*> when last update time is <*> (minimum one second step)', 'RRD_update (/var/lib/ganglia/rrds/D <*>): illegal attempt to update using time <*> when last update time is <*> (minimum one second step)', 'RRD_update (<*>): illegal attempt to update using time <*> when last update time is <*> (minimum one second step)']
# Content List: [
# 	RRD_update (/var/lib/ganglia/rrds/C Nodes/cn304/pkts_out.rrd): illegal attempt to update using time 1131563037 when last update time is 1131563037 (minimum one second step)
# 	RRD_update (/var/lib/ganglia/rrds/D Nodes/dn731/pkts_out.rrd): illegal attempt to update using time 1131563089 when last update time is 1131563089 (minimum one second step)
# 	RRD_update (/var/lib/ganglia/rrds/D Nodes/dn731/pkts_out.rrd): illegal attempt to update using time 1131563117 when last update time is 1131563117 (minimum one second step)
# ]
# Length parse: 3
# ----------------------------------------
# Total differences found: 54
# ============================================= END =============================================
#
# ======================================== COMPARE Zookeeper ========================================
# SHAPE: (2000, 10)
# SHAPE PARSER: (2000, 13)
# Num of truth templates: 50
# No. 5
# Length: 2, Nums: 11
# Ground truth  : Server environment:<*>
# Parse templs  : ['Server environment:<*>=<*>', 'Server environment:java.vendor=Oracle Corporation', 'Server environment:zookeeper.version=<*>, built on <*> <*>:<*> GMT', 'Server environment:java.class.path=/etc/zookeeper/conf:/usr/share/java/jline.jar:<*>:/usr/share/java/xercesImpl.jar:/usr/share/java/xmlParserAPIs.jar:/usr/share/java/netty.jar:<*>:<*>:/usr/share/java/zookeeper.jar']
# Content List: [
# 	Server environment:user.dir=/
# 	Server environment:host.name=mesos-master-1
# 	Server environment:java.vendor=Oracle Corporation
# ]
# Length parse: 4
# ----------------------------------------
# No. 23
# Length: 5, Nums: 1
# Ground truth  : My election bind port: <*>/<*>:<*>
# Parse templs  : ['My election bind port: <*>:<*>']
# Content List: [
# 	My election bind port: 0.0.0.0/0.0.0.0:3888
# ]
# Length parse: 1
# ----------------------------------------
# No. 31
# Length: 8, Nums: 41
# Ground truth  : Client attempting to establish new session at <*>:<*>
# Parse templs  : ['Client attempting to establish new <*> at <*>:<*>']
# Content List: [
# 	Client attempting to establish new session at /10.10.34.19:33425
# 	Client attempting to establish new session at /10.10.34.11:50286
# 	Client attempting to establish new session at /10.10.34.11:50301
# ]
# Length parse: 1
# ----------------------------------------
# No. 50
# Length: 18, Nums: 1
# Ground truth  : Got user-level KeeperException when processing sessionid:<*> type:create cxid:<*> zxid:<*> txntype:<*> reqpath:<*> Error Path:<*> Error:KeeperErrorCode = NodeExists for <*>
# Parse templs  : ['Got user-level KeeperException when processing sessionid:<*> type:create cxid:<*> zxid:<*> txntype:<*> reqpath:n/a Error Path:/home/curi/.zookeeper Error:KeeperErrorCode = NodeExists for /home/curi/.zookeeper']
# Content List: [
# 	Got user-level KeeperException when processing sessionid:0x34ed93485090001 type:create cxid:0x55b8bb0f zxid:0x100000010 txntype:-1 reqpath:n/a Error Path:/home/curi/.zookeeper Error:KeeperErrorCode = NodeExists for /home/curi/.zookeeper
# ]
# Length parse: 1
# ----------------------------------------
# Total differences found: 4
# ============================================= END =============================================
