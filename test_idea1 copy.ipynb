# %% [markdown]
# #### **0. CHUẨN BỊ**
#
# ##### **0.1. CẤU HÌNH CÁC THAM SỐ**

# %%
import re
import sys
sys.path.append('../')
import os
import pandas as pd
from collections import Counter, defaultdict
import datetime
from tqdm import tqdm
import string
from copy import deepcopy

pd.set_option('display.max_rows', None)

SETTING_PARAMS = {
    'Apache': {
        'log_file': './logs/Apache/Apache_full.log',
        'log_template': './logs/Apache/Apache_full.log_templates.csv',
        'log_structure': './logs/Apache/Apache_full.log_structured.csv',
        'log_format': '\[<Time>\] \[<Level>\] <Content>',
        'filters': [],
        'regexs': [r'\/(?:\w+\/){2,}\w+\.\w+$'],    
    },
    'HealthApp':{
        'log_file': './logs/HealthApp/HealthApp_full.log',
        'log_template': './logs/HealthApp/HealthApp_full.log_templates.csv',
        'log_structure': './logs/HealthApp/HealthApp_full.log_structured.csv',
        'log_format': '<Time>\|<Component>\|<Pid>\|<Content>',
        'filters': [],
        'regexs': [],  
    },
    'Mac': {
        'log_file': './logs/Mac/Mac_full.log',
        'log_template': './logs/Mac/Mac_full.log_templates.csv',
        'log_structure': './logs/Mac/Mac_full.log_structured.csv',
        'log_format': '<Month>  <Date> <Time> <User> <Component>\[<PID>\]( \(<Address>\))?: <Content>',
        'filters': [],
        'regexs': [r'([\w-]+\.){2,}[\w-]+'],  
    },
    'Linux': {
        'log_file': './logs/Linux/Linux_full.log',
        'log_template': './logs/Linux/Linux_full.log_templates.csv',
        'log_structure': './logs/Linux/Linux_full.log_structured.csv',
        'log_format': '<Month> <Date> <Time> <Level> <Component>(\[<PID>\])?: <Content>',
        'filters': [],
        'regexs': [r'(\d+\.){3}\d+', r'\d{2}:\d{2}:\d{2}'],  
    },
    'OpenSSH': {
        'log_file': './logs/OpenSSH/OpenSSH_full.log',
        'log_template': './logs/OpenSSH/OpenSSH_full.log_templates.csv',
        'log_structure': './logs/OpenSSH/OpenSSH_full.log_structured.csv',
        'log_format': '<Date> <Day> <Time> <Component> sshd\[<Pid>\]: <Content>',
        'filters': [],
        'regexs': [r"(\d+):"],    
    },
}

# %% [markdown]
# ##### **0.2. CLASS**

# %%
class LogCluster:
    def __init__(self, keyGroup, logTemplate, tokens, length, logIDL=None, dynamic_tokenL=None, static_tokenL=None):
        self.keyGroup = keyGroup
        self.logTemplate = logTemplate
        self.tokens = tokens
        self.length = length
        self.logIDL = logIDL if logIDL is not None else []
        self.dynamic_tokenL = dynamic_tokenL if dynamic_tokenL is not None else {}
        self.static_tokenL = static_tokenL if static_tokenL is not None else {}
        
    def __str__(self):
        dynamic_str = "Dynamic Tokens: {\n"
        for k, v in self.dynamic_tokenL.items():
            dynamic_str += f"  {k}: {v},\n"
        dynamic_str += "}"
        
        static_str = "Cover Tokens: {\n"
        for k, v in self.static_tokenL.items():
            static_str += f"  {k}: {v},\n"
        static_str += "}"
        return (
            f"Key: {self.keyGroup}\n"
            f"Template: {self.logTemplate}\n"
            f"Tokens: {self.tokens}\n"
            f"Length: {self.length}\n"
            f"Len LogIDs: {len(self.logIDL)}\n"
            f"{dynamic_str}\n"
            f"{static_str}\n"
        )

# %% [markdown]
# #### **1. Các phương thức sử dụng**
#
# ##### **1.1. Read data**
# - **`log_to_dataframe()`**
#
# - **`generate_logformat_regex()`**
#
# - **`load_data()`**

# %%
# =============================== READ DATA =============================== #
def log_to_dataframe(log_file, regex, headers):
    """ Phương thức chuyển đổi file log thành dataframe
    """ 
    log_messages = []
    linecount = 0
    with open(log_file, 'r', encoding="utf8") as fin:
        for line in fin.readlines():
            try:
                match = regex.search(line.strip())
                message = [match.group(header) for header in headers]
                log_messages.append(message)
                linecount += 1
            except Exception as e:
                pass
    logdf = pd.DataFrame(log_messages, columns=headers)
    logdf.insert(0, 'LineId', None)
    logdf['LineId'] = [i + 1 for i in range(linecount)]
    return logdf

def generate_logformat_regex(logformat):
    """ Phương thức tạo regex từ logformat, biểu thức định dạng của một event log: 
    Ex: 'log_format': '<Date> <Time> <Pid> <Level> <Component>: <Content>'
    """
    headers = []
    splitters = re.split(r'(<[^<>]+>)', logformat)
    regex = ''
    for k in range(len(splitters)):
        if k % 2 == 0:
            splitter = re.sub(' +', '\\\s+', splitters[k])
            regex += splitter
        else:
            header = splitters[k].strip('<').strip('>')
            regex += '(?P<%s>.*?)' % header
            headers.append(header)
    regex = re.compile('^' + regex + '$')
    return headers, regex

def load_data(logfile, logformat):
    """ Phương thức trả về một dataframe từ một file log chỉ định
    """
    log_headers, log_regex = generate_logformat_regex(logformat)
    logs_df = log_to_dataframe(logfile, log_regex, log_headers)
    return logs_df

# %% [markdown]
# ##### **1.2. PRE_PROCESSING_0**
# - **`pre0_hasNumbers()`**
# - **`pre0_regexAndFilter()`**
#
# - **`create_special_pattern()`**
# - **`process_line()`**

# %%
# ========================== PRE_PROCESSING_0 ========================== #
def pre0_hasNumbers(s):
    return any(char.isdigit() for char in s)

def pre0_regexAndFilter(line, regexs = [], filters = []):
    for currentFil in filters:
        line = re.sub(currentFil, '', line)
    for currentRex in regexs:
        line = re.sub(currentRex, "<*>", line)
    return line.strip()

# ======================= CÁC PHƯƠNG THỨC BỔ TRỢ ======================= #
def create_special_pattern(dict_special_token):
    """ Tạo biểu thức chính quy cho các từ điển yêu cầu (không phân biệt hoa thường) """
    keywords = '|'.join([re.escape(k) for k in dict_special_token])
    return re.compile(f'({keywords})', flags=re.IGNORECASE)


def process_line(line, regexs, filters, dict_special_token, pattern_special):
    """ Phương thức hỗ trợ xử lý từng dòng log """
    
    # ================== Xử lý regex và filter ================== #
    # tokens0 là list token sau khi tiền xử lý
    # tokens1 là list token sau khi đã xử lý hết
    # groups_token là chuỗi log để nhóm các log chung lại với nhau
    
    parsed = pre0_regexAndFilter(line['Content'], regexs=regexs, filters=filters)
    tokens0 = str(parsed).strip().split()

    tokens1 = []
    groups_token = []
    
    for token in tokens0:
        if token == "<*>":
            tokens1.append("<*>")
        if not pre0_hasNumbers(token) and str(token).lower() not in dict_special_token:
            temp = re.sub(pattern_special, r'\1<*>', token)
            groups_token.append(temp)
            tokens1.append(temp)
        else:
            tokens1.append("<*>")

    return pd.Series({
        # 'ParseTemplate0': parsed,
        # 'Tokens0': tokens0,
        'Tokens1': tokens1,
        'ParseTemplate1': f"{' '.join(groups_token)} : {len(tokens0)}"
    })

# %% [markdown]
# ##### **1.3. PHƯƠNG THỨC HỖ TRỢ NHÓM GROUP**
#
# - **`extractDynamicTok()`**

# %%
def extractDynamicTok(groups, tokens):
    dynamic_tokenL = defaultdict(list)
    split_lines = [row['Content'].strip().split() for _, row in groups.iterrows()]

    for pos, token in enumerate(tokens):
        if "<*>" in token:
            for line in split_lines:
                if pos < len(line):
                    dynamic_tokenL[pos].append(line[pos])
    return dict(dynamic_tokenL)

# %% [markdown]
# ##### **1.4. PREPROCESSING_1**
#
# - **`splitSepToken()`**

# %%
# ========================== PRE_PROCESSING_1 ========================== #

# %% [markdown]
# ##### **1.#. PHƯƠNG THỨC KHÁC**
#
# - **`write_df_to_txt()`**

# %%
def write_df_to_txt(df, filename):
    col_widths = [max(len(str(val)) for val in [col] + df[col].tolist()) for col in df.columns]

    with open(filename, 'w', encoding='utf-8') as f:
        header = '\t'.join(str(col).ljust(width) for col, width in zip(df.columns, col_widths))
        f.write(header + '\n')

        for row in df.itertuples(index=False):
            line = '\t'.join(str(val).ljust(width) for val, width in zip(row, col_widths))
            f.write(line + '\n')
            
def compare_templates(datasets, parse_df):
    structured_df = pd.read_csv(datasets['log_structure']) 
    unique_templates = structured_df['EventTemplate'].unique()
    print(f"SHAPE: {structured_df.shape}")
    print(f"SHAPE PARSER: {parse_df.shape}")
    print(f"Num of templates: {len(unique_templates)}")

    template_compare = {}
    for template in tqdm(unique_templates, total=len(parse_df), desc="Processing templates", unit="rows"):
        arr_index = structured_df[structured_df['EventTemplate'] == template].index.tolist()
        parse_template_series = parse_df.loc[arr_index, 'TemplateProcessing']
        parse_template_unique = parse_template_series.unique().tolist()

        hash_key = hash(template)
        template_compare[hash_key] = {
            'ground_truth': template,
            'parse': parse_template_unique,
            'index': arr_index,
            'length': len(template.strip().split()),
            'nums': len(arr_index)
        }
        
    sorted_items = sorted(
            template_compare.items(),
            key=lambda item: (item[1]['length'], item[1]['ground_truth'])
        )

    num_dif = 0
    for idx, (key, value) in enumerate(sorted_items, 1):
        if len(value['parse']) != 1 or value['parse'][0] != value['ground_truth']:
            num_dif += 1
            print(f"No. {idx}")
            print(f"Length: {value['length']}, Nums: {value['nums']}")
            print(f"Ground truth  : {value['ground_truth']}")
            print(f"Parse templs  : {value['parse']}")
            print(f"Length parse: {len(value['parse'])}")
            print("-" * 40)
    print(f"Total differences found: {num_dif}")

# %% [markdown]
# #### **2. KHUNG LÀM VIỆC CHÍNH**

# %%
import hashlib

# CẤU HÌNH CÁC THAM SỐ:
datasets = SETTING_PARAMS['Mac']
DICT_SPECIAL_TOKEN = ['true', 'false']
PUNCTUATIONL = '(),<>:;{}[]~='

logs_df = load_data(datasets['log_file'], datasets['log_format'])

# ================================ PROCESSING 0 ================================ #
parse_df = logs_df.copy()
parse_df['GroupTemplate'] = ""                                  # Lưu template sử dụng để nhóm
parse_df['GroupTokens'] = [[] for _ in range(len(parse_df))]    # Lưu list token của Group Teplate
parse_df['idxDynamicTok'] = [[] for _ in range(len(parse_df))]  # Lưu vị trí token động
parse_df['DynamicTok'] = [[] for _ in range(len(parse_df))]     # Lưu token động theo vị trí tương ứng
parse_df['DynamicTokList'] = [[] for _ in range(len(parse_df))] # Lưu list token động theo vị trí tương ứng
parse_df['StaticTokList'] = [[] for _ in range(len(parse_df))]  # Lưu list token tĩnh theo vị trí tương ứng
parse_df['StaticTok'] = [[] for _ in range(len(parse_df))]      # Lưu token tĩnh đã phân tích tương ứng
parse_df['TemplateProcessing'] = ""                             # Template cuối cùng sau khi xử lý

# Viết lại phương thức tiền xử lý 1:
def splitSepToken(s, seps):
    """ Tách chuỗi s giữ lại ký tự phân tách trong seps. Trả về None nếu không có ký tự phân tách."""
    pattern = '|'.join(map(re.escape, seps))  
    if not re.search(pattern, s):             
        return None, None, None
    tokens = re.split(f'({pattern})', s)
    sep_token = [tok for tok in tokens if tok]   
    static_tokenL = ["<*>" if pre0_hasNumbers(tok) else tok for tok in sep_token]
    assert(len(static_tokenL) == len(sep_token))
    static_str = mergeSpecialTok("".join(static_tokenL), seps)
        
    return sep_token, static_str, static_tokenL

# Phương thức gộp chuỗi
def mergeSpecialTok(token_str, seps):
    """ Nhận chuỗi string token đã xử lý và danh sách phân tách seps. Dùng regex để lặp lại việc thay thế mẫu: <*> + (kí tự phân tách giống nhau) + <*> => <*> hoặc <*>+... ==> <*>
    """
    sep_pattern = '|'.join(re.escape(sep) for sep in seps)

    prev = None
    while token_str != prev:
        prev = token_str
        
        # Gộp mẫu: <*> + (các ký tự phân tách giống nhau) + <*>
        token_str = re.sub(rf'(<\*>)(({sep_pattern})\3*)(<\*>)', r'<*>', token_str)
        
        # Gộp nhiều <*><*> liên tiếp:
        token_str = re.sub(r'(<\*>)+', r'<*>', token_str)

    return token_str

# Viết lại phương thức xử lý theo từng dòng
def processLine(line, regexs, filters, pattern_special, punctuationL):
    """ Phương thức hỗ trợ xử lý từng dòng log """
    # ================== Xử lý regex và filter ================== #
    # tokens0 là list token sau khi tiền xử lý
    # groups_token là list tokens templates
    
    parsed = pre0_regexAndFilter(line['Content'], regexs=regexs, filters=filters)
    tokens0 = str(parsed).strip().split()

    groups_token = []         
    idx_dynamic_token = []
    dynamic_token = []
    dynamic_tokenL = []
    static_tokenL = []
    static_token = []
    
    for idx_tok, token in enumerate(tokens0):
        # Duyệt qua từng token, xử lý token có giá trị đặc biệt
        # Nếu token không chứa ký tự đặc biệt thì thêm vào groups_token, nếu có thì xử lý tiếp
        temp = pattern_special.sub('<*>', token)
        if not pre0_hasNumbers(temp): 
            groups_token.append(temp)
        else:
            groups_token.append("<*>")
            sep_token, sta_str, static_tokL = splitSepToken(temp, punctuationL)
            if sep_token is not None:
                idx_dynamic_token.append(idx_tok)
                dynamic_token.append(token)
                dynamic_tokenL.append(sep_token) 
                static_token.append(sta_str)
                static_tokenL.append(static_tokL.copy())
    
    # Tạo template chính của phương pháp
    template = groups_token.copy()
    for idx, val in enumerate(idx_dynamic_token):
        val = int(val)
        template[val] = static_token[idx]
    
    groupTem_str = f"{' '.join(groups_token)} : {len(groups_token)}"
    if idx_dynamic_token:
        posa = []
        for item in static_tokenL:
            posa.append(item[0])
        groupTem_str += f" : {' '.join([str(tok) for tok in idx_dynamic_token])} : {' '.join([str(len(item)) for item in static_tokenL])} : {' '.join(posa)}"
    
    return pd.Series({
        'GroupTemplate': hashlib.md5(groupTem_str.encode('utf-8')).hexdigest(),
        'GroupTokens': groups_token,
        'idxDynamicTok': idx_dynamic_token,
        'DynamicTok': dynamic_token, 
        'DynamicTokList': dynamic_tokenL,
        'StaticTokList': static_tokenL,
        'StaticTok': static_token,
        'TemplateProcessing': f"{' '.join(template)} : {len(template)}"
    })


tqdm.pandas(desc="Tiền xử lý giai đoạn 0 và 1")
pattern_special = create_special_pattern(DICT_SPECIAL_TOKEN)
punctuationL = set(PUNCTUATIONL)

results = parse_df.progress_apply(
        lambda row: processLine(row, datasets['regexs'], datasets['filters'], pattern_special, punctuationL),
        axis=1
    )

for col in results.columns:
    parse_df[col] = results[col]

# compare_templates(datasets, parse_df)
# write_df_to_txt(parse_df, 'z_parse_df.txt')
# Out:
# Tiền xử lý giai đoạn 0 và 1: 100%|██████████| 100314/100314 [00:25<00:00, 3883.87it/s]

# %%
# ================================ GROUP LOG ================================ #
N_MERGE = 3

log_clusters_list = []

unique_groups = parse_df.groupby("GroupTemplate")
print(len(unique_groups))

for key, group_val in unique_groups:
    # print("NUMS: ", len(group_val))
    first_row = group_val.iloc[0]
    tokens = first_row['GroupTokens']
    
    if len(first_row["idxDynamicTok"]) != 0:
        group_staticL = group_val['StaticTokList'].to_list()
        # print(len(group_val), len(group_staticL), group_staticL)   
        static_processingL = []
        for idx in range(len(group_staticL[0])):
            cols_idx_gr = list(zip(*[x[idx] for x in group_staticL])) 
            static_idx = []
            for idx0, lst_idx in enumerate(cols_idx_gr): # Lấy các phần tử theo cột của từng token đã được phân tách
                unique_idx = set(lst_idx)
                if len(unique_idx) > 1:
                    static_idx.append("<*>")
                else: 
                    static_idx.append(next(iter(unique_idx)))
            static_processingL.append("".join(static_idx))
    
        # Chuyển group thành các log cluster:
        for idx, val in enumerate(first_row["idxDynamicTok"]):
            tokens[val] = static_processingL[idx]
    
    logTemplate = " ".join(tokens)

    cluster = LogCluster(
        keyGroup= hashlib.md5(logTemplate.encode('utf-8')).hexdigest(),
        logTemplate=logTemplate,
        tokens=tokens,
        length=len(tokens),
        logIDL=group_val.index.tolist(),
        static_tokenL=None
    )
    log_clusters_list.append(cluster)
# Out:
# 907

# %%
# ================================ MERGE TEMPLATE ================================ #
# Sử dụng cấu trúc Drain và cải tiến thêm quy trình, ta giả sử rằng các template là các log đã được tiền xử lý rồi và bây giờ ta đưa vào cây để so sánh độ tương đồng, cũng như ta cải tiến chỗ Drain để giải quyết các template giống nhau chỉ khác ở token đầu tiên

# ===================== EXTEND DRAIN ==================== #
class Node:
    def __init__(self, childD=None, depth=0, digitOrtoken=None):
        if childD is None:
            childD = dict()
        self.childD = childD
        self.depth = depth
        self.digitOrtoken = digitOrtoken
        
        
class DrainTree:
    def __init__(self, depth=4, st=0.5, maxChild=100):
        self.depth = depth - 2
        self.st = st
        self.maxChild = maxChild
        self.rootNode = Node()

    def treeSearch(self, rn, seq):
        retLogClust = None

        seqLen = len(seq)
        if seqLen not in rn.childD:
            return retLogClust

        parentn = rn.childD[seqLen]

        currentDepth = 1
        for token in seq:
            if currentDepth >= self.depth or currentDepth > seqLen:
                break

            if token in parentn.childD:
                parentn = parentn.childD[token]
            elif "<*>" in parentn.childD:
                parentn = parentn.childD["<*>"]
            else:
                return retLogClust
            currentDepth += 1

        logClustL = parentn.childD

        retLogClust = self.fastMatch(logClustL, seq)

        return retLogClust

    def addSeqToPrefixTree(self, rn, logClust):
        seqLen = len(logClust.tokens)
        if seqLen not in rn.childD:
            firtLayerNode = Node(depth=1, digitOrtoken=seqLen)
            rn.childD[seqLen] = firtLayerNode
        else:
            firtLayerNode = rn.childD[seqLen]

        parentn = firtLayerNode

        currentDepth = 1
        for token in logClust.tokens:
            # Add current log cluster to the leaf node
            if currentDepth >= self.depth or currentDepth > seqLen:
                if len(parentn.childD) == 0:
                    parentn.childD = [logClust]
                else:
                    parentn.childD.append(logClust)
                break

            # If token not matched in this layer of existing tree.
            if token not in parentn.childD:
                if "<*>" in parentn.childD:
                    if len(parentn.childD) < self.maxChild:
                        newNode = Node(depth=currentDepth + 1, digitOrtoken=token)
                        parentn.childD[token] = newNode
                        parentn = newNode
                    else:
                        parentn = parentn.childD["<*>"]
                else:
                    if len(parentn.childD) + 1 < self.maxChild:
                        newNode = Node(depth=currentDepth + 1, digitOrtoken=token)
                        parentn.childD[token] = newNode
                        parentn = newNode
                    elif len(parentn.childD) + 1 == self.maxChild:
                        newNode = Node(depth=currentDepth + 1, digitOrtoken="<*>")
                        parentn.childD["<*>"] = newNode
                        parentn = newNode
                    else:
                        parentn = parentn.childD["<*>"]

            # If the token is matched
            else:
                parentn = parentn.childD[token]

            currentDepth += 1
    
    def seqDist(self, seq1, seq2):
        assert len(seq1) == len(seq2)
        simTokens = 0
        numOfPar = 0

        for token1, token2 in zip(seq1, seq2):
            if token1 == "<*>":
                numOfPar += 1
                continue
            if token1 == token2:
                simTokens += 1

        retVal = float(simTokens) / len(seq1)

        return retVal, numOfPar

    def fastMatch(self, logClustL, seq):
        retLogClust = None

        maxSim = -1
        maxNumOfPara = -1
        maxClust = None

        for logClust in logClustL:
            curSim, curNumOfPara = self.seqDist(logClust.tokens, seq)
            if curSim > maxSim or (curSim == maxSim and curNumOfPara > maxNumOfPara):
                maxSim = curSim
                maxNumOfPara = curNumOfPara
                maxClust = logClust

        if maxSim >= self.st:
            retLogClust = maxClust

        return retLogClust

    def getTemplate(self, seq1, seq2):
        assert len(seq1) == len(seq2)
        retVal = []

        i = 0
        for word in seq1:
            if word == seq2[i]:
                retVal.append(word)
            else:
                retVal.append("<*>")

            i += 1

        return retVal
    
    def createTree(self, log_clusters_list):
        rootNode = self.rootNode
        newLogCluL = []

        for idx, log_cluster in enumerate(log_clusters_list):
            matchCluster = self.treeSearch(rootNode, log_cluster.tokens)
            
            # Match no existing log cluster
            if matchCluster is None:
                newLogCluL.append(log_cluster)
                self.addSeqToPrefixTree(rootNode, log_cluster)

            # Merge log cluster:
            else:
                newTemplate = self.getTemplate(log_cluster.tokens, matchCluster.tokens)
                matchCluster.logIDL.extend(log_cluster.logIDL)
                if " ".join(newTemplate) != " ".join(matchCluster.tokens):
                    matchCluster.tokens = newTemplate
        print(len(newLogCluL))
        # for idx in newLogCluL:
        #     print(idx.logTemplate)
        print("MERGE TEMPLATE DONE!")

    
    
    
    def mergeFirstTok(self):
        rootNode = self.rootNode
        
        get_token2L = []
        for length, items in rootNode.childD.items():       # rootNode.childD is dict
            # Truy nhập vào các Node length để lấy các token thứ hai của từng token đầu
            if length == 1:
                continue
            for f_tok, first_tok in items.childD.items():
                mem = [" ".join(val.tokens) for val in first_tok.childD] 
                print(mem)
                
    # def printTree(self, node, dep):
    #     pStr = ""
    #     for i in range(dep):
    #         pStr += "\t"

    #     if node.depth == 0:
    #         pStr += "Root"
    #     elif node.depth == 1:
    #         pStr += "<" + str(node.digitOrtoken) + ">"
    #     else:
    #         pStr += node.digitOrtoken

    #     print(pStr)

    #     if node.depth == self.depth:
    #         return 1
    #     for child in node.childD:
    #         self.printTree(node.childD[child], dep + 1)
        
tree = DrainTree()
tree.createTree(log_clusters_list)
tree.mergeFirstTok()

# %%
nema = log_clusters_list
grouped_by_length = defaultdict(list)
[grouped_by_length[t.length].append(t) for t in nema]
N_MERGE = 2
ST = 0.6

def seqDist(seq1, seq2):
        assert len(seq1) == len(seq2)
        simTokens = 0
        numOfPar = 0

        for token1, token2 in zip(seq1, seq2):
            if token1 == "<*>":
                numOfPar += 1
                continue
            if token1 == token2:
                simTokens += 1

        retVal = float(simTokens) / len(seq1)

        return retVal, numOfPar
    

def fastMatch(seqGroupL, seq):
    choose_group = None
    
    maxSim = -1
    maxNumOfPara = -1
    maxGroup = None

    for gr in seqGroupL:
            curSim, curNumOfPara = seqDist(gr[0].tokens, seq.tokens)
            if curSim > maxSim or (curSim == maxSim and curNumOfPara > maxNumOfPara):
                maxSim = curSim
                maxNumOfPara = curNumOfPara
                maxClust = gr
                
            if maxSim >= ST:
                choose_group = maxClust
    return choose_group
    
    
# Sau khi nhóm, thực hiện merge:
def generalize_group(group):
    """Tạo pattern chung bằng cách đếm số lượng token khác nhau tại mỗi vị trí"""
    mask_positions = set()
    tokensL = [s.tokens for s in group]
    
    for idx, col in enumerate(zip(*tokensL)):
        if len(set(col)) >= N_MERGE:
            mask_positions.add(idx)

    # Tạo pattern chung
    for seq in group:
        seq.tokens = [token if i not in mask_positions else "<*>" for i, token in enumerate(seq.tokens)]
        seq.logTemplate = " ".join(seq.tokens)

    # Gom nhóm lại theo pattern
    pattern_dict = defaultdict(list)
    for seq in group:
        key = tuple(seq.tokens)
        pattern_dict[key].append(seq)

    result = []
    for key, values in pattern_dict.items():
        if len(values) != 1: 
            logIDL = []
            for x in values:
                logIDL.extend(x.logIDL)
            values[0].logIDL = logIDL
        result.append(values[0])
    return result


newClusterGroupsL = []
for length, groups_len in grouped_by_length.items():
    groupsSimTemL = []
    for log_clust in groups_len:
        matched_gr = fastMatch(groupsSimTemL, log_clust)
        if matched_gr is not None:
            matched_gr.append(log_clust)
        else:
            groupsSimTemL.append([log_clust])
    for group in groupsSimTemL:
        if len(group) < N_MERGE:
            newClusterGroupsL.extend(group)
        else:
            refined_groups = generalize_group(group)
            newClusterGroupsL.extend(refined_groups)

print(len(newClusterGroupsL))
df = pd.read_csv(datasets['log_template'])
print(len(df))

sorted_list = sorted(newClusterGroupsL, key=lambda log: (log.length, log.logTemplate))
for e in sorted_list:
    print(e.logTemplate)

# %%
for item in newClusterGroupsL:
    for idx in item.logIDL:
        parse_df['TemplateProcessing'][idx] = item.logTemplate

# %%
compare_templates(datasets, parse_df)
# Out:
# SHAPE: (100314, 4)
# SHAPE PARSER: (100314, 17)
# Num of templates: 626
# Processing templates:   1%|          | 626/100314 [00:02<07:55, 209.81rows/s]
# No. 8
# Length: 1, Nums: 2
# Ground truth  : NSAllowAppKitWeakReferences=<*>
# Parse templs  : ['NSAllowAppKitWeakReferences=YES']
# Length parse: 1
# ----------------------------------------
# No. 18
# Length: 2, Nums: 114
# Ground truth  : AppleActuatorDevice::<*> Entered
# Parse templs  : ['AppleActuatorDevice::stop Entered', 'AppleActuatorDevice::start Entered']
# Length parse: 2
# ----------------------------------------
# No. 19
# Length: 2, Nums: 114
# Ground truth  : AppleActuatorDeviceUserClient::<*> Entered
# Parse templs  : ['AppleActuatorDeviceUserClient::stop Entered', 'AppleActuatorDeviceUserClient::start Entered']
# Length parse: 2
# ----------------------------------------
# No. 38
# Length: 3, Nums: 600
# Ground truth  : <*>::<*>::<*> bssid changed
# Parse templs  : ['<*>::<*>::postMessage bssid changed']
# Length parse: 1
# ----------------------------------------
# No. 47
# Length: 3, Nums: 24
# Ground truth  : DB Path: <*>
# Parse templs  : ['DB Path: /Users/xpc/Library/Containers/<*><*>']
# Length parse: 1
# ----------------------------------------
# No. 51
# Length: 3, Nums: 521
# Ground truth  : IO80211AWDLPeerManager::setAwdlAutoMode Resuming AWDL
# Parse templs  : ['<*>::setAwdlAutoMode Resuming AWDL']
# Length parse: 1
# ----------------------------------------
# No. 56
# Length: 3, Nums: 664
# Ground truth  : KeychainGetICDPStatus: status: <*>
# Parse templs  : ['KeychainGetICDPStatus: status: off']
# Length parse: 1
# ----------------------------------------
# No. 63
# Length: 3, Nums: 15
# Ground truth  : Unrecognized XSSimpleTypeDefinition: <*>
# Parse templs  : ['Unrecognized XSSimpleTypeDefinition: OneOff']
# Length parse: 1
# ----------------------------------------
# No. 64
# Length: 3, Nums: 532
# Ground truth  : Wake reason: <*>
# Parse templs  : ['Wake reason: <*>', 'Wake reason: RTC (Alarm)', 'Wake reason: <*> (Maintenance)', 'Wake reason: EC.SleepTimer (SleepTimer)', 'Wake reason: <*> (User)', 'Wake reason: ARPT (Network)']
# Length parse: 6
# ----------------------------------------
# No. 68
# Length: 3, Nums: 1
# Ground truth  : deny(<*>) file-read-data <*>
# Parse templs  : ['deny(<*>) file-read-data /private/etc/hosts']
# Length parse: 1
# ----------------------------------------
# No. 72
# Length: 3, Nums: 1
# Ground truth  : moduleFromLegacyDefaults: <ScreenSaverDefaults: <*>
# Parse templs  : ['moduleFromLegacyDefaults: <ScreenSaverDefaults: <*>>']
# Length parse: 1
# ----------------------------------------
# No. 77
# Length: 4, Nums: 31
# Ground truth  : -[ABAddressBook save] failed. (<*>)
# Parse templs  : ['-[ABAddressBook save] failed. (<ABAddressBook: <*>>)']
# Length parse: 1
# ----------------------------------------
# No. 80
# Length: 4, Nums: 135
# Ground truth  : <*>(<*>) deny mach-lookup <*>
# Parse templs  : ['QQ(<*>) deny mach-lookup <*>', '<*>(<*>) deny mach-lookup <*>']
# Length parse: 2
# ----------------------------------------
# No. 81
# Length: 4, Nums: 1245
# Ground truth  : <*>(<*>) deny network-outbound <*>
# Parse templs  : ['<*>(<*>) deny network-outbound /private/var/run/mDNSResponder']
# Length parse: 1
# ----------------------------------------
# No. 83
# Length: 4, Nums: 445
# Ground truth  : <*>: Supported channels <*>
# Parse templs  : ['<*>: Supported channels <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*>', '<*>: Supported channels <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*>']
# Length parse: 2
# ----------------------------------------
# No. 86
# Length: 4, Nums: 1063
# Ground truth  : ARPT: <*>: AirPort_Brcm43xx::platformWoWEnable: WWEN[<*>]
# Parse templs  : ['ARPT: <*>: <*>::platformWoWEnable: WWEN[enable]', 'ARPT: <*>: <*>::platformWoWEnable: WWEN[disable]']
# Length parse: 2
# ----------------------------------------
# No. 87
# Length: 4, Nums: 532
# Ground truth  : ARPT: <*>: AirPort_Brcm43xx::syncPowerState: WWEN[<*>]
# Parse templs  : ['ARPT: <*>: <*>::syncPowerState: <*>']
# Length parse: 1
# ----------------------------------------
# No. 95
# Length: 4, Nums: 114
# Ground truth  : Error: [<*>][<*>]Couldn't copy BD_ADDR
# Parse templs  : ["Error: [<*>][_setEventService:]Couldn't copy BD_ADDR"]
# Length parse: 1
# ----------------------------------------
# No. 98
# Length: 4, Nums: 535
# Ground truth  : IO80211AWDLPeerManager::setAwdlSuspendedMode() Suspending AWDL, enterQuietMode(<*>)
# Parse templs  : ['<*>::setAwdlSuspendedMode() Suspending AWDL, enterQuietMode(<*>)']
# Length parse: 1
# ----------------------------------------
# No. 105
# Length: 4, Nums: 1
# Ground truth  : QuickLookUIHelpe(<*>) deny file-read-data <*>
# Parse templs  : ['QuickLookUIHelpe(<*>) deny file-read-data /private/var/vm/sleepimage']
# Length parse: 1
# ----------------------------------------
# No. 107
# Length: 4, Nums: 2
# Ground truth  : Removing excessive log: <*>
# Parse templs  : ['Removing excessive log: file:///Library/Logs/DiagnosticReports/<*>']
# Length parse: 1
# ----------------------------------------
# No. 108
# Length: 4, Nums: 7
# Ground truth  : Running daily periodic task.
# Parse templs  : ['Running <*> periodic task.']
# Length parse: 1
# ----------------------------------------
# No. 109
# Length: 4, Nums: 1
# Ground truth  : Running weekly periodic task.
# Parse templs  : ['Running <*> periodic task.']
# Length parse: 1
# ----------------------------------------
# No. 110
# Length: 4, Nums: 6
# Ground truth  : SpotlightNetHelp(<*>) deny ipc-posix-shm-read-data <*>:
# Parse templs  : ['SpotlightNetHelp(<*>) deny ipc-posix-shm-read-data CFPBS:<*>:']
# Length parse: 1
# ----------------------------------------
# No. 112
# Length: 4, Nums: 8
# Ground truth  : UNINSTALLED:<*> <*>(<*>) <*> <*>
# Parse templs  : ['UNINSTALLED:<*> <*>(<*>) <*> /Applications/Skype.app/Contents/PlugIns/<*>']
# Length parse: 1
# ----------------------------------------
# No. 113
# Length: 4, Nums: 355
# Ground truth  : Unrecognized attribute value: <*>
# Parse templs  : ['Unrecognized attribute value: t:AbchPersonItemType']
# Length parse: 1
# ----------------------------------------
# No. 114
# Length: 4, Nums: 29
# Ground truth  : [<*>] (Fig) signalled err=<*>
# Parse templs  : ['[<*>:<*>:<*>] (Fig) signalled err=<*>']
# Length parse: 1
# ----------------------------------------
# No. 115
# Length: 4, Nums: 57
# Ground truth  : [HID] [MT] AppleActuatorHIDEventDriver::start entered
# Parse templs  : ['[HID] [MT] <*> entered']
# Length parse: 1
# ----------------------------------------
# No. 116
# Length: 4, Nums: 57
# Ground truth  : [HID] [MT] AppleMultitouchDevice::start entered
# Parse templs  : ['[HID] [MT] <*> entered']
# Length parse: 1
# ----------------------------------------
# No. 117
# Length: 4, Nums: 57
# Ground truth  : [HID] [MT] AppleMultitouchDevice::stop entered
# Parse templs  : ['[HID] [MT] <*> entered']
# Length parse: 1
# ----------------------------------------
# No. 118
# Length: 4, Nums: 57
# Ground truth  : [HID] [MT] AppleMultitouchDevice::willTerminate entered
# Parse templs  : ['[HID] [MT] <*> entered']
# Length parse: 1
# ----------------------------------------
# No. 119
# Length: 4, Nums: 14
# Ground truth  : com.apple.WebKit(<*>) deny file-read-data <*>
# Parse templs  : ['<*>(<*>) deny file-read-data /private/etc/hosts']
# Length parse: 1
# ----------------------------------------
# No. 120
# Length: 4, Nums: 27
# Ground truth  : extension <*> -> <*>
# Parse templs  : ['extension <*> -> (null)', 'extension <*> -> <*>']
# Length parse: 2
# ----------------------------------------
# No. 122
# Length: 4, Nums: 57
# Ground truth  : hibernate image path: <*>
# Parse templs  : ['hibernate image path: /var/vm/sleepimage']
# Length parse: 1
# ----------------------------------------
# No. 128
# Length: 4, Nums: 1
# Ground truth  : it(<*>) deny(<*>) file-read-data <*>
# Parse templs  : ['it(<*>) deny(<*>) file-read-data /private/etc/hosts']
# Length parse: 1
# ----------------------------------------
# No. 132
# Length: 4, Nums: 356
# Ground truth  : setting hostname to "<*>"
# Parse templs  : ['setting hostname to <*>']
# Length parse: 1
# ----------------------------------------
# No. 139
# Length: 5, Nums: 5
# Ground truth  : -> DNSServiceQueryRecord <*> (PTR) PID[<*>]()
# Parse templs  : ['-> DNSServiceQueryRecord <*> <*> <*>. (PTR) PID[<*>]()']
# Length parse: 1
# ----------------------------------------
# No. 140
# Length: 5, Nums: 1
# Ground truth  : <*> : AirDrop server disabled
# Parse templs  : ['<*>:<*>:<*> : AirDrop server disabled']
# Length parse: 1
# ----------------------------------------
# No. 141
# Length: 5, Nums: 112
# Ground truth  : <*> : BTLE scanning started
# Parse templs  : ['<*>:<*>:<*> : BTLE scanning <*>']
# Length parse: 1
# ----------------------------------------
# No. 142
# Length: 5, Nums: 113
# Ground truth  : <*> : BTLE scanning stopped
# Parse templs  : ['<*>:<*>:<*> : BTLE scanning <*>']
# Length parse: 1
# ----------------------------------------
# No. 143
# Length: 5, Nums: 10
# Ground truth  : <*> : Finished generating hashes
# Parse templs  : ['<*>:<*>:<*> : <*> <*> hashes']
# Length parse: 1
# ----------------------------------------
# No. 144
# Length: 5, Nums: 106
# Ground truth  : <*> : Purged contact hashes
# Parse templs  : ['<*>:<*>:<*> : <*> <*> hashes']
# Length parse: 1
# ----------------------------------------
# No. 145
# Length: 5, Nums: 201
# Ground truth  : <*> : Scanning mode <*>
# Parse templs  : ['<*>:<*>:<*> : Scanning mode Contacts Only']
# Length parse: 1
# ----------------------------------------
# No. 146
# Length: 5, Nums: 10
# Ground truth  : <*> : Started generating hashes
# Parse templs  : ['<*>:<*>:<*> : <*> <*> hashes']
# Length parse: 1
# ----------------------------------------
# No. 147
# Length: 5, Nums: 1118
# Ground truth  : <*>: BSSID changed to <*>
# Parse templs  : ['<*>: <*> changed to <*>']
# Length parse: 1
# ----------------------------------------
# No. 148
# Length: 5, Nums: 1510
# Ground truth  : <*>: channel changed to <*>
# Parse templs  : ['<*>: <*> changed to <*>']
# Length parse: 1
# ----------------------------------------
# No. 149
# Length: 5, Nums: 57
# Ground truth  : <*>: message service is terminated
# Parse templs  : ['AppleActuatorHIDEventDriver: message service is terminated']
# Length parse: 1
# ----------------------------------------
# No. 150
# Length: 5, Nums: 147
# Ground truth  : <IMMacNotificationCenterManager: <*>: DND Enabled: <*>
# Parse templs  : ['<IMMacNotificationCenterManager: <*>>: DND Enabled: <*>']
# Length parse: 1
# ----------------------------------------
# No. 151
# Length: 5, Nums: 147
# Ground truth  : <IMMacNotificationCenterManager: <*>: NC Disabled: <*>
# Parse templs  : ['<IMMacNotificationCenterManager: <*>>: NC Disabled: NO']
# Length parse: 1
# ----------------------------------------
# No. 152
# Length: 5, Nums: 2
# Ground truth  : ARPT: <*>: <*>: <*> failed
# Parse templs  : ['ARPT: <*>: <*>: wl_update_tcpkeep_seq: mDNSOffloadUserClient::GetKeepaliveData failed']
# Length parse: 1
# ----------------------------------------
# No. 153
# Length: 5, Nums: 532
# Ground truth  : ARPT: <*>: AirPort_Brcm43xx::powerChange: System Sleep
# Parse templs  : ['ARPT: <*>: <*>::powerChange: System Sleep']
# Length parse: 1
# ----------------------------------------
# No. 156
# Length: 5, Nums: 532
# Ground truth  : AppleThunderboltNHIType2::waitForOk2Go2Sx - retries = <*>
# Parse templs  : ['<*>::<*> - retries = <*>']
# Length parse: 1
# ----------------------------------------
# No. 157
# Length: 5, Nums: 110
# Ground truth  : CCDataTap::profileRemoved, Owner: <*>, Name: <*>
# Parse templs  : ['<*> Owner: <*>, Name: <*>']
# Length parse: 1
# ----------------------------------------
# No. 158
# Length: 5, Nums: 165
# Ground truth  : CCLogTap::profileRemoved, Owner: <*>, Name: <*>
# Parse templs  : ['<*> Owner: <*>, Name: <*>']
# Length parse: 1
# ----------------------------------------
# No. 160
# Length: 5, Nums: 13
# Ground truth  : CFPasteboardBeginGenerationReturn CFPasteboardBeginGeneration(<*>) : Lock timeout
# Parse templs  : ['CFPasteboardBeginGenerationReturn CFPasteboardBeginGeneration(CFPasteboardRef) : Lock timeout']
# Length parse: 1
# ----------------------------------------
# No. 161
# Length: 5, Nums: 41
# Ground truth  : ChromeExistion main isBrowserDetect = <*>
# Parse templs  : ['ChromeExistion main <*> = <*>']
# Length parse: 1
# ----------------------------------------
# No. 162
# Length: 5, Nums: 41
# Ground truth  : ChromeExistion main isUndetectWebsite = <*>
# Parse templs  : ['ChromeExistion main <*> = <*>']
# Length parse: 1
# ----------------------------------------
# No. 163
# Length: 5, Nums: 41
# Ground truth  : ChromeExistion main isUndetectWithCommand = <*>
# Parse templs  : ['ChromeExistion main <*> = <*>']
# Length parse: 1
# ----------------------------------------
# No. 164
# Length: 5, Nums: 41
# Ground truth  : ChromeExistion main linkUrl = (<*>)
# Parse templs  : ['ChromeExistion main <*> = <*>']
# Length parse: 1
# ----------------------------------------
# No. 165
# Length: 5, Nums: 41
# Ground truth  : ChromeExistion main strSendMsg = {"websitekey":<*>,"commandkey":<*>,"browserkey":<*>}
# Parse templs  : ['ChromeExistion main <*> = <*>']
# Length parse: 1
# ----------------------------------------
# No. 166
# Length: 5, Nums: 5
# Ground truth  : Connected to Dropbox on <*>.
# Parse templs  : ['<*> to Dropbox on <*>']
# Length parse: 1
# ----------------------------------------
# No. 167
# Length: 5, Nums: 5
# Ground truth  : Connecting to Dropbox on '<*>'
# Parse templs  : ['<*> to Dropbox on <*>']
# Length parse: 1
# ----------------------------------------
# No. 169
# Length: 5, Nums: 1
# Ground truth  : DHCP <*>: INIT transmit failed
# Parse templs  : ['DHCP <*>: <*> transmit failed']
# Length parse: 1
# ----------------------------------------
# No. 170
# Length: 5, Nums: 2
# Ground truth  : DHCP <*>: INIT-REBOOT transmit failed
# Parse templs  : ['DHCP <*>: <*> transmit failed']
# Length parse: 1
# ----------------------------------------
# No. 171
# Length: 5, Nums: 679
# Ground truth  : Error returned from iconservicesagent: (<*>)
# Parse templs  : ['Error returned from iconservicesagent: (null)']
# Length parse: 1
# ----------------------------------------
# No. 175
# Length: 5, Nums: 1
# Ground truth  : RTC: Alarm <*>, sleep <*>
# Parse templs  : ['RTC: Alarm <*> <*>:<*>:<*>, sleep <*> <*>:<*>:<*>']
# Length parse: 1
# ----------------------------------------
# No. 176
# Length: 5, Nums: 251
# Ground truth  : RTC: Maintenance <*>, sleep <*>
# Parse templs  : ['RTC: Maintenance <*> <*>:<*>:<*>, sleep <*> <*>:<*>:<*>']
# Length parse: 1
# ----------------------------------------
# No. 179
# Length: 5, Nums: 2
# Ground truth  : Sandbox: QuickLookSatelli(<*>) deny(<*>) file-issue-extension <*>
# Parse templs  : ['Sandbox: <*> deny(<*>) <*> /Users/xpc/Library/Caches/<*>']
# Length parse: 1
# ----------------------------------------
# No. 180
# Length: 5, Nums: 2
# Ground truth  : Sandbox: SpotlightNetHelp(<*>) deny(<*>) file-read-data <*>
# Parse templs  : ['Sandbox: SpotlightNetHelp(<*>) deny(<*>) file-read-data <*> <*>']
# Length parse: 1
# ----------------------------------------
# No. 181
# Length: 5, Nums: 86
# Ground truth  : Sandbox: SpotlightNetHelp(<*>) deny(<*>) ipc-posix-shm-read-data <*>
# Parse templs  : ['Sandbox: SpotlightNetHelp(<*>) deny(<*>) ipc-posix-shm-read-data CFPBS:<*>:']
# Length parse: 1
# ----------------------------------------
# No. 182
# Length: 5, Nums: 12
# Ground truth  : Sandbox: com.apple.Addres(<*>) deny(<*>) mach-lookup <*>
# Parse templs  : ['Sandbox: <*>(<*>) deny(<*>) <*> <*>']
# Length parse: 1
# ----------------------------------------
# No. 183
# Length: 5, Nums: 1659
# Ground truth  : Sandbox: com.apple.Addres(<*>) deny(<*>) network-outbound <*>
# Parse templs  : ['Sandbox: <*>(<*>) deny(<*>) <*> <*>']
# Length parse: 1
# ----------------------------------------
# No. 184
# Length: 5, Nums: 39
# Ground truth  : Sandbox: com.apple.WebKit(<*>) deny(<*>) file-read-data <*>
# Parse templs  : ['<*> <*>(<*>) deny(<*>) file-read-data /private/etc/hosts', 'Sandbox: <*>(<*>) deny(<*>) <*> <*>']
# Length parse: 2
# ----------------------------------------
# No. 185
# Length: 5, Nums: 1
# Ground truth  : Sandbox: com.apple.WebKit(<*>) deny(<*>) ipc-posix-sem SandboxingDetectionTest
# Parse templs  : ['Sandbox: <*>(<*>) deny(<*>) <*> <*>']
# Length parse: 1
# ----------------------------------------
# No. 186
# Length: 5, Nums: 9
# Ground truth  : Sandbox: storeaccountd(<*>) deny(<*>) file-write-create <*>
# Parse templs  : ['Sandbox: <*> deny(<*>) <*> /Users/xpc/Library/Caches/<*>', 'Sandbox: storeaccountd(<*>) deny(<*>) file-write-create /Users/xpc/Library/Caches/<*>/ProductionBag']
# Length parse: 2
# ----------------------------------------
# No. 187
# Length: 5, Nums: 532
# Ground truth  : TBT W (<*>): <*> [<*>]
# Parse templs  : ['TBT W (<*>): <*> [x]']
# Length parse: 1
# ----------------------------------------
# No. 192
# Length: 5, Nums: 185
# Ground truth  : [<*>(<*>)] Failed to read DnsConfig.
# Parse templs  : ['[<*>:WARNING:dns_config_service_posix.cc(<*>)] Failed to read DnsConfig.']
# Length parse: 1
# ----------------------------------------
# No. 195
# Length: 5, Nums: 1
# Ground truth  : box: <*> deny(<*>) file-read-data <*>
# Parse templs  : ['<*> <*>(<*>) deny(<*>) file-read-data /private/etc/hosts']
# Length parse: 1
# ----------------------------------------
# No. 196
# Length: 5, Nums: 117
# Ground truth  : device_generate_desktop_screenshot: authw <*> shield <*>(<*>)
# Parse templs  : ['device_generate_desktop_screenshot: authw <*>(<*>), shield <*>(<*>)']
# Length parse: 1
# ----------------------------------------
# No. 197
# Length: 5, Nums: 84
# Ground truth  : enabling pid=<*> for plug-in <*>
# Parse templs  : ['enabling pid=<*> for plug-in <*>(<*>) <*> <*>']
# Length parse: 1
# ----------------------------------------
# No. 200
# Length: 5, Nums: 180
# Ground truth  : network changed: <*> DNS- Proxy-
# Parse templs  : ['network changed: <*> DNS- Proxy-', 'network changed: <*>(<*>:<*>) <*>(<*>:<*>:<*>:<*>:<*>:<*>:<*>:<*>:<*>) DNS- Proxy-']
# Length parse: 2
# ----------------------------------------
# No. 201
# Length: 5, Nums: 36
# Ground truth  : no sleep images for <*>
# Parse templs  : ['no sleep images for WillPowerOffWithImages']
# Length parse: 1
# ----------------------------------------
# No. 202
# Length: 5, Nums: 2
# Ground truth  : notice USBMuxBonjourDeviceListenerCreate: LOCKDOWN_V2_BONJOUR_SERVICE_NAME is <*>
# Parse templs  : ['notice USBMuxBonjourDeviceListenerCreate: <*> is <*>,<*>']
# Length parse: 1
# ----------------------------------------
# No. 204
# Length: 5, Nums: 3
# Ground truth  : realpath() returned <*> for <*>
# Parse templs  : ['realpath() returned NULL for <*><*>']
# Length parse: 1
# ----------------------------------------
# No. 207
# Length: 6, Nums: 1
# Ground truth  : #<*> [I:AssetCacheLocatorService.queue] found no caching servers
# Parse templs  : ['<*> [I:AssetCacheLocatorService.queue] found no caching servers']
# Length parse: 1
# ----------------------------------------
# No. 208
# Length: 6, Nums: 65
# Ground truth  : (ImportBailout.Error:<*>) Asked to exit for <*>
# Parse templs  : ['(ImportBailout.Error:<*>) Asked to exit for Diskarb']
# Length parse: 1
# ----------------------------------------
# No. 210
# Length: 6, Nums: 4
# Ground truth  : -> DNSServiceGetAddrInfo <*> v4v6 <*>. PID[<*>]()
# Parse templs  : ['-> DNSServiceGetAddrInfo <*> <*> <*> <*>. PID[<*>]()']
# Length parse: 1
# ----------------------------------------
# No. 212
# Length: 6, Nums: 1
# Ground truth  : <*> : <*> server idle timeout
# Parse templs  : ['<*>:<*>:<*> : AirDrop server idle timeout']
# Length parse: 1
# ----------------------------------------
# No. 213
# Length: 6, Nums: 10
# Ground truth  : <*> : Adding my hashes manually
# Parse templs  : ['<*>:<*>:<*> : Adding my hashes manually']
# Length parse: 1
# ----------------------------------------
# No. 214
# Length: 6, Nums: 528
# Ground truth  : <*> : BTLE scanner Powered <*>
# Parse templs  : ['<*>:<*>:<*> : BTLE scanner Powered <*>']
# Length parse: 1
# ----------------------------------------
# No. 215
# Length: 6, Nums: 1
# Ground truth  : <*> : Bonjour advertise <*> started
# Parse templs  : ['<*>:<*>:<*> : Bonjour advertise <*> started']
# Length parse: 1
# ----------------------------------------
# No. 216
# Length: 6, Nums: 1
# Ground truth  : <*> : Terminate AirDrop P2P link
# Parse templs  : ['<*>:<*>:<*> : Terminate AirDrop <*> link']
# Length parse: 1
# ----------------------------------------
# No. 217
# Length: 6, Nums: 11
# Ground truth  : <*> <*> AM [AirPlayUIAgent] BecomingInactive: NSWorkspaceWillSleepNotification
# Parse templs  : ['<*> <*>:<*>:<*> <*> [AirPlayUIAgent] BecomingInactive: NSWorkspaceWillSleepNotification']
# Length parse: 1
# ----------------------------------------
# No. 218
# Length: 6, Nums: 29
# Ground truth  : <*> <*> PM [AirPlayUIAgent] BecomingInactive: NSWorkspaceWillSleepNotification
# Parse templs  : ['<*> <*>:<*>:<*> <*> [AirPlayUIAgent] BecomingInactive: NSWorkspaceWillSleepNotification']
# Length parse: 1
# ----------------------------------------
# No. 226
# Length: 6, Nums: 35
# Ground truth  : Central manager is not powered on
# Parse templs  : ['<*> manager is not powered on']
# Length parse: 1
# ----------------------------------------
# No. 228
# Length: 6, Nums: 4
# Ground truth  : Finder(<*>) System Policy: deny file-write-create <*>
# Parse templs  : ['Finder(<*>) System Policy: deny file-write-create /Volumes/Recovery <*>']
# Length parse: 1
# ----------------------------------------
# No. 232
# Length: 6, Nums: 8
# Ground truth  : INSTALLED:<*> <*>(<*>) <__NSConcreteUUID <*> <*> <*>
# Parse templs  : ['INSTALLED:<*> <*>(<*>) <__NSConcreteUUID <*>> <*> /Applications/Skype.app/Contents/PlugIns/<*>']
# Length parse: 1
# ----------------------------------------
# No. 233
# Length: 6, Nums: 2
# Ground truth  : LSCopyApplicationURLsForBundleIdentifier error:Error Domain=<*> Code=<*> "kLSApplicationNotFoundErr: <*>"
# Parse templs  : ['LSCopyApplicationURLsForBundleIdentifier error:Error Domain=NSOSStatusErrorDomain Code=<*> "kLSApplicationNotFoundErr: E.g. no application claims the file"']
# Length parse: 1
# ----------------------------------------
# No. 234
# Length: 6, Nums: 1
# Ground truth  : MessageTracer: load_domain_prefix_whitelist:<*>: Opening whitelist file: <*>
# Parse templs  : ['MessageTracer: load_domain_prefix_whitelist:<*>: Opening whitelist file: /Library/Application Support/CrashReporter/SubmitDiagInfo.domains']
# Length parse: 1
# ----------------------------------------
# No. 238
# Length: 6, Nums: 147
# Ground truth  : Peripheral manager is not powered on
# Parse templs  : ['<*> manager is not powered on']
# Length parse: 1
# ----------------------------------------
# No. 239
# Length: 6, Nums: 1
# Ground truth  : Returning cached encoded userInfo (<*> <*>)
# Parse templs  : ['Returning cached encoded userInfo (UAUserActivity.m <*>)']
# Length parse: 1
# ----------------------------------------
# No. 240
# Length: 6, Nums: 1
# Ground truth  : Sandbox: com.apple.WebKit(<*>) Sandbox: deny(<*>) <*> <*>
# Parse templs  : ['Sandbox: <*>(<*>) Sandbox: deny(<*>) .apple.WfileebK-read-data /private/etc/hosts']
# Length parse: 1
# ----------------------------------------
# No. 247
# Length: 6, Nums: 3
# Ground truth  : [bootp_transmit.c:<*>] bootp_transmit(): bpf_write(<*>) failed: <*> (<*>)
# Parse templs  : ['[bootp_transmit.c:<*>] bootp_transmit(): bpf_write(<*>) failed: Network is down (<*>)']
# Length parse: 1
# ----------------------------------------
# No. 251
# Length: 6, Nums: 57
# Ground truth  : hibernate_rebuild completed - took <*> msecs
# Parse templs  : ['<*> completed - took <*> msecs']
# Length parse: 1
# ----------------------------------------
# No. 253
# Length: 6, Nums: 22
# Ground truth  : network changed: <*> DNS Proxy SMB
# Parse templs  : ['network changed: <*>(<*>:<*>) <*>(<*>:<*>:<*>:<*>:<*>:<*>:<*>:<*>:<*>) <*> Proxy SMB', 'network changed: <*> <*> Proxy SMB']
# Length parse: 2
# ----------------------------------------
# No. 254
# Length: 6, Nums: 374
# Ground truth  : network changed: <*> DNS! Proxy SMB
# Parse templs  : ['network changed: <*>(<*>:<*>) <*>(<*>:<*>:<*>:<*>:<*>:<*>:<*>:<*>:<*>) <*> Proxy SMB', 'network changed: <*> <*> Proxy SMB']
# Length parse: 2
# ----------------------------------------
# No. 255
# Length: 6, Nums: 181
# Ground truth  : network changed: <*> DNS+ Proxy+ SMB
# Parse templs  : ['network changed: <*>(<*>:<*>) DNS+ Proxy+ SMB', 'network changed: <*>(<*>:<*>:<*>:<*>:<*>:<*>:<*>:fecd:<*>) DNS+ Proxy+ SMB', 'network changed: <*>(<*>:<*>) <*>(<*>:<*>:<*>:<*>:<*>:<*>:<*>:fecd:<*>) DNS+ Proxy+ SMB']
# Length parse: 3
# ----------------------------------------
# No. 256
# Length: 6, Nums: 1
# Ground truth  : network changed: <*>(<*>) DNS* Proxy SMB
# Parse templs  : ['network changed: <*> <*> Proxy SMB']
# Length parse: 1
# ----------------------------------------
# No. 257
# Length: 6, Nums: 1
# Ground truth  : network changed: <*>(<*>) DNS- Proxy SMB
# Parse templs  : ['network changed: <*> <*> Proxy SMB']
# Length parse: 1
# ----------------------------------------
# No. 259
# Length: 6, Nums: 6
# Ground truth  : vm_compressor_fastwake_warmup completed - took <*> msecs
# Parse templs  : ['<*> completed - took <*> msecs']
# Length parse: 1
# ----------------------------------------
# No. 260
# Length: 6, Nums: 57
# Ground truth  : vm_compressor_flush completed - took <*> msecs
# Parse templs  : ['<*> completed - took <*> msecs']
# Length parse: 1
# ----------------------------------------
# No. 261
# Length: 7, Nums: 1
# Ground truth  : *** Assertion failure in +[LUTextAccessor rangeOfTermInString:containingOffset:language:partOfSpeech:], <*>
# Parse templs  : ['*** Assertion failure in +[LUTextAccessor rangeOfTermInString:containingOffset:language:partOfSpeech:], /Library/Caches/<*><*>:<*>']
# Length parse: 1
# ----------------------------------------
# No. 262
# Length: 7, Nums: 103
# Ground truth  : <*> : Discoverable mode changed to Off
# Parse templs  : ['<*>:<*>:<*> : Discoverable mode changed to Off']
# Length parse: 1
# ----------------------------------------
# No. 263
# Length: 7, Nums: 6
# Ground truth  : <*> : Hash <*> exists in contacts
# Parse templs  : ['<*>:<*>:<*> : Hash <<*> <*> <*>> exists in contacts']
# Length parse: 1
# ----------------------------------------
# No. 266
# Length: 7, Nums: 147
# Ground truth  : <IMMacNotificationCenterManager: <*>: Updating enabled: <*> (Topics: (
# Parse templs  : ['<IMMacNotificationCenterManager: <*>>: Updating enabled: <*> (Topics: (']
# Length parse: 1
# ----------------------------------------
# No. 270
# Length: 7, Nums: 2
# Ground truth  : Arranged view frame: {{<*>, <*>}, {<*>, <*>}}
# Parse templs  : ['<*> view <*> {{<*>, <*>}, {<*>, <*>}}']
# Length parse: 1
# ----------------------------------------
# No. 272
# Length: 7, Nums: 3
# Ground truth  : CoreAnimation: failed to receive fence reply: <*>
# Parse templs  : ['CoreAnimation: failed to <*> fence reply: <*>']
# Length parse: 1
# ----------------------------------------
# No. 273
# Length: 7, Nums: 2
# Ground truth  : CoreAnimation: failed to send fence reply: <*>
# Parse templs  : ['CoreAnimation: failed to <*> fence reply: <*>']
# Length parse: 1
# ----------------------------------------
# No. 274
# Length: 7, Nums: 24
# Ground truth  : DB Error: <*> "no such table: <*>"
# Parse templs  : ['DB Error: <*> "no such table: <*>']
# Length parse: 1
# ----------------------------------------
# No. 276
# Length: 7, Nums: 5
# Ground truth  : Logging disabled completely for device:<*>: <*> <*>
# Parse templs  : ['Logging disabled completely for device:<*>: /Volumes/Recovery HD']
# Length parse: 1
# ----------------------------------------
# No. 277
# Length: 7, Nums: 1
# Ground truth  : Lookup: Unhandled exception <*> caught in -[<*>]
# Parse templs  : ["Lookup: Unhandled exception 'NSInternalInconsistencyException' caught in -[LULookupDefinitionModule lookupAnimationControllerForString:range:options:originProvider:inView:]"]
# Length parse: 1
# ----------------------------------------
# No. 278
# Length: 7, Nums: 685
# Ground truth  : PM response took <*> ms (<*>, <*>)
# Parse templs  : ['PM response took <*> ms (<*>, <*>']
# Length parse: 1
# ----------------------------------------
# No. 280
# Length: 7, Nums: 1
# Ground truth  : SSaandbox:ndb ox: <*>(bKit(<*>) ) ddeennyy((<*>)) fifleile-re-raedad--ddaattaa <*>
# Parse templs  : ['SSaandbox:ndb ox: <*>(bKit(<*>) ) ddeennyy((<*>)) fifleile-re-raedad--ddaattaa /p/pririvavatte/ee/ettcc/h/hostosts']
# Length parse: 1
# ----------------------------------------
# No. 281
# Length: 7, Nums: 1
# Ground truth  : Sandbox: Finder(<*>) System Policy: deny(<*>) file-write-create <*>
# Parse templs  : ['Sandbox: Finder(<*>) System Policy: deny(<*>) file-write-create /Volumes/Recovery <*>']
# Length parse: 1
# ----------------------------------------
# No. 282
# Length: 7, Nums: 1
# Ground truth  : Sandbox: com.apple.Sandbox: WebKit(<*>) plede.WebKny(<*>)i file-reat(<*> <*>) <*>
# Parse templs  : ['Sandbox: <*>: WebKit(<*>) plede.WebKny(<*>)i file-reat(<*> <*>) ate/etc/hosts']
# Length parse: 1
# ----------------------------------------
# No. 284
# Length: 7, Nums: 388
# Ground truth  : Setting BTCoex Config: enable_2G:<*>, profile_2g:<*>, enable_5G:<*>, profile_5G:<*>
# Parse templs  : ['Setting BTCoex Config: <*>:<*>, <*>:<*>, <*>:<*>, <*>:<*>']
# Length parse: 1
# ----------------------------------------
# No. 285
# Length: 7, Nums: 1
# Ground truth  : Split view bounds: {{<*>, <*>}, {<*>, <*>}}
# Parse templs  : ['<*> view <*> {{<*>, <*>}, {<*>, <*>}}']
# Length parse: 1
# ----------------------------------------
# No. 286
# Length: 7, Nums: 2
# Ground truth  : Unknown class <*> in Interface Builder file.
# Parse templs  : ['Unknown class GPUTesselationSliderCell in Interface Builder file.']
# Length parse: 1
# ----------------------------------------
# No. 289
# Length: 7, Nums: 9
# Ground truth  : [CardDAVPlugin-ERROR] -getPrincipalInfo:[_controller <*> Error Domain=<*> Code=<*> "(<*>)"
# Parse templs  : ['[CardDAVPlugin-ERROR] -getPrincipalInfo:[_controller <*> Error Domain=CoreDAVErrorDomain Code=<*> "(null)"']
# Length parse: 1
# ----------------------------------------
# No. 290
# Length: 7, Nums: 17
# Ground truth  : [HID] [ATC] AppleDeviceManagementHIDEventService::processWakeReason Wake reason: Button (<*>)
# Parse templs  : ['[HID] [ATC] AppleDeviceManagementHIDEventService::processWakeReason Wake reason: <*> (<*>)']
# Length parse: 1
# ----------------------------------------
# No. 291
# Length: 7, Nums: 572
# Ground truth  : [HID] [ATC] AppleDeviceManagementHIDEventService::processWakeReason Wake reason: Host (<*>)
# Parse templs  : ['[HID] [ATC] AppleDeviceManagementHIDEventService::processWakeReason Wake reason: <*> (<*>)']
# Length parse: 1
# ----------------------------------------
# No. 294
# Length: 7, Nums: 419
# Ground truth  : doSaveChannels@<*>: Will write to: <*> - <*>
# Parse templs  : ['<*>: Will write to: /Library/Logs/CrashReporter/CoreCapture/IOReporters/[<*>,<*>,<*>] - <*>']
# Length parse: 1
# ----------------------------------------
# No. 295
# Length: 7, Nums: 15
# Ground truth  : full wake promotion (reason <*>) <*> ms
# Parse templs  : ['full wake <*> (reason <*>) <*> ms']
# Length parse: 1
# ----------------------------------------
# No. 296
# Length: 7, Nums: 46
# Ground truth  : full wake request (reason <*>) <*> ms
# Parse templs  : ['full wake <*> (reason <*>) <*> ms']
# Length parse: 1
# ----------------------------------------
# No. 301
# Length: 7, Nums: 715
# Ground truth  : in6_unlink_ifa: IPv6 address <*> has no prefix
# Parse templs  : ['<*>: <*> address <*> has no prefix']
# Length parse: 1
# ----------------------------------------
# No. 302
# Length: 7, Nums: 185
# Ground truth  : mDNS_DeregisterInterface: Frequent transitions for interface <*> (<*>)
# Parse templs  : ['mDNS_DeregisterInterface: Frequent transitions for interface <*> <*>']
# Length parse: 1
# ----------------------------------------
# No. 303
# Length: 7, Nums: 318
# Ground truth  : mDNS_RegisterInterface: Frequent transitions for interface <*> (<*>)
# Parse templs  : ['mDNS_RegisterInterface: Frequent transitions for interface <*> <*>']
# Length parse: 1
# ----------------------------------------
# No. 305
# Length: 7, Nums: 3
# Ground truth  : tcp_connection_get_statistics called with <*> connection, dumping backtrace:
# Parse templs  : ['tcp_connection_get_statistics called with null connection, dumping backtrace:']
# Length parse: 1
# ----------------------------------------
# No. 308
# Length: 8, Nums: 1
# Ground truth  : <*> : AirDrop server enabled on port <*>
# Parse templs  : ['<*>:<*>:<*> : AirDrop server enabled on port <*>']
# Length parse: 1
# ----------------------------------------
# No. 309
# Length: 8, Nums: 13
# Ground truth  : <*> : BTLE discovered device with hash <*>
# Parse templs  : ['<*>:<*>:<*> : BTLE discovered device with hash <<*> <*> <*>>']
# Length parse: 1
# ----------------------------------------
# No. 310
# Length: 8, Nums: 105
# Ground truth  : <*> : Discoverable mode changed to Contacts Only
# Parse templs  : ['<*>:<*>:<*> : Discoverable mode changed to Contacts Only']
# Length parse: 1
# ----------------------------------------
# No. 311
# Length: 8, Nums: 40
# Ground truth  : <*> <*> ksfetch[<*>] [lvl=<*>] main() Fetcher is exiting.
# Parse templs  : ['<*> <*>:<*>:<*> ksfetch[<*>] [lvl=<*>] main() Fetcher is exiting.']
# Length parse: 1
# ----------------------------------------
# No. 312
# Length: 8, Nums: 40
# Ground truth  : <*> <*> ksfetch[<*>] [lvl=<*>] main() ksfetch done fetching.
# Parse templs  : ['<*> <*>:<*>:<*> ksfetch[<*>] [lvl=<*>] main() ksfetch done fetching.']
# Length parse: 1
# ----------------------------------------
# No. 317
# Length: 8, Nums: 531
# Ground truth  : ARPT: <*>: <*>: leaveModulePoweredForOffloads: Wi-Fi will stay on.
# Parse templs  : ['ARPT: <*>: <*>: leaveModulePoweredForOffloads: Wi-Fi will <*> <*>']
# Length parse: 1
# ----------------------------------------
# No. 318
# Length: 8, Nums: 1
# Ground truth  : ARPT: <*>: <*>: leaveModulePoweredForOffloads: Wi-Fi will turn off.
# Parse templs  : ['ARPT: <*>: <*>: leaveModulePoweredForOffloads: Wi-Fi will <*> <*>']
# Length parse: 1
# ----------------------------------------
# No. 319
# Length: 8, Nums: 1
# Ground truth  : ARPT: <*>: Data written into the PLL_CNTRL_ADDR2: <*>
# Parse templs  : ['ARPT: <*>: Data written into the <*>: <*>']
# Length parse: 1
# ----------------------------------------
# No. 321
# Length: 8, Nums: 532
# Ground truth  : AirPort: Link Down on <*>. Reason <*> (Unspecified).
# Parse templs  : ['AirPort: Link Down on <*> Reason <*> (Unspecified).']
# Length parse: 1
# ----------------------------------------
# No. 322
# Length: 8, Nums: 532
# Ground truth  : AppleThunderboltNHIType2::waitForOk2Go2Sx - intel_rp = <*> dlla_reporting_supported = <*>
# Parse templs  : ['<*>::<*> - intel_rp = <*> dlla_reporting_supported = <*>']
# Length parse: 1
# ----------------------------------------
# No. 324
# Length: 8, Nums: 1283
# Ground truth  : CCFile::copyFile fileName is [<*>]-<*>, source path:<*>, dest path:<*>
# Parse templs  : ['CCFile::copyFile fileName is [<*>,<*>,<*>]<*>, source path:/var/log/CoreCapture/<*><*>[<*>,<*>,<*>]<*>, dest <*>']
# Length parse: 1
# ----------------------------------------
# No. 326
# Length: 8, Nums: 4
# Ground truth  : Could not find access page in directory <*>
# Parse templs  : ['Could not find access page in directory /Applications/PyCharm CE.app/Contents/Resources/PY.help']
# Length parse: 1
# ----------------------------------------
# No. 327
# Length: 8, Nums: 2
# Ground truth  : Failed to obtain sandbox extension for path=<*>. Errno:<*>
# Parse templs  : ['Failed to obtain sandbox extension for path=/Users/xpc/Library/Caches/<*>. Errno:<*>']
# Length parse: 1
# ----------------------------------------
# No. 329
# Length: 8, Nums: 12
# Ground truth  : LaunchServices: Could not store lsd-identifiers file at <*>
# Parse templs  : ['LaunchServices: Could not store lsd-identifiers file at /private/var/db/lsd/<*>']
# Length parse: 1
# ----------------------------------------
# No. 338
# Length: 8, Nums: 1052
# Ground truth  : [<*>] <<<< Boss >>>> figPlaybackBossPrerollCompleted: unexpected preroll-complete notification
# Parse templs  : ['[<*>:<*>:<*>] <<<< Boss >>>> figPlaybackBossPrerollCompleted: unexpected preroll-complete notification']
# Length parse: 1
# ----------------------------------------
# No. 339
# Length: 8, Nums: 2
# Ground truth  : [<*>] HTTPRequest figHTTPDumpFinalURLAndRemoteAddress: address <*> final url <*>
# Parse templs  : ['[<*>:<*>:<*>] HTTPRequest figHTTPDumpFinalURLAndRemoteAddress: address <*> final url <*>']
# Length parse: 1
# ----------------------------------------
# No. 340
# Length: 8, Nums: 16
# Ground truth  : [<*>] [Coalescing failed operation [<CalDAVAccountRefreshQueueableOperation: <*> Sequence: <*>]]
# Parse templs  : ['[<*>] [Coalescing failed operation [<CalDAVAccountRefreshQueueableOperation: <*>; Sequence: <*>>]]']
# Length parse: 1
# ----------------------------------------
# No. 342
# Length: 8, Nums: 14
# Ground truth  : blued: unable to relinquishBluetoothPagingLockAndReply Error Domain=<*> Code=<*> "(<*>)"
# Parse templs  : ['blued: unable to relinquishBluetoothPagingLockAndReply Error Domain=<*> Code=<*> "(null)"']
# Length parse: 1
# ----------------------------------------
# No. 344
# Length: 8, Nums: 1
# Ground truth  : zip importer encountered an error (<*>) scanning "<*>".
# Parse templs  : ['zip importer encountered an error (<*>) scanning "/Users/xpc/Library/Containers/<*>/Data/Documents/storage/Logs/<*>".']
# Length parse: 1
# ----------------------------------------
# No. 345
# Length: 9, Nums: 3
# Ground truth  : *** -[NSRecursiveLock unlock]: lock <*> unlocked when not locked
# Parse templs  : ["*** -[NSRecursiveLock unlock]: lock (<NSRecursiveLock: <*>> <*> <*>') unlocked when not locked"]
# Length parse: 1
# ----------------------------------------
# No. 347
# Length: 9, Nums: 679
# Ground truth  : -[ISGenerateImageOp generateImageWithCompletion:] Failed to composit image for descriptor <*>.
# Parse templs  : ['-[ISGenerateImageOp generateImageWithCompletion:] Failed to composit image for descriptor <ISBindingImageDescriptor: <*>>.']
# Length parse: 1
# ----------------------------------------
# No. 348
# Length: 9, Nums: 483
# Ground truth  : -[NETClientConnection <*>] <*> - Perform <*>! <*> <*> <*>
# Parse templs  : ['-[NETClientConnection <*>] <*> - Perform <*> <*> <*> <*>:<*>']
# Length parse: 1
# ----------------------------------------
# No. 349
# Length: 9, Nums: 19
# Ground truth  : <*> <*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSAgentApp checkForUpdates] Finished update check.
# Parse templs  : ['<*> <*>:<*>:<*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSAgentApp checkForUpdates] Finished update check.']
# Length parse: 1
# ----------------------------------------
# No. 350
# Length: 9, Nums: 38
# Ground truth  : <*> <*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSAgentApp(KeystoneDelegate) updateEngineFinishedWithErrors:] Keystone finished: errors=<*>
# Parse templs  : ['<*> <*>:<*>:<*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSAgentApp(KeystoneDelegate) updateEngineFinishedWithErrors:] Keystone finished: errors=<*>']
# Length parse: 1
# ----------------------------------------
# No. 351
# Length: 9, Nums: 19
# Ground truth  : <*> <*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSAgentApp(KeystoneThread) runKeystonesInThreadWithArg:] Starting engine thread
# Parse templs  : ['<*> <*>:<*>:<*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSAgentApp(KeystoneThread) runKeystonesInThreadWithArg:] Starting engine thread']
# Length parse: 1
# ----------------------------------------
# No. 354
# Length: 9, Nums: 262
# Ground truth  : ARPT: <*>: ARPT: Wake Reason: Wake on Scan offload
# Parse templs  : ['ARPT: <*>: ARPT: Wake Reason: Wake on <*> <*>']
# Length parse: 1
# ----------------------------------------
# No. 355
# Length: 9, Nums: 148
# Ground truth  : ARPT: <*>: ARPT: Wake Reason: Wake on TCP Timeout
# Parse templs  : ['ARPT: <*>: ARPT: Wake Reason: Wake on <*> <*>']
# Length parse: 1
# ----------------------------------------
# No. 357
# Length: 9, Nums: 1
# Ground truth  : ARPT: <*>: Data written into the PLL_CNTRL_ADDR3 (Fractional): <*>
# Parse templs  : ['ARPT: <*>: Data written into the <*> (Fractional): <*>']
# Length parse: 1
# ----------------------------------------
# No. 358
# Length: 9, Nums: 151
# Ground truth  : ASSERTION FAILED: dvcAddrRef != <*> -[DriverServices getDeviceAddress:] line: <*>
# Parse templs  : ['ASSERTION FAILED: dvcAddrRef != ((void *)<*>) -[DriverServices getDeviceAddress:] line: <*>']
# Length parse: 1
# ----------------------------------------
# No. 359
# Length: 9, Nums: 1019
# Ground truth  : AppleThunderboltNHIType2::prePCIWake - power up complete - took <*> us
# Parse templs  : ['<*>::prePCIWake - power up complete - took <*> us']
# Length parse: 1
# ----------------------------------------
# No. 363
# Length: 9, Nums: 7
# Ground truth  : Cleaning up expired diagnostic messages database at path: <*>
# Parse templs  : ['Cleaning up expired diagnostic messages database at path: /var/log/DiagnosticMessages/<*>']
# Length parse: 1
# ----------------------------------------
# No. 367
# Length: 9, Nums: 1
# Ground truth  : SSandbandbox: ox: <*>(le.WebKit(<*>) <*>) deny(deny(<*>) <*>) filee--rreaead-data <*> <*>
# Parse templs  : ['SSandbandbox: ox: <*>(le.WebKit(<*>) <*>) deny(deny(<*>) <*>) filee--rreaead-data /private/etd-c/hdata /osts']
# Length parse: 1
# ----------------------------------------
# No. 370
# Length: 9, Nums: 2
# Ground truth  : Warning: I could not find the column named <*>'.
# Parse templs  : ['Warning: I could not find the column named <*>']
# Length parse: 1
# ----------------------------------------
# No. 371
# Length: 9, Nums: 4
# Ground truth  : [<*>] <<<< FigPlayerSurrogate >>>> surrogatePlayer_respondToLoadingOfItemAssetTypeInternal: Avoiding unexpected additional FigPlayerAddToPlayQueue!
# Parse templs  : ['[<*>:<*>:<*>] <<<< FigPlayerSurrogate >>>> surrogatePlayer_respondToLoadingOfItemAssetTypeInternal: Avoiding unexpected additional FigPlayerAddToPlayQueue!']
# Length parse: 1
# ----------------------------------------
# No. 372
# Length: 9, Nums: 1
# Ground truth  : [<*>] HTTPRequest figHTTPRequestCreateErrorComment: encountered an error: HTTP <*>: Forbidden
# Parse templs  : ['[<*>:<*>:<*>] HTTPRequest figHTTPRequestCreateErrorComment: encountered an error: HTTP <*>: Forbidden']
# Length parse: 1
# ----------------------------------------
# No. 373
# Length: 9, Nums: 56
# Ground truth  : [<*>] [Adding [<CalDAVAccountRefreshQueueableOperation: <*> Sequence: <*>] to failed operations.]
# Parse templs  : ['[<*>] [Adding [<CalDAVAccountRefreshQueueableOperation: <*>; Sequence: <*>>] to failed operations.]']
# Length parse: 1
# ----------------------------------------
# No. 374
# Length: 9, Nums: 111
# Ground truth  : [<*>] itemasync_CopyProperty signalled err=<*> (<*>) at <*> line <*>
# Parse templs  : ['[<*>:<*>:<*>] <*> signalled err=<*> (kFigBaseObjectError_Invalidated) (invalidated) at /Library/Caches/<*>/Sources/CoreMedia/<*>/Prototypes/Player/FigPlayer_Async.c line <*>']
# Length parse: 1
# ----------------------------------------
# No. 378
# Length: 9, Nums: 15
# Ground truth  : childFrame with no value: <*> EWSMailboxTypeTypeDefinition:<*> (Inlined Arrays: (<*>))
# Parse templs  : ['childFrame with no value: <_SOAPParserFrame: <*>> EWSMailboxTypeTypeDefinition:__NSCFString (Inlined Arrays: (null))']
# Length parse: 1
# ----------------------------------------
# No. 379
# Length: 9, Nums: 3
# Ground truth  : failed to copy buffer for AID: <*> PID: <*>
# Parse templs  : ['failed to copy buffer for AID: <*>, PID: <*>']
# Length parse: 1
# ----------------------------------------
# No. 381
# Length: 9, Nums: 82
# Ground truth  : host connection <NSXPCConnection: <*> connection from pid <*> invalidated
# Parse templs  : ['host connection <NSXPCConnection: <*>> connection from pid <*> invalidated']
# Length parse: 1
# ----------------------------------------
# No. 382
# Length: 9, Nums: 2
# Ground truth  : mDNSOffloadUserClient: GetKeepaliveData: tcp.info sysctl failed, err=<*>. <*> -> <*>
# Parse templs  : ['mDNSOffloadUserClient: GetKeepaliveData: tcp.info sysctl failed, err=<*> <*> -> <*>']
# Length parse: 1
# ----------------------------------------
# No. 384
# Length: 9, Nums: 414
# Ground truth  : nw_nat64_post_new_ifstate successfully changed NAT64 ifstate from <*> to <*>
# Parse templs  : ['<*> successfully changed <*> ifstate from <*> to <*>']
# Length parse: 1
# ----------------------------------------
# No. 386
# Length: 9, Nums: 1
# Ground truth  : select(<*>, <*>, <*>, <*>, <*>) error: Bad file descriptor
# Parse templs  : ['select(<*>, #########--------------------, <*>, <*>, <*>) error: Bad file descriptor']
# Length parse: 1
# ----------------------------------------
# No. 388
# Length: 9, Nums: 5
# Ground truth  : wifi scan failed with error: Error Domain=<*> <*> "(<*>)"
# Parse templs  : ['wifi scan failed with error: Error Domain=<*> Code=<*> "(null)"']
# Length parse: 1
# ----------------------------------------
# No. 390
# Length: 10, Nums: 2
# Ground truth  : -[MMCoreTextView(Drawing) batchDrawData:]@<*>: Conversion error: some text may not be rendered
# Parse templs  : ['-[MMCoreTextView(Drawing) batchDrawData:]<*>: Conversion error: some text may not be rendered']
# Length parse: 1
# ----------------------------------------
# No. 392
# Length: 10, Nums: 6
# Ground truth  : <*> : SDWormholeServer::failedToStartScanningWithError Error Domain=<*> Code=<*> "(os/kern) no access" UserInfo={NSLocalizedDescription=<*>}
# Parse templs  : ['<*>:<*>:<*> : SDWormholeServer::failedToStartScanningWithError Error Domain=NSMachErrorDomain Code=<*> "(os/kern) no access" UserInfo={NSLocalizedDescription=wirelessproxd can\'t start scanning at this time.}']
# Length parse: 1
# ----------------------------------------
# No. 393
# Length: 10, Nums: 91
# Ground truth  : <*> : Starting AirDrop server for user <*> on wake
# Parse templs  : ['<*>:<*>:<*> : Starting AirDrop server for user <*> on wake']
# Length parse: 1
# ----------------------------------------
# No. 394
# Length: 10, Nums: 19
# Ground truth  : <*> <*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSAgentApp performSelfUpdateWithEngine:] Finished self update check.
# Parse templs  : ['<*> <*>:<*>:<*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSAgentApp performSelfUpdateWithEngine:] Finished self update check.']
# Length parse: 1
# ----------------------------------------
# No. 395
# Length: 10, Nums: 19
# Ground truth  : <*> <*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSAgentApp(KeystoneThread) runKeystonesInThreadWithArg:] Finished with engine thread
# Parse templs  : ['<*> <*>:<*>:<*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSAgentApp(KeystoneThread) runKeystonesInThreadWithArg:] Finished with engine thread']
# Length parse: 1
# ----------------------------------------
# No. 396
# Length: 10, Nums: 38
# Ground truth  : <*> <*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSCheckAction performAction] KSCheckAction checking <*> ticket(s).
# Parse templs  : ['<*> <*>:<*>:<*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSCheckAction performAction] KSCheckAction checking <*> ticket(s).']
# Length parse: 1
# ----------------------------------------
# No. 397
# Length: 10, Nums: 36
# Ground truth  : <*> <*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSOmahaServer updateInfosForUpdateResponse:updateRequest:infoStore:upToDateTickets:updatedTickets:events:errors:] Response passed CUP validation.
# Parse templs  : ['<*> <*>:<*>:<*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSOmahaServer updateInfosForUpdateResponse:updateRequest:infoStore:upToDateTickets:updatedTickets:events:errors:] Response passed CUP validation.']
# Length parse: 1
# ----------------------------------------
# No. 398
# Length: 10, Nums: 38
# Ground truth  : <*> <*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSUpdateCheckAction performAction] KSUpdateCheckAction running KSServerUpdateRequest: <KSOmahaServerUpdateRequest:<*>
# Parse templs  : ['<*> <*>:<*>:<*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSUpdateCheckAction performAction] KSUpdateCheckAction running KSServerUpdateRequest: <KSOmahaServerUpdateRequest:<*>']
# Length parse: 1
# ----------------------------------------
# No. 399
# Length: 10, Nums: 36
# Ground truth  : <*> <*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSUpdateCheckAction(KSServerUpdateRequestDelegate) serverRequest:fetchedWithResponse:] KSUpdateCheckAction received KSServerUpdateResponse: <KSOmahaServerUpdateResponse:<*>
# Parse templs  : ['<*> <*>:<*>:<*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSUpdateCheckAction(KSServerUpdateRequestDelegate) serverRequest:fetchedWithResponse:] KSUpdateCheckAction received KSServerUpdateResponse: <KSOmahaServerUpdateResponse:<*>']
# Length parse: 1
# ----------------------------------------
# No. 400
# Length: 10, Nums: 38
# Ground truth  : <*> <*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSUpdateEngine(PrivateMethods) updateFinish] KSUpdateEngine update processing complete.
# Parse templs  : ['<*> <*>:<*>:<*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSUpdateEngine(PrivateMethods) updateFinish] KSUpdateEngine update processing complete.']
# Length parse: 1
# ...
# Length parse: 1
# ----------------------------------------
# No. 609
# Length: 26, Nums: 14
# Ground truth  : [<*>] <<< FFR_Common >>> FigFormatReaderCreateForStreamReturningMatchingContainerLabelType: *** Could not find format reader for URL <*> path <*> extension <*> FileType '' MIMETYPE "(<*>)" SuggFileName "(<*>)" SuggNameExtension "(<*>)"
# Parse templs  : ['[<*>:<*>:<*>] <<< FFR_Common >>> FigFormatReaderCreateForStreamReturningMatchingContainerLabelType: *** Could not find format reader for URL "file:<*>(Chs,Jap)<*> path "/Users/xpc/Desktop/[Kamigami] Sword Art Online [BDrip <*> <*> FLAC MKV Sub(Chs,Jap)]/[Kamigami] Sword Art Online - <*> [BDrip <*> <*> FLAC].mkv" extension "mkv" FileType \'\' MIMETYPE "(null)" SuggFileName "(null)" SuggNameExtension "(null)"', '[<*>:<*>:<*>] <<< FFR_Common >>> FigFormatReaderCreateForStreamReturningMatchingContainerLabelType: *** Could not find format reader for URL "file:///Users/xpc/Downloads/FIG_cropper.swf" path "/Users/xpc/Downloads/FIG_cropper.swf" extension "swf" FileType \'\' MIMETYPE "(null)" SuggFileName "(null)" SuggNameExtension "(null)"']
# Length parse: 2
# ----------------------------------------
# No. 610
# Length: 27, Nums: 19
# Ground truth  : <*> <*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSAgentApp performSelfUpdateWithEngine:] This process may be killed if self-update is necessary. In such cases, sub-processes may still be running to complete the self-update.
# Parse templs  : ['<*> <*>:<*>:<*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSAgentApp performSelfUpdateWithEngine:] This process may be killed if self-update is necessary. In such cases, sub-processes may still be running to complete the self-update.']
# Length parse: 1
# ----------------------------------------
# No. 611
# Length: 27, Nums: 3
# Ground truth  : CoreText: *** Unmapped <*> <CTFont: <*>{name = <*>, size = <*>, matrix = <*>, descriptor = <CTFontDescriptor: <*>{attributes = <CFBasicHash <*> [<*>]>{type = <*>, count = <*>,
# Parse templs  : ['CoreText: *** Unmapped <*> <CTFont: <*>>{name = HelveticaNeue-Bold, size = <*>, matrix = <*>, descriptor = <CTFontDescriptor: <*>>{attributes = <CFBasicHash <*> [<*>]>{type = mutable dict, count = <*>,']
# Length parse: 1
# ----------------------------------------
# No. 612
# Length: 27, Nums: 57
# Ground truth  : hibernate_machine_init pagesDone <*> sum2 <*>, time: <*> ms, disk(<*>) <*> Mb/s, comp bytes: <*> time: <*> ms <*> Mb/s, crypt bytes: <*> time: <*> ms <*> Mb/s
# Parse templs  : ['hibernate_machine_init pagesDone <*> <*> <*>, time: <*> ms, disk(<*>) <*> Mb/s, comp bytes: <*> time: <*> ms <*> Mb/s, crypt bytes: <*> time: <*> ms <*> Mb/s']
# Length parse: 1
# ----------------------------------------
# No. 613
# Length: 28, Nums: 4
# Ground truth  : <*> <*> ksfetch[<*>] [lvl=<*>] -[FetchDelegate fetcher:failedWithError:] Fetcher generated error: Error Domain=<*> Code=<*> <*>" UserInfo={NSUnderlyingError=<*> {Error Domain=<*> Code=<*> <*>" UserInfo={NSErrorFailingURLStringKey=<*>, NSErrorFailingURLKey=<*>, _kCFStreamErrorCodeKey=<*>, _kCFStreamErrorDomainKey=<*>, NSLocalizedDescription=<*>}}, NSErrorFailingURLStringKey=<*>, NSErrorFailingURLKey=<*>, _kCFStreamErrorDomainKey=<*>, _kCFStreamErrorCodeKey=<*>, NSLocalizedDescription=<*>}
# Parse templs  : ['<*> <*>:<*>:<*> ksfetch[<*>] [lvl=<*>] -[FetchDelegate fetcher:failedWithError:] Fetcher generated error: Error Domain=NSURLErrorDomain Code=<*> "The Internet connection appears to be offline." UserInfo={NSUnderlyingError=<*> {Error Domain=kCFErrorDomainCFNetwork Code=<*> "The Internet connection appears to be offline." UserInfo={NSErrorFailingURLStringKey=<*>://<*><*>=<*>=<*>:<*>, NSErrorFailingURLKey=<*>://<*><*>=<*>=<*>:<*>, _kCFStreamErrorCodeKey=<*>, _kCFStreamErrorDomainKey=<*>, NSLocalizedDescription=The Internet connection appears to be offline.}}, NSErrorFailingURLStringKey=<*>://<*><*>=<*>=<*>:<*>, NSErrorFailingURLKey=<*>://<*><*>=<*>=<*>:<*>, _kCFStreamErrorDomainKey=<*>, _kCFStreamErrorCodeKey=<*>, NSLocalizedDescription=The Internet connection appears to be offline.}']
# Length parse: 1
# ----------------------------------------
# No. 614
# Length: 28, Nums: 2
# Ground truth  : Application App:<*> asn:<*> pid:<*> refs=<*> @ <*> tried to be brought forward, but isn't in fPermittedFrontApps ( ( "<*>")), so denying. : LASSession.cp <*> SetFrontApplication() q=LSSession <*> queue
# Parse templs  : ['Application App:"loginwindow" asn:<*> pid:<*> refs=<*> @ <*> tried to be brought forward, but isn\'t in fPermittedFrontApps ( ( "LSApplication:<*> pid=<*> "ScreenSaverEngine"")), so denying. : LASSession.cp <*> SetFrontApplication() q=LSSession <*> queue']
# Length parse: 1
# ----------------------------------------
# No. 616
# Length: 28, Nums: 925
# Ground truth  : Path not allowed in target domain: type = <*>, path = <*> error = <*>: The specified service did not ship in the requestor's bundle, origin = <*>
# Parse templs  : ["Path not allowed in target domain: type = pid, path = /System/Library/StagedFrameworks/Safari/SafariShared.framework/Versions/A/XPCServices/<*>/Contents/MacOS/<*> error = <*>: The specified service did not ship in the requestor's bundle, origin = /System/Library/StagedFrameworks/Safari/WebKit.framework/Versions/A/XPCServices/<*>"]
# Length parse: 1
# ----------------------------------------
# No. 617
# Length: 29, Nums: 1
# Ground truth  : Google Chrome[<*>] triggered unnest of range <*>-<*> of DYLD shared region in VM map <*>. While not abnormal for debuggers, this increases system memory footprint until the target exits.
# Parse templs  : ['Google Chrome[<*>] triggered unnest of range <*>><*> of DYLD shared region in VM map <*> While not abnormal for debuggers, this increases system memory footprint until the target exits.']
# Length parse: 1
# ----------------------------------------
# No. 618
# Length: 29, Nums: 12
# Ground truth  : [<*>] [Sync report for calendar home iCloud, failed with error Error Domain=NSURLErrorDomain <*> <*> <*> {Error Domain=kCFErrorDomainCFNetwork <*> <*> UserInfo={NSErrorFailingURLStringKey=<*>, NSErrorFailingURLKey=<*>, _kCFStreamErrorCodeKey=<*>, _kCFStreamErrorDomainKey=<*>, <*> NSErrorFailingURLStringKey=<*>, NSErrorFailingURLKey=<*>, _kCFStreamErrorDomainKey=<*>, _kCFStreamErrorCodeKey=<*>, <*>
# Parse templs  : ['[<*>] [Sync report for calendar home iCloud, failed with error Error Domain=NSURLErrorDomain Code=<*> <*> UserInfo={NSUnderlyingError=<*> {Error Domain=kCFErrorDomainCFNetwork Code=<*> <*> UserInfo={NSErrorFailingURLStringKey=https:<*><*><*>, NSErrorFailingURLKey=https:<*><*><*>, _kCFStreamErrorCodeKey=<*>, _kCFStreamErrorDomainKey=<*>, <*> NSErrorFailingURLStringKey=https:<*><*><*>, NSErrorFailingURLKey=https:<*><*><*>, _kCFStreamErrorDomainKey=<*>, _kCFStreamErrorCodeKey=<*>, <*>']
# Length parse: 1
# ----------------------------------------
# No. 620
# Length: 30, Nums: 46
# Ground truth  : <*> <*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSAgentApp setupLoggerOutput] Agent settings: <KSAgentSettings:<*> bundleID=<*> lastCheck=<*> checkInterval=<*> uiDisplayInterval=<*> sleepInterval=<*> jitterInterval=<*> maxRunInterval=<*> isConsoleUser=<*> ticketStorePath=<*> runMode=<*> daemonUpdateEngineBrokerServiceName=<*> daemonAdministrationServiceName=<*> logEverything=<*> logBufferSize=<*> alwaysPromptForUpdates=<*> productIDToUpdate=(<*>) lastUIDisplayed=(<*>) alwaysShowStatusItem=<*> updateCheckTag=(<*>) printResults=<*> userInitiated=<*>
# Parse templs  : ['<*> <*>:<*>:<*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] -[KSAgentApp setupLoggerOutput] Agent settings: <KSAgentSettings:<*> bundleID=<*> lastCheck=<*> <*>:<*>:<*> <*> checkInterval=<*> uiDisplayInterval=<*> sleepInterval=<*> jitterInterval=<*> maxRunInterval=<*> isConsoleUser=<*> ticketStorePath=/Users/xpc/Library/Google/GoogleSoftwareUpdate/TicketStore/Keystone.ticketstore runMode=<*> daemonUpdateEngineBrokerServiceName=<*> daemonAdministrationServiceName=<*> logEverything=<*> logBufferSize=<*> alwaysPromptForUpdates=<*> productIDToUpdate=(null) lastUIDisplayed=(null) alwaysShowStatusItem=<*> updateCheckTag=(null) printResults=NO userInitiated=NO>']
# Length parse: 1
# ----------------------------------------
# No. 621
# Length: 30, Nums: 16
# Ground truth  : <*> <*>, <*>, <*>, [CountryConfiguration]: Could not determine current country code: Error Domain=<*> Code=<*> <*> UserInfo={NSUnderlyingError=<*> {Error Domain=<*> Code=<*> <*> UserInfo={NSErrorFailingURLStringKey=<*>, NSErrorFailingURLKey=<*>, _kCFStreamErrorCodeKey=<*>, _kCFStreamErrorDomainKey=<*>, NSLocalizedDescription=<*>}}, NSErrorFailingURLStringKey=<*>, NSErrorFailingURLKey=<*>, _kCFStreamErrorDomainKey=<*>, _kCFStreamErrorCodeKey=<*>, NSLocalizedDescription=<*>}
# Parse templs  : ['<*> <*>:<*>:<*>, <*>, <*>, [CountryConfiguration]: Could not determine current country code: Error Domain=NSURLErrorDomain Code=<*> "The Internet connection appears to be offline." UserInfo={NSUnderlyingError=<*> {Error Domain=kCFErrorDomainCFNetwork Code=<*> "The Internet connection appears to be offline." UserInfo={NSErrorFailingURLStringKey=https://<*>/pep/gcc, NSErrorFailingURLKey=https://<*>/pep/gcc, _kCFStreamErrorCodeKey=<*>, _kCFStreamErrorDomainKey=<*>, NSLocalizedDescription=The Internet connection appears to be offline.}}, NSErrorFailingURLStringKey=https://<*>/pep/gcc, NSErrorFailingURLKey=https://<*>/pep/gcc, _kCFStreamErrorDomainKey=<*>, _kCFStreamErrorCodeKey=<*>, NSLocalizedDescription=The Internet connection appears to be offline.}', '<*> <*>:<*>:<*>, <*>, <*>, [CountryConfiguration]: Could not determine current country code: Error Domain=NSURLErrorDomain Code=<*> "A server with the specified hostname could not be found." UserInfo={NSUnderlyingError=<*> {Error Domain=kCFErrorDomainCFNetwork Code=<*> "A server with the specified hostname could not be found." UserInfo={NSErrorFailingURLStringKey=https://<*>/pep/gcc, NSErrorFailingURLKey=https://<*>/pep/gcc, _kCFStreamErrorCodeKey=<*>, _kCFStreamErrorDomainKey=<*>, NSLocalizedDescription=A server with the specified hostname could not be found.}}, NSErrorFailingURLStringKey=https://<*>/pep/gcc, NSErrorFailingURLKey=https://<*>/pep/gcc, _kCFStreamErrorDomainKey=<*>, _kCFStreamErrorCodeKey=<*>, NSLocalizedDescription=A server with the specified hostname could not be found.}']
# Length parse: 2
# ----------------------------------------
# No. 622
# Length: 30, Nums: 149
# Ground truth  : Google Chrome <*> triggered unnest of range <*>-<*> of DYLD shared region in VM map <*>. While not abnormal for debuggers, this increases system memory footprint until the target exits.
# Parse templs  : ['Google Chrome He[<*>] triggered unnest of range <*>><*> of DYLD shared region in VM map <*> While not abnormal for debuggers, this increases system memory footprint until the target exits.']
# Length parse: 1
# ----------------------------------------
# No. 623
# Length: 31, Nums: 38
# Ground truth  : <*> <*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] +[KSCodeSigningVerification verifyBundle:applicationId:error:] KSCodeSigningVerification verifying code signing for <*> with the requirement 'anchor apple generic and certificate <*>[field.<*>] exists and certificate leaf[field.<*>] exists and certificate leaf[subject.OU]=<*> and (identifier=<*>)'
# Parse templs  : ['<*> <*>:<*>:<*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] +[KSCodeSigningVerification verifyBundle:applicationId:error:] KSCodeSigningVerification verifying code signing for \'/Users/xpc/Library/Google/GoogleSoftwareUpdate/GoogleSoftwareUpdate.bundle/Contents/MacOS/GoogleSoftwareUpdateDaemon\' with the requirement \'anchor apple generic and certificate <*>[<*>] exists and certificate leaf[<*>] exists and certificate leaf[subject.OU]=<*> and (identifier="<*>")\'', '<*> <*>:<*>:<*> GoogleSoftwareUpdateAgent[<*>] [lvl=<*>] +[KSCodeSigningVerification verifyBundle:applicationId:error:] KSCodeSigningVerification verifying code signing for \'/Applications/Google Chrome.app\' with the requirement \'anchor apple generic and certificate <*>[<*>] exists and certificate leaf[<*>] exists and certificate leaf[subject.OU]=<*> and (identifier="<*>")\'']
# Length parse: 2
# ----------------------------------------
# No. 624
# Length: 36, Nums: 7
# Ground truth  : <*> <*>, <*>, <*>, [LogMessageLogging]: [<*>] - Request to send LogMessages of count (<*>) failed with Error: Error Domain=<*> Code=-<*> <*> UserInfo={NSUnderlyingError=<*> {Error Domain=<*> Code=<*> <*> UserInfo={NSErrorFailingURLStringKey=<*>, NSErrorFailingURLKey=<*>, _kCFStreamErrorCodeKey=<*>, _kCFStreamErrorDomainKey=<*>, NSLocalizedDescription=<*>}}, NSErrorFailingURLStringKey=<*>, NSErrorFailingURLKey=<*>, _kCFStreamErrorDomainKey=<*>, _kCFStreamErrorCodeKey=<*>, NSLocalizedDescription=<*>}
# Parse templs  : ['<*> <*>:<*>:<*>, <*>, <*>, [LogMessageLogging]: [<*>] - Request to send LogMessages of count (<*>) failed with Error: Error Domain=NSURLErrorDomain Code=<*> "The Internet connection appears to be offline." UserInfo={NSUnderlyingError=<*> {Error Domain=kCFErrorDomainCFNetwork Code=<*> "The Internet connection appears to be offline." UserInfo={NSErrorFailingURLStringKey=https://<*><*>, NSErrorFailingURLKey=https://<*><*>, _kCFStreamErrorCodeKey=<*>, _kCFStreamErrorDomainKey=<*>, NSLocalizedDescription=The Internet connection appears to be offline.}}, NSErrorFailingURLStringKey=https://<*><*>, NSErrorFailingURLKey=https://<*><*>, _kCFStreamErrorDomainKey=<*>, _kCFStreamErrorCodeKey=<*>, NSLocalizedDescription=The Internet connection appears to be offline.}', '<*> <*>:<*>:<*>, <*>, <*>, [LogMessageLogging]: [<*>] - Request to send LogMessages of count (<*>) failed with Error: Error Domain=NSURLErrorDomain Code=<*> "The network connection was lost." UserInfo={NSUnderlyingError=<*> {Error Domain=kCFErrorDomainCFNetwork Code=<*> "The network connection was lost." UserInfo={NSErrorFailingURLStringKey=https://<*><*>, NSErrorFailingURLKey=https://<*><*>, _kCFStreamErrorCodeKey=<*>, _kCFStreamErrorDomainKey=<*>, NSLocalizedDescription=The network connection was lost.}}, NSErrorFailingURLStringKey=https://<*><*>, NSErrorFailingURLKey=https://<*><*>, _kCFStreamErrorDomainKey=<*>, _kCFStreamErrorCodeKey=<*>, NSLocalizedDescription=The network connection was lost.}', '<*> <*>:<*>:<*>, <*>, <*>, [LogMessageLogging]: [<*>] - Request to send LogMessages of count (<*>) failed with Error: Error Domain=NSURLErrorDomain Code=<*> "A server with the specified hostname could not be found." UserInfo={NSUnderlyingError=<*> {Error Domain=kCFErrorDomainCFNetwork Code=<*> "A server with the specified hostname could not be found." UserInfo={NSErrorFailingURLStringKey=https://<*><*>, NSErrorFailingURLKey=https://<*><*>, _kCFStreamErrorCodeKey=<*>, _kCFStreamErrorDomainKey=<*>, NSLocalizedDescription=A server with the specified hostname could not be found.}}, NSErrorFailingURLStringKey=https://<*><*>, NSErrorFailingURLKey=https://<*><*>, _kCFStreamErrorDomainKey=<*>, _kCFStreamErrorCodeKey=<*>, NSLocalizedDescription=A server with the specified hostname could not be found.}']
# Length parse: 3
# ----------------------------------------
# No. 626
# Length: 41, Nums: 2
# Ground truth  : [Warning] Broadcasting no devices for account IDSDAccount: <*> [Service: IDSDService: <*> [Identifier: <*> Display Name: <*> Topic: <*> Service: <*> Protocol: <*>] Login: <*> UniqueID: <*> Account Type: <*> Registration: <*> Registered: <*> Linked Accounts: <*>] even though we have some
# Parse templs  : ['[Warning] Broadcasting no devices for account IDSDAccount: <*> [Service: IDSDService: <*> [Identifier: <*> Display Name: ScreenSharing Topic: <*> Service: <*> Protocol: <*>] Login: <*> UniqueID: <*> Account Type: Apple ID Registration: (null) Registered: YES Linked Accounts: (null)] even though we have some']
# Length parse: 1
# ----------------------------------------
# Total differences found: 357

# %% [markdown]
# ##### **@.2. HOÀN CHỈNH**

# %%
# def parse_DrainDS(datasets):
#     logs_df = load_data(datasets['log_file'], datasets['log_format'])
    
    
#     # =============================== CÁC CÂU LỆNH IN KIỂM TRA ===============================
#     logs_df.head(100)
    
    
    
# # =============== CHẠY CHƯƠNG TRÌNH ==============
# parse_DrainDS(SETTING_PARAMS['Mac'])
