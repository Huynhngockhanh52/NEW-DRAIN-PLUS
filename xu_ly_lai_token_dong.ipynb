# %%
import re
import sys
sys.path.append('../')
import os
import pandas as pd
from collections import Counter, defaultdict
import datetime
from tqdm import tqdm
import string
from copy import deepcopy

import hashlib
import time

pd.set_option('display.max_rows', None)

# %%
def hasNumbers(s):
    return any(char.isdigit() for char in s)

def isDynamicToken(token: str, special_tokens: set) -> bool:
    """ Kiểm tra xem token có phải là token động hay không """

    # 1. Kiểm tra nếu token.lower() nằm trong special_tokens
    if token.lower() in special_tokens:
        return True

    # 2. Kiểm tra nếu toàn bộ token là số HEX hợp lệ (ít nhất 8 chữ số hex)
    if re.fullmatch(r'0x[0-9a-fA-F]+', token) or re.fullmatch(r'[0-9a-fA-F]{8,}', token):
        return True

    # 3. Kiểm tra nếu token là số (có thể âm, có thể thập phân)
    if re.fullmatch(r'-?\d+(\.\d+)?', token):
        return True

    return False

# %%
def splitSubToken(s, seps):
    placeholder = "~~WILDCARD~~"
    s = s.replace("<*>", placeholder)

    pattern = '|'.join(re.escape(sep) for sep in seps)

    tokensL = re.split(f'({pattern})', s)
    tokensL = [tok.replace(placeholder, "<*>") for tok in tokensL if tok.strip() != '']

    return tokensL
def processingSubToken(tok):
    # 1. Kiểm tra nếu toàn bộ token là số HEX hợp lệ (ít nhất 8 chữ số hex)
    if re.fullmatch(r'0x[0-9a-fA-F]+', tok) or re.fullmatch(r'[0-9a-fA-F]{8,}', tok):
        return True
    
    if not hasNumbers(tok):
        return False

    # 2. Kiểm tra nếu token là số (có thể âm, có thể thập phân)
    if re.fullmatch(r'-?\d+(\.\d+)?', tok):
        return True
    
    number_groups = re.findall(r'\d+', tok)
    if len(number_groups) > 1:
        return True
    
    matches = list(re.finditer(r'[a-zA-Z]+[0-9]+', tok))
    if len(matches) == 1:
        end = matches[0].end()
        if end == len(tok) or not tok[end].isalnum():
            return False  # tĩnh

    return True

# %%
log_df = pd.read_csv('test.csv')

special_tokens = ['true', 'false', 'null', 'root']
punctuationL = "[](){}=:,#"
special_set = set(tok.lower() for tok in special_tokens)
regexs = [
    [r'(?:[0-9a-fA-F]{2}:){3,}[0-9a-fA-F]{2}', "<*>"],
    [r'([\\\/]([\w.-_@#!]+?)){2,}[\\\/]([\w.-_@#!]+)', "<*>"],
]

logTemplate = defaultdict(list)

for idx, row in log_df.iterrows():
    content_str = row['Content']
    for pattern, *replacement in regexs:
        replacement = replacement[0] if replacement else "<*>"
        content_str = re.sub(pattern, replacement, content_str)
    special_set = set(tok.lower() for tok in special_tokens)
    
    tokensL = str(content_str).strip().split()
    
    new_tokens = []
    idx_dynamic_token = []
    static_tokenL = []
    
    for idx_tok, token in enumerate(tokensL):
        sub_tokensL = splitSubToken(token, punctuationL)
        for idx_sub, sub_token in enumerate(sub_tokensL):
            if sub_token in special_set:
                sub_tokensL[idx_sub] = "<*>"
                continue
            
            if processingSubToken(sub_token):
                sub_tokensL[idx_sub] = "<*>"
        
        if len(sub_tokensL) <= 1:
            new_tokens.append(sub_tokensL[0])
        else:
            new_tokens.append("".join(sub_tokensL))
            idx_dynamic_token.append(idx_tok)
            static_tokenL.append(sub_tokensL)
    logTemplate[" ".join(new_tokens)].append(idx)
    print(f"Row {idx}: {row['Content']}\n{new_tokens}")
# Out:
# Row 0: session closed for user root
# ['session', 'closed', 'for', 'user', '<*>']
# Row 1: session opened for user root by (uid=0)
# ['session', 'opened', 'for', 'user', '<*>', 'by', '(uid=<*>)']
# Row 2: (root) CMD (run-parts /etc/cron.hourly)
# ['(<*>)', 'CMD', '(run-parts', '/etc/cron.hourly)']
# Row 3: session closed for user root
# ['session', 'closed', 'for', 'user', '<*>']
# Row 4: session opened for user root by (uid=0)
# ['session', 'opened', 'for', 'user', '<*>', 'by', '(uid=<*>)']
# Row 5: (root) CMD (run-parts /etc/cron.hourly)
# ['(<*>)', 'CMD', '(run-parts', '/etc/cron.hourly)']
# Row 6: session closed for user root
# ['session', 'closed', 'for', 'user', '<*>']
# Row 7: session opened for user root by (uid=0)
# ['session', 'opened', 'for', 'user', '<*>', 'by', '(uid=<*>)']
# Row 8: (root) CMD (run-parts /etc/cron.hourly)
# ['(<*>)', 'CMD', '(run-parts', '/etc/cron.hourly)']
# Row 9: session closed for user root
# ['session', 'closed', 'for', 'user', '<*>']
# Row 10: session opened for user root by (uid=0)
# ['session', 'opened', 'for', 'user', '<*>', 'by', '(uid=<*>)']
# Row 11: (root) CMD (run-parts /etc/cron.hourly)
# ['(<*>)', 'CMD', '(run-parts', '/etc/cron.hourly)']
# Row 12: session closed for user root
# ['session', 'closed', 'for', 'user', '<*>']
# Row 13: session opened for user root by (uid=0)
# ['session', 'opened', 'for', 'user', '<*>', 'by', '(uid=<*>)']
# Row 14: (root) CMD (run-parts /etc/cron.hourly)
# ['(<*>)', 'CMD', '(run-parts', '/etc/cron.hourly)']
# Row 15: session closed for user root
# ['session', 'closed', 'for', 'user', '<*>']
# Row 16: session opened for user root by (uid=0)
# ['session', 'opened', 'for', 'user', '<*>', 'by', '(uid=<*>)']
# Row 17: (root) CMD (run-parts /etc/cron.hourly)
# ['(<*>)', 'CMD', '(run-parts', '/etc/cron.hourly)']
# Row 18: session closed for user root
# ['session', 'closed', 'for', 'user', '<*>']
# Row 19: session opened for user root by (uid=0)
# ['session', 'opened', 'for', 'user', '<*>', 'by', '(uid=<*>)']
# Row 20: (root) CMD (run-parts /etc/cron.hourly)
# ['(<*>)', 'CMD', '(run-parts', '/etc/cron.hourly)']
# Row 21: session closed for user root
# ['session', 'closed', 'for', 'user', '<*>']
# Row 22: session opened for user root by (uid=0)
# ['session', 'opened', 'for', 'user', '<*>', 'by', '(uid=<*>)']
# Row 23: (root) CMD (run-parts /etc/cron.hourly)
# ['(<*>)', 'CMD', '(run-parts', '/etc/cron.hourly)']
# Row 24: session closed for user root
# ['session', 'closed', 'for', 'user', '<*>']
# Row 25: session opened for user root by (uid=0)
# ['session', 'opened', 'for', 'user', '<*>', 'by', '(uid=<*>)']
# Row 26: (root) CMD (run-parts /etc/cron.hourly)
# ['(<*>)', 'CMD', '(run-parts', '/etc/cron.hourly)']
# Row 27: session closed for user root
# ['session', 'closed', 'for', 'user', '<*>']
# Row 28: session opened for user root by (uid=0)
# ['session', 'opened', 'for', 'user', '<*>', 'by', '(uid=<*>)']
# Row 29: (root) CMD (run-parts /etc/cron.hourly)
# ['(<*>)', 'CMD', '(run-parts', '/etc/cron.hourly)']
# Row 30: session closed for user root
# ['session', 'closed', 'for', 'user', '<*>']
# Row 31: session opened for user root by (uid=0)
# ['session', 'opened', 'for', 'user', '<*>', 'by', '(uid=<*>)']
# Row 32: (root) CMD (run-parts /etc/cron.hourly)
# ['(<*>)', 'CMD', '(run-parts', '/etc/cron.hourly)']
# Row 33: session closed for user root
# ['session', 'closed', 'for', 'user', '<*>']
# Row 34: session opened for user root by (uid=0)
# ['session', 'opened', 'for', 'user', '<*>', 'by', '(uid=<*>)']
# Row 35: (root) CMD (run-parts /etc/cron.hourly)
# ['(<*>)', 'CMD', '(run-parts', '/etc/cron.hourly)']
# Row 36: session closed for user root
# ['session', 'closed', 'for', 'user', '<*>']
# Row 37: session opened for user root by (uid=0)
# ['session', 'opened', 'for', 'user', '<*>', 'by', '(uid=<*>)']
# Row 38: (root) CMD (run-parts /etc/cron.hourly)
# ['(<*>)', 'CMD', '(run-parts', '/etc/cron.hourly)']
# Row 39: data_thread() got not answer from any [Thunderbird_A8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A8]', 'datasource']
# Row 40: data_thread() got not answer from any [Thunderbird_B8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B8]', 'datasource']
# Row 41: data_thread() got not answer from any [Thunderbird_C5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C5]', 'datasource']
# Row 42: session closed for user root
# ['session', 'closed', 'for', 'user', '<*>']
# Row 43: session opened for user root by (uid=0)
# ['session', 'opened', 'for', 'user', '<*>', 'by', '(uid=<*>)']
# Row 44: (root) CMD (run-parts /etc/cron.hourly)
# ['(<*>)', 'CMD', '(run-parts', '/etc/cron.hourly)']
# Row 45: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 46: synchronized to 10.100.28.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 47: synchronized to 10.100.24.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 48: data_thread() got not answer from any [Thunderbird_B7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B7]', 'datasource']
# Row 49: synchronized to 10.100.16.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 50: data_thread() got not answer from any [Thunderbird_A4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A4]', 'datasource']
# Row 51: data_thread() got not answer from any [Thunderbird_B4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B4]', 'datasource']
# Row 52: data_thread() got not answer from any [Thunderbird_C8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C8]', 'datasource']
# Row 53: synchronized to 10.100.18.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 54: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 55: [ib_sm_sweep.c:1831]: ********************** NEW SWEEP ********************
# ['[ib_sm_sweep.c:<*>]:', '**********************', 'NEW', 'SWEEP', '********************']
# Row 56: synchronized to 10.100.26.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 57: data_thread() got not answer from any [Thunderbird_B3] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B3]', 'datasource']
# Row 58: synchronized to 10.100.18.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 59: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 60: data_thread() got not answer from any [Thunderbird_D5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D5]', 'datasource']
# Row 61: synchronized to 10.100.22.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 62: [ib_sm_sweep.c:1455]: No topology change
# ['[ib_sm_sweep.c:<*>]:', 'No', 'topology', 'change']
# Row 63: [ib_sm_sweep.c:1482]: No configuration change required
# ['[ib_sm_sweep.c:<*>]:', 'No', 'configuration', 'change', 'required']
# Row 64: data_thread() got not answer from any [Thunderbird_A1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A1]', 'datasource']
# Row 65: data_thread() got not answer from any [Thunderbird_C2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C2]', 'datasource']
# Row 66: data_thread() got not answer from any [Thunderbird_B1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B1]', 'datasource']
# Row 67: synchronized to 10.100.18.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 68: data_thread() got not answer from any [Thunderbird_A3] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A3]', 'datasource']
# Row 69: data_thread() got not answer from any [Thunderbird_A5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A5]', 'datasource']
# Row 70: synchronized to 10.100.22.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 71: synchronized to 10.100.28.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 72: data_thread() got not answer from any [Thunderbird_A6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A6]', 'datasource']
# Row 73: Local disconnected: Connection closed.
# ['Local', 'disconnected:', 'Connection', 'closed.']
# Row 74: connection lost: 'Connection closed.'
# ['connection', 'lost:', "'Connection", "closed.'"]
# Row 75: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 76: synchronized to 10.100.24.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 77: data_thread() got not answer from any [Thunderbird_B6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B6]', 'datasource']
# Row 78: data_thread() got not answer from any [Thunderbird_B2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B2]', 'datasource']
# Row 79: data_thread() got not answer from any [Thunderbird_C1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C1]', 'datasource']
# Row 80: data_thread() got not answer from any [Thunderbird_C4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C4]', 'datasource']
# Row 81: data_thread() got not answer from any [Thunderbird_D7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D7]', 'datasource']
# Row 82: data_thread() got not answer from any [Thunderbird_A7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A7]', 'datasource']
# Row 83: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 84: [ib_sm_sweep.c:1831]: ********************** NEW SWEEP ********************
# ['[ib_sm_sweep.c:<*>]:', '**********************', 'NEW', 'SWEEP', '********************']
# Row 85: data_thread() got not answer from any [Thunderbird_D6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D6]', 'datasource']
# Row 86: data_thread() got not answer from any [Thunderbird_B5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B5]', 'datasource']
# Row 87: data_thread() got not answer from any [Thunderbird_B8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B8]', 'datasource']
# Row 88: data_thread() got not answer from any [Thunderbird_D4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D4]', 'datasource']
# Row 89: data_thread() got not answer from any [Thunderbird_C6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C6]', 'datasource']
# Row 90: synchronized to 10.100.26.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 91: synchronized to 10.100.26.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 92: data_thread() got not answer from any [Thunderbird_D8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D8]', 'datasource']
# Row 93: [ib_sm_sweep.c:1455]: No topology change
# ['[ib_sm_sweep.c:<*>]:', 'No', 'topology', 'change']
# Row 94: [ib_sm_sweep.c:1482]: No configuration change required
# ['[ib_sm_sweep.c:<*>]:', 'No', 'configuration', 'change', 'required']
# Row 95: unable to qualify my own domain name (eadmin1) -- using short name
# ['unable', 'to', 'qualify', 'my', 'own', 'domain', 'name', '(eadmin1)', '--', 'using', 'short', 'name']
# Row 96: session closed for user root
# ['session', 'closed', 'for', 'user', '<*>']
# Row 97: jA9J1UvC004306: from=root, size=629060, class=0, nrcpts=1, msgid=<200511091901.jA9J1UvC004306@eadmin1>, relay=#7#@localhost
# ['<*>:', 'from=<*>,', 'size=<*>,', 'class=<*>,', 'nrcpts=<*>,', 'msgid=<*>,', 'relay=#<*>#@localhost']
# Row 98: jA9J1UvC004306: to=root, ctladdr=root (0/0), delay=00:00:01, xdelay=00:00:00, mailer=relay, pri=659060, relay=[127.0.0.1] [127.0.0.1], dsn=4.0.0, stat=Deferred: Connection refused by [127.0.0.1]
# ['<*>:', 'to=<*>,', 'ctladdr=<*>', '(<*>),', 'delay=<*>:<*>:<*>,', 'xdelay=<*>:<*>:<*>,', 'mailer=relay,', 'pri=<*>,', 'relay=[<*>]', '[<*>],', 'dsn=<*>,', 'stat=Deferred:', 'Connection', 'refused', 'by', '[<*>]']
# Row 99: data_thread() got not answer from any [Thunderbird_A2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A2]', 'datasource']
# Row 100: unable to qualify my own domain name (badmin1) -- using short name
# ['unable', 'to', 'qualify', 'my', 'own', 'domain', 'name', '(badmin1)', '--', 'using', 'short', 'name']
# Row 101: unable to qualify my own domain name (cadmin1) -- using short name
# ['unable', 'to', 'qualify', 'my', 'own', 'domain', 'name', '(cadmin1)', '--', 'using', 'short', 'name']
# Row 102: synchronized to 10.100.16.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 103: unable to qualify my own domain name (dadmin1) -- using short name
# ['unable', 'to', 'qualify', 'my', 'own', 'domain', 'name', '(dadmin1)', '--', 'using', 'short', 'name']
# Row 104: data_thread() got not answer from any [Thunderbird_A8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A8]', 'datasource']
# Row 105: synchronized to 10.100.22.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 106: data_thread() got not answer from any [Thunderbird_B7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B7]', 'datasource']
# Row 107: session closed for user root
# ['session', 'closed', 'for', 'user', '<*>']
# Row 108: jA9J1Wd7019391: from=root, size=1594553, class=0, nrcpts=1, msgid=<200511091901.jA9J1Wd7019391@cadmin1>, relay=#7#@localhost
# ['<*>:', 'from=<*>,', 'size=<*>,', 'class=<*>,', 'nrcpts=<*>,', 'msgid=<*>,', 'relay=#<*>#@localhost']
# Row 109: jA9J1Wd7019391: to=root, ctladdr=root (0/0), delay=00:00:02, xdelay=00:00:00, mailer=relay, pri=1624553, relay=[127.0.0.1] [127.0.0.1], dsn=4.0.0, stat=Deferred: Connection refused by [127.0.0.1]
# ['<*>:', 'to=<*>,', 'ctladdr=<*>', '(<*>),', 'delay=<*>:<*>:<*>,', 'xdelay=<*>:<*>:<*>,', 'mailer=relay,', 'pri=<*>,', 'relay=[<*>]', '[<*>],', 'dsn=<*>,', 'stat=Deferred:', 'Connection', 'refused', 'by', '[<*>]']
# Row 110: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 111: data_thread() got not answer from any [Thunderbird_A4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A4]', 'datasource']
# Row 112: session closed for user root
# ['session', 'closed', 'for', 'user', '<*>']
# Row 113: jA9J1WSU011176: from=root, size=1593894, class=0, nrcpts=1, msgid=<200511091901.jA9J1WSU011176@badmin1>, relay=#7#@localhost
# ['<*>:', 'from=<*>,', 'size=<*>,', 'class=<*>,', 'nrcpts=<*>,', 'msgid=<*>,', 'relay=#<*>#@localhost']
# Row 114: jA9J1WSU011176: to=root, ctladdr=root (0/0), delay=00:00:03, xdelay=00:00:00, mailer=relay, pri=1623894, relay=[127.0.0.1] [127.0.0.1], dsn=4.0.0, stat=Deferred: Connection refused by [127.0.0.1]
# ['<*>:', 'to=<*>,', 'ctladdr=<*>', '(<*>),', 'delay=<*>:<*>:<*>,', 'xdelay=<*>:<*>:<*>,', 'mailer=relay,', 'pri=<*>,', 'relay=[<*>]', '[<*>],', 'dsn=<*>,', 'stat=Deferred:', 'Connection', 'refused', 'by', '[<*>]']
# Row 115: session closed for user root
# ['session', 'closed', 'for', 'user', '<*>']
# Row 116: jA9J1WFE024258: from=root, size=1597080, class=0, nrcpts=1, msgid=<200511091901.jA9J1WFE024258@dadmin1>, relay=#7#@localhost
# ['<*>:', 'from=<*>,', 'size=<*>,', 'class=<*>,', 'nrcpts=<*>,', 'msgid=<*>,', 'relay=#<*>#@localhost']
# Row 117: jA9J1WFE024258: to=root, ctladdr=root (0/0), delay=00:00:03, xdelay=00:00:00, mailer=relay, pri=1627080, relay=[127.0.0.1] [127.0.0.1], dsn=4.0.0, stat=Deferred: Connection refused by [127.0.0.1]
# ['<*>:', 'to=<*>,', 'ctladdr=<*>', '(<*>),', 'delay=<*>:<*>:<*>,', 'xdelay=<*>:<*>:<*>,', 'mailer=relay,', 'pri=<*>,', 'relay=[<*>]', '[<*>],', 'dsn=<*>,', 'stat=Deferred:', 'Connection', 'refused', 'by', '[<*>]']
# Row 118: data_thread() got not answer from any [Thunderbird_C5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C5]', 'datasource']
# Row 119: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 120: data_thread() got not answer from any [Thunderbird_B4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B4]', 'datasource']
# Row 121: data_thread() got not answer from any [Thunderbird_C8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C8]', 'datasource']
# Row 122: data_thread() got not answer from any [Thunderbird_D5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D5]', 'datasource']
# Row 123: [ib_sm_sweep.c:1831]: ********************** NEW SWEEP ********************
# ['[ib_sm_sweep.c:<*>]:', '**********************', 'NEW', 'SWEEP', '********************']
# Row 124: unable to qualify my own domain name (aadmin1) -- using short name
# ['unable', 'to', 'qualify', 'my', 'own', 'domain', 'name', '(aadmin1)', '--', 'using', 'short', 'name']
# Row 125: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 126: session closed for user root
# ['session', 'closed', 'for', 'user', '<*>']
# Row 127: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1']
# Row 128: DHCPOFFER on 10.100.4.251 to 00:11:43:e3:ba:c3 via eth1
# ['DHCPOFFER', 'on', '<*>', 'to', '<*>', 'via', 'eth1']
# Row 129: jA9J1dQ7016560: from=root, size=1595423, class=0, nrcpts=1, msgid=<200511091901.jA9J1dQ7016560@aadmin1>, relay=#7#@localhost
# ['<*>:', 'from=<*>,', 'size=<*>,', 'class=<*>,', 'nrcpts=<*>,', 'msgid=<*>,', 'relay=#<*>#@localhost']
# Row 130: jA9J1dQ7016560: to=root, ctladdr=root (0/0), delay=00:00:02, xdelay=00:00:00, mailer=relay, pri=1625423, relay=[127.0.0.1] [127.0.0.1], dsn=4.0.0, stat=Deferred: Connection refused by [127.0.0.1]
# ['<*>:', 'to=<*>,', 'ctladdr=<*>', '(<*>),', 'delay=<*>:<*>:<*>,', 'xdelay=<*>:<*>:<*>,', 'mailer=relay,', 'pri=<*>,', 'relay=[<*>]', '[<*>],', 'dsn=<*>,', 'stat=Deferred:', 'Connection', 'refused', 'by', '[<*>]']
# Row 131: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1: network A_net: no free leases
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1:', 'network', 'A_net:', 'no', 'free', 'leases']
# Row 132: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1: network A_net: no free leases
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1:', 'network', 'A_net:', 'no', 'free', 'leases']
# Row 133: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1: network A_net: no free leases
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1:', 'network', 'A_net:', 'no', 'free', 'leases']
# Row 134: data_thread() got not answer from any [Thunderbird_B3] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B3]', 'datasource']
# Row 135: synchronized to 10.100.18.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 136: [ib_sm_sweep.c:1455]: No topology change
# ['[ib_sm_sweep.c:<*>]:', 'No', 'topology', 'change']
# Row 137: [ib_sm_sweep.c:1482]: No configuration change required
# ['[ib_sm_sweep.c:<*>]:', 'No', 'configuration', 'change', 'required']
# Row 138: DHCPACK on 10.100.4.251 to 00:11:43:e3:ba:c3 via eth1
# ['DHCPACK', 'on', '<*>', 'to', '<*>', 'via', 'eth1']
# Row 139: DHCPREQUEST for 10.100.4.251 (10.100.0.250) from 00:11:43:e3:ba:c3 via eth1
# ['DHCPREQUEST', 'for', '<*>', '(<*>)', 'from', '<*>', 'via', 'eth1']
# Row 140: START: tftp pid=16563 from=10.100.4.251
# ['START:', 'tftp', 'pid=<*>', 'from=<*>']
# Row 141: DHCPREQUEST for 10.100.4.251 (10.100.0.250) from 00:11:43:e3:ba:c3 via eth1: unknown lease 10.100.4.251.
# ['DHCPREQUEST', 'for', '<*>', '(<*>)', 'from', '<*>', 'via', 'eth1:', 'unknown', 'lease', '<*>']
# Row 142: DHCPREQUEST for 10.100.4.251 (10.100.0.250) from 00:11:43:e3:ba:c3 via eth1: unknown lease 10.100.4.251.
# ['DHCPREQUEST', 'for', '<*>', '(<*>)', 'from', '<*>', 'via', 'eth1:', 'unknown', 'lease', '<*>']
# Row 143: DHCPREQUEST for 10.100.4.251 (10.100.0.250) from 00:11:43:e3:ba:c3 via eth1: unknown lease 10.100.4.251.
# ['DHCPREQUEST', 'for', '<*>', '(<*>)', 'from', '<*>', 'via', 'eth1:', 'unknown', 'lease', '<*>']
# Row 144: synchronized to 10.100.30.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 145: data_thread() got not answer from any [Thunderbird_C2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C2]', 'datasource']
# Row 146: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 147: data_thread() got not answer from any [Thunderbird_B1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B1]', 'datasource']
# Row 148: data_thread() got not answer from any [Thunderbird_A1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A1]', 'datasource']
# Row 149: data_thread() got not answer from any [Thunderbird_C4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C4]', 'datasource']
# Row 150: synchronized to 10.100.30.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 151: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 152: data_thread() got not answer from any [Thunderbird_A5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A5]', 'datasource']
# Row 153: data_thread() got not answer from any [Thunderbird_C1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C1]', 'datasource']
# Row 154: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 155: synchronized to 10.100.18.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 156: synchronized to 10.100.18.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 157: data_thread() got not answer from any [Thunderbird_A6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A6]', 'datasource']
# Row 158: data_thread() got not answer from any [Thunderbird_D7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D7]', 'datasource']
# Row 159: data_thread() got not answer from any [Thunderbird_A3] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A3]', 'datasource']
# Row 160: data_thread() got not answer from any [Thunderbird_B6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B6]', 'datasource']
# Row 161: [ib_sm_sweep.c:1831]: ********************** NEW SWEEP ********************
# ['[ib_sm_sweep.c:<*>]:', '**********************', 'NEW', 'SWEEP', '********************']
# Row 162: data_thread() got not answer from any [Thunderbird_B2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B2]', 'datasource']
# Row 163: synchronized to 10.100.22.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 164: data_thread() got not answer from any [Thunderbird_B5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B5]', 'datasource']
# Row 165: data_thread() got not answer from any [Thunderbird_D6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D6]', 'datasource']
# Row 166: data_thread() got not answer from any [Thunderbird_D8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D8]', 'datasource']
# Row 167: [ib_sm_sweep.c:1455]: No topology change
# ['[ib_sm_sweep.c:<*>]:', 'No', 'topology', 'change']
# Row 168: [ib_sm_sweep.c:1482]: No configuration change required
# ['[ib_sm_sweep.c:<*>]:', 'No', 'configuration', 'change', 'required']
# Row 169: synchronized to 10.100.16.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 170: data_thread() got not answer from any [Thunderbird_A2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A2]', 'datasource']
# Row 171: data_thread() got not answer from any [Thunderbird_A7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A7]', 'datasource']
# Row 172: data_thread() got not answer from any [Thunderbird_B8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B8]', 'datasource']
# Row 173: data_thread() got not answer from any [Thunderbird_D4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D4]', 'datasource']
# Row 174: synchronized to 10.100.22.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 175: synchronized to 10.100.18.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 176: synchronized to 10.100.28.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 177: data_thread() got not answer from any [Thunderbird_C6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C6]', 'datasource']
# Row 178: synchronized to 10.100.16.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 179: synchronized to 10.100.22.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 180: data_thread() got not answer from any [Thunderbird_B7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B7]', 'datasource']
# Row 181: synchronized to 10.100.22.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 182: data_thread() got not answer from any [Thunderbird_A4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A4]', 'datasource']
# Row 183: data_thread() got not answer from any [Thunderbird_B4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B4]', 'datasource']
# Row 184: data_thread() got not answer from any [Thunderbird_C8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C8]', 'datasource']
# Row 185: synchronized to 10.100.24.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 186: data_thread() got not answer from any [Thunderbird_C5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C5]', 'datasource']
# Row 187: DHCPACK on 10.100.4.251 to 00:11:43:e3:ba:c3 via eth1
# ['DHCPACK', 'on', '<*>', 'to', '<*>', 'via', 'eth1']
# Row 188: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1']
# Row 189: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1']
# Row 190: DHCPOFFER on 10.100.4.251 to 00:11:43:e3:ba:c3 via eth1
# ['DHCPOFFER', 'on', '<*>', 'to', '<*>', 'via', 'eth1']
# Row 191: DHCPOFFER on 10.100.4.251 to 00:11:43:e3:ba:c3 via eth1
# ['DHCPOFFER', 'on', '<*>', 'to', '<*>', 'via', 'eth1']
# Row 192: DHCPREQUEST for 10.100.4.251 (10.100.0.250) from 00:11:43:e3:ba:c3 via eth1
# ['DHCPREQUEST', 'for', '<*>', '(<*>)', 'from', '<*>', 'via', 'eth1']
# Row 193: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1: network A_net: no free leases
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1:', 'network', 'A_net:', 'no', 'free', 'leases']
# Row 194: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1: network A_net: no free leases
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1:', 'network', 'A_net:', 'no', 'free', 'leases']
# Row 195: DHCPREQUEST for 10.100.4.251 (10.100.0.250) from 00:11:43:e3:ba:c3 via eth1: unknown lease 10.100.4.251.
# ['DHCPREQUEST', 'for', '<*>', '(<*>)', 'from', '<*>', 'via', 'eth1:', 'unknown', 'lease', '<*>']
# Row 196: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1: network A_net: no free leases
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1:', 'network', 'A_net:', 'no', 'free', 'leases']
# Row 197: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1: network A_net: no free leases
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1:', 'network', 'A_net:', 'no', 'free', 'leases']
# Row 198: DHCPREQUEST for 10.100.4.251 (10.100.0.250) from 00:11:43:e3:ba:c3 via eth1: unknown lease 10.100.4.251.
# ['DHCPREQUEST', 'for', '<*>', '(<*>)', 'from', '<*>', 'via', 'eth1:', 'unknown', 'lease', '<*>']
# Row 199: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1: network A_net: no free leases
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1:', 'network', 'A_net:', 'no', 'free', 'leases']
# Row 200: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1: network A_net: no free leases
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1:', 'network', 'A_net:', 'no', 'free', 'leases']
# Row 201: DHCPREQUEST for 10.100.4.251 (10.100.0.250) from 00:11:43:e3:ba:c3 via eth1: unknown lease 10.100.4.251.
# ['DHCPREQUEST', 'for', '<*>', '(<*>)', 'from', '<*>', 'via', 'eth1:', 'unknown', 'lease', '<*>']
# Row 202: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 203: data_thread() got not answer from any [Thunderbird_A8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A8]', 'datasource']
# Row 204: [ib_sm_sweep.c:1831]: ********************** NEW SWEEP ********************
# ['[ib_sm_sweep.c:<*>]:', '**********************', 'NEW', 'SWEEP', '********************']
# Row 205: DHCPACK on 10.100.4.251 to 00:11:43:e3:ba:c3 via eth1
# ['DHCPACK', 'on', '<*>', 'to', '<*>', 'via', 'eth1']
# Row 206: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1']
# Row 207: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1']
# Row 208: DHCPOFFER on 10.100.4.251 to 00:11:43:e3:ba:c3 via eth1
# ['DHCPOFFER', 'on', '<*>', 'to', '<*>', 'via', 'eth1']
# Row 209: DHCPOFFER on 10.100.4.251 to 00:11:43:e3:ba:c3 via eth1
# ['DHCPOFFER', 'on', '<*>', 'to', '<*>', 'via', 'eth1']
# Row 210: DHCPREQUEST for 10.100.4.251 (10.100.0.250) from 00:11:43:e3:ba:c3 via eth1
# ['DHCPREQUEST', 'for', '<*>', '(<*>)', 'from', '<*>', 'via', 'eth1']
# Row 211: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1: network A_net: no free leases
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1:', 'network', 'A_net:', 'no', 'free', 'leases']
# Row 212: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1: network A_net: no free leases
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1:', 'network', 'A_net:', 'no', 'free', 'leases']
# Row 213: DHCPREQUEST for 10.100.4.251 (10.100.0.250) from 00:11:43:e3:ba:c3 via eth1: unknown lease 10.100.4.251.
# ['DHCPREQUEST', 'for', '<*>', '(<*>)', 'from', '<*>', 'via', 'eth1:', 'unknown', 'lease', '<*>']
# Row 214: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1: network A_net: no free leases
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1:', 'network', 'A_net:', 'no', 'free', 'leases']
# Row 215: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1: network A_net: no free leases
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1:', 'network', 'A_net:', 'no', 'free', 'leases']
# Row 216: DHCPREQUEST for 10.100.4.251 (10.100.0.250) from 00:11:43:e3:ba:c3 via eth1: unknown lease 10.100.4.251.
# ['DHCPREQUEST', 'for', '<*>', '(<*>)', 'from', '<*>', 'via', 'eth1:', 'unknown', 'lease', '<*>']
# Row 217: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1: network A_net: no free leases
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1:', 'network', 'A_net:', 'no', 'free', 'leases']
# Row 218: DHCPDISCOVER from 00:11:43:e3:ba:c3 via eth1: network A_net: no free leases
# ['DHCPDISCOVER', 'from', '<*>', 'via', 'eth1:', 'network', 'A_net:', 'no', 'free', 'leases']
# Row 219: DHCPREQUEST for 10.100.4.251 (10.100.0.250) from 00:11:43:e3:ba:c3 via eth1: unknown lease 10.100.4.251.
# ['DHCPREQUEST', 'for', '<*>', '(<*>)', 'from', '<*>', 'via', 'eth1:', 'unknown', 'lease', '<*>']
# Row 220: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 221: synchronized to 10.100.30.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 222: data_thread() got not answer from any [Thunderbird_D5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D5]', 'datasource']
# Row 223: synchronized to 10.100.18.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 224: [ib_sm_sweep.c:1455]: No topology change
# ['[ib_sm_sweep.c:<*>]:', 'No', 'topology', 'change']
# Row 225: [ib_sm_sweep.c:1482]: No configuration change required
# ['[ib_sm_sweep.c:<*>]:', 'No', 'configuration', 'change', 'required']
# Row 226: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 227: data_thread() got not answer from any [Thunderbird_C2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C2]', 'datasource']
# Row 228: data_thread() got not answer from any [Thunderbird_C4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C4]', 'datasource']
# Row 229: data_thread() got not answer from any [Thunderbird_B3] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B3]', 'datasource']
# Row 230: synchronized to 10.100.22.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 231: data_thread() got not answer from any [Thunderbird_A1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A1]', 'datasource']
# Row 232: synchronized to 10.100.22.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 233: data_thread() got not answer from any [Thunderbird_A6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A6]', 'datasource']
# Row 234: data_thread() got not answer from any [Thunderbird_B1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B1]', 'datasource']
# Row 235: data_thread() got not answer from any [Thunderbird_A3] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A3]', 'datasource']
# Row 236: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 237: data_thread() got not answer from any [Thunderbird_C1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C1]', 'datasource']
# Row 238: data_thread() got not answer from any [Thunderbird_A5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A5]', 'datasource']
# Row 239: data_thread() got not answer from any [Thunderbird_D7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D7]', 'datasource']
# Row 240: [ib_sm_sweep.c:1831]: ********************** NEW SWEEP ********************
# ['[ib_sm_sweep.c:<*>]:', '**********************', 'NEW', 'SWEEP', '********************']
# Row 241: data_thread() got not answer from any [Thunderbird_D6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D6]', 'datasource']
# Row 242: synchronized to 10.100.30.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 243: data_thread() got not answer from any [Thunderbird_A2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A2]', 'datasource']
# Row 244: data_thread() got not answer from any [Thunderbird_B5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B5]', 'datasource']
# Row 245: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 246: synchronized to 10.100.18.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 247: [ib_sm_sweep.c:1455]: No topology change
# ['[ib_sm_sweep.c:<*>]:', 'No', 'topology', 'change']
# Row 248: [ib_sm_sweep.c:1482]: No configuration change required
# ['[ib_sm_sweep.c:<*>]:', 'No', 'configuration', 'change', 'required']
# Row 249: data_thread() got not answer from any [Thunderbird_B6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B6]', 'datasource']
# Row 250: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 251: data_thread() got not answer from any [Thunderbird_D4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D4]', 'datasource']
# Row 252: data_thread() got not answer from any [Thunderbird_B2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B2]', 'datasource']
# Row 253: data_thread() got not answer from any [Thunderbird_B7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B7]', 'datasource']
# Row 254: data_thread() got not answer from any [Thunderbird_C6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C6]', 'datasource']
# Row 255: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 256: data_thread() got not answer from any [Thunderbird_A7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A7]', 'datasource']
# Row 257: data_thread() got not answer from any [Thunderbird_D8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D8]', 'datasource']
# Row 258: data_thread() got not answer from any [Thunderbird_B8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B8]', 'datasource']
# Row 259: data_thread() got not answer from any [Thunderbird_C8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C8]', 'datasource']
# Row 260: data_thread() got not answer from any [Thunderbird_A4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A4]', 'datasource']
# Row 261: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 262: synchronized to 10.100.28.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 263: data_thread() got not answer from any [Thunderbird_B4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B4]', 'datasource']
# Row 264: data_thread() got not answer from any [Thunderbird_C5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C5]', 'datasource']
# Row 265: data_thread() got not answer from any [Thunderbird_D5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D5]', 'datasource']
# Row 266: [ib_sm_sweep.c:1831]: ********************** NEW SWEEP ********************
# ['[ib_sm_sweep.c:<*>]:', '**********************', 'NEW', 'SWEEP', '********************']
# Row 267: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 268: data_thread() got not answer from any [Thunderbird_A8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A8]', 'datasource']
# Row 269: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 270: [ib_sm_sweep.c:1455]: No topology change
# ['[ib_sm_sweep.c:<*>]:', 'No', 'topology', 'change']
# Row 271: [ib_sm_sweep.c:1482]: No configuration change required
# ['[ib_sm_sweep.c:<*>]:', 'No', 'configuration', 'change', 'required']
# Row 272: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 273: synchronized to 10.100.16.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 274: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 275: synchronized to 10.100.22.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 276: data_thread() got not answer from any [Thunderbird_C4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C4]', 'datasource']
# Row 277: data_thread() got not answer from any [Thunderbird_B3] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B3]', 'datasource']
# Row 278: data_thread() got not answer from any [Thunderbird_C2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C2]', 'datasource']
# Row 279: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 280: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 281: data_thread() got not answer from any [Thunderbird_A6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A6]', 'datasource']
# Row 282: data_thread() got not answer from any [Thunderbird_B5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B5]', 'datasource']
# Row 283: synchronized to 10.100.22.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 284: data_thread() got not answer from any [Thunderbird_A1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A1]', 'datasource']
# Row 285: data_thread() got not answer from any [Thunderbird_A5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A5]', 'datasource']
# Row 286: data_thread() got not answer from any [Thunderbird_B1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B1]', 'datasource']
# Row 287: [ib_sm_sweep.c:1831]: ********************** NEW SWEEP ********************
# ['[ib_sm_sweep.c:<*>]:', '**********************', 'NEW', 'SWEEP', '********************']
# Row 288: data_thread() got not answer from any [Thunderbird_C1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C1]', 'datasource']
# Row 289: synchronized to 10.100.16.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 290: data_thread() got not answer from any [Thunderbird_A3] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A3]', 'datasource']
# Row 291: synchronized to 10.100.16.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 292: data_thread() got not answer from any [Thunderbird_B6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B6]', 'datasource']
# Row 293: [ib_sm_sweep.c:1455]: No topology change
# ['[ib_sm_sweep.c:<*>]:', 'No', 'topology', 'change']
# Row 294: [ib_sm_sweep.c:1482]: No configuration change required
# ['[ib_sm_sweep.c:<*>]:', 'No', 'configuration', 'change', 'required']
# Row 295: data_thread() got not answer from any [Thunderbird_B2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B2]', 'datasource']
# Row 296: data_thread() got not answer from any [Thunderbird_C6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C6]', 'datasource']
# Row 297: data_thread() got not answer from any [Thunderbird_D7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D7]', 'datasource']
# Row 298: data_thread() got not answer from any [Thunderbird_D4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D4]', 'datasource']
# Row 299: data_thread() got not answer from any [Thunderbird_D6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D6]', 'datasource']
# Row 300: synchronized to 10.100.22.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 301: data_thread() got not answer from any [Thunderbird_A2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A2]', 'datasource']
# Row 302: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 303: synchronized to 10.100.22.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 304: data_thread() got not answer from any [Thunderbird_A4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A4]', 'datasource']
# Row 305: data_thread() got not answer from any [Thunderbird_A7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A7]', 'datasource']
# Row 306: data_thread() got not answer from any [Thunderbird_D8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D8]', 'datasource']
# Row 307: synchronized to 10.100.18.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 308: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 309: data_thread() got not answer from any [Thunderbird_B7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B7]', 'datasource']
# Row 310: data_thread() got not answer from any [Thunderbird_B8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B8]', 'datasource']
# Row 311: data_thread() got not answer from any [Thunderbird_C8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C8]', 'datasource']
# Row 312: synchronized to 10.100.16.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 313: data_thread() got not answer from any [Thunderbird_B4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B4]', 'datasource']
# Row 314: [ib_sm_sweep.c:1831]: ********************** NEW SWEEP ********************
# ['[ib_sm_sweep.c:<*>]:', '**********************', 'NEW', 'SWEEP', '********************']
# Row 315: data_thread() got not answer from any [Thunderbird_A8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A8]', 'datasource']
# Row 316: data_thread() got not answer from any [Thunderbird_D5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D5]', 'datasource']
# Row 317: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 318: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 319: [ib_sm_sweep.c:1455]: No topology change
# ['[ib_sm_sweep.c:<*>]:', 'No', 'topology', 'change']
# Row 320: [ib_sm_sweep.c:1482]: No configuration change required
# ['[ib_sm_sweep.c:<*>]:', 'No', 'configuration', 'change', 'required']
# Row 321: data_thread() got not answer from any [Thunderbird_C4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C4]', 'datasource']
# Row 322: data_thread() got not answer from any [Thunderbird_C5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C5]', 'datasource']
# Row 323: data_thread() got not answer from any [Thunderbird_B3] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B3]', 'datasource']
# Row 324: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 325: data_thread() got not answer from any [Thunderbird_A6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A6]', 'datasource']
# Row 326: data_thread() got not answer from any [Thunderbird_A1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A1]', 'datasource']
# Row 327: data_thread() got not answer from any [Thunderbird_C2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C2]', 'datasource']
# Row 328: data_thread() got not answer from any [Thunderbird_C1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C1]', 'datasource']
# Row 329: synchronized to 10.100.14.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 330: data_thread() got not answer from any [Thunderbird_A5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A5]', 'datasource']
# Row 331: [ib_sm_sweep.c:1831]: ********************** NEW SWEEP ********************
# ['[ib_sm_sweep.c:<*>]:', '**********************', 'NEW', 'SWEEP', '********************']
# Row 332: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 333: data_thread() got not answer from any [Thunderbird_B5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B5]', 'datasource']
# Row 334: data_thread() got not answer from any [Thunderbird_B6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B6]', 'datasource']
# Row 335: data_thread() got not answer from any [Thunderbird_B1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B1]', 'datasource']
# Row 336: [ib_sm_sweep.c:1455]: No topology change
# ['[ib_sm_sweep.c:<*>]:', 'No', 'topology', 'change']
# Row 337: [ib_sm_sweep.c:1482]: No configuration change required
# ...
# Row 1888: synchronized to 10.100.16.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1889: data_thread() got not answer from any [Thunderbird_C2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C2]', 'datasource']
# Row 1890: data_thread() got not answer from any [Thunderbird_B1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B1]', 'datasource']
# Row 1891: data_thread() got not answer from any [Thunderbird_A2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A2]', 'datasource']
# Row 1892: data_thread() got not answer from any [Thunderbird_A3] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A3]', 'datasource']
# Row 1893: [ib_sm_sweep.c:1831]: ********************** NEW SWEEP ********************
# ['[ib_sm_sweep.c:<*>]:', '**********************', 'NEW', 'SWEEP', '********************']
# Row 1894: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1895: data_thread() got not answer from any [Thunderbird_B6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B6]', 'datasource']
# Row 1896: data_thread() got not answer from any [Thunderbird_D7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D7]', 'datasource']
# Row 1897: synchronized to 10.100.26.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1898: [ib_sm_sweep.c:1455]: No topology change
# ['[ib_sm_sweep.c:<*>]:', 'No', 'topology', 'change']
# Row 1899: [ib_sm_sweep.c:1482]: No configuration change required
# ['[ib_sm_sweep.c:<*>]:', 'No', 'configuration', 'change', 'required']
# Row 1900: data_thread() got not answer from any [Thunderbird_A1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A1]', 'datasource']
# Row 1901: data_thread() got not answer from any [Thunderbird_B2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B2]', 'datasource']
# Row 1902: data_thread() got not answer from any [Thunderbird_A7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A7]', 'datasource']
# Row 1903: data_thread() got not answer from any [Thunderbird_C1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C1]', 'datasource']
# Row 1904: data_thread() got not answer from any [Thunderbird_A8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A8]', 'datasource']
# Row 1905: data_thread() got not answer from any [Thunderbird_B8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B8]', 'datasource']
# Row 1906: data_thread() got not answer from any [Thunderbird_D5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D5]', 'datasource']
# Row 1907: data_thread() got not answer from any [Thunderbird_B3] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B3]', 'datasource']
# Row 1908: synchronized to 10.100.26.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1909: data_thread() got not answer from any [Thunderbird_C8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C8]', 'datasource']
# Row 1910: synchronized to 10.100.26.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1911: data_thread() got not answer from any [Thunderbird_B7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B7]', 'datasource']
# Row 1912: [ib_sm_sweep.c:1831]: ********************** NEW SWEEP ********************
# ['[ib_sm_sweep.c:<*>]:', '**********************', 'NEW', 'SWEEP', '********************']
# Row 1913: data_thread() got not answer from any [Thunderbird_C6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C6]', 'datasource']
# Row 1914: data_thread() got not answer from any [Thunderbird_A6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A6]', 'datasource']
# Row 1915: data_thread() got not answer from any [Thunderbird_B4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B4]', 'datasource']
# Row 1916: data_thread() got not answer from any [Thunderbird_D8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D8]', 'datasource']
# Row 1917: data_thread() got not answer from any [Thunderbird_D4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D4]', 'datasource']
# Row 1918: [ib_sm_sweep.c:1455]: No topology change
# ['[ib_sm_sweep.c:<*>]:', 'No', 'topology', 'change']
# Row 1919: [ib_sm_sweep.c:1482]: No configuration change required
# ['[ib_sm_sweep.c:<*>]:', 'No', 'configuration', 'change', 'required']
# Row 1920: synchronized to 10.100.18.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1921: synchronized to 10.100.22.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1922: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1923: synchronized to 10.100.18.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1924: synchronized to 10.100.22.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1925: synchronized to 10.100.30.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1926: data_thread() got not answer from any [Thunderbird_D6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D6]', 'datasource']
# Row 1927: data_thread() got not answer from any [Thunderbird_C2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C2]', 'datasource']
# Row 1928: data_thread() got not answer from any [Thunderbird_B5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B5]', 'datasource']
# Row 1929: data_thread() got not answer from any [Thunderbird_C4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C4]', 'datasource']
# Row 1930: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1931: synchronized to 10.100.10.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1932: data_thread() got not answer from any [Thunderbird_A3] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A3]', 'datasource']
# Row 1933: synchronized to 10.100.18.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1934: data_thread() got not answer from any [Thunderbird_A5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A5]', 'datasource']
# Row 1935: data_thread() got not answer from any [Thunderbird_B1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B1]', 'datasource']
# Row 1936: data_thread() got not answer from any [Thunderbird_B6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B6]', 'datasource']
# Row 1937: [ib_sm_sweep.c:1831]: ********************** NEW SWEEP ********************
# ['[ib_sm_sweep.c:<*>]:', '**********************', 'NEW', 'SWEEP', '********************']
# Row 1938: data_thread() got not answer from any [Thunderbird_A4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A4]', 'datasource']
# Row 1939: synchronized to 10.100.16.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1940: data_thread() got not answer from any [Thunderbird_A2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A2]', 'datasource']
# Row 1941: data_thread() got not answer from any [Thunderbird_C5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C5]', 'datasource']
# Row 1942: data_thread() got not answer from any [Thunderbird_D7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D7]', 'datasource']
# Row 1943: [ib_sm_sweep.c:1455]: No topology change
# ['[ib_sm_sweep.c:<*>]:', 'No', 'topology', 'change']
# Row 1944: [ib_sm_sweep.c:1482]: No configuration change required
# ['[ib_sm_sweep.c:<*>]:', 'No', 'configuration', 'change', 'required']
# Row 1945: data_thread() got not answer from any [Thunderbird_B8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B8]', 'datasource']
# Row 1946: data_thread() got not answer from any [Thunderbird_A8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A8]', 'datasource']
# Row 1947: data_thread() got not answer from any [Thunderbird_B2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B2]', 'datasource']
# Row 1948: synchronized to 10.100.16.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1949: synchronized to 10.100.16.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1950: data_thread() got not answer from any [Thunderbird_A7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A7]', 'datasource']
# Row 1951: data_thread() got not answer from any [Thunderbird_C1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C1]', 'datasource']
# Row 1952: Device: /dev/sda, Temperature changed -2 Celsius to 26 Celsius since last report
# ['Device:', '/dev/sda,', 'Temperature', 'changed', '<*>', 'Celsius', 'to', '<*>', 'Celsius', 'since', 'last', 'report']
# Row 1953: data_thread() got not answer from any [Thunderbird_A1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A1]', 'datasource']
# Row 1954: data_thread() got not answer from any [Thunderbird_C8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C8]', 'datasource']
# Row 1955: synchronized to 10.100.22.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1956: data_thread() got not answer from any [Thunderbird_B7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B7]', 'datasource']
# Row 1957: data_thread() got not answer from any [Thunderbird_C6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C6]', 'datasource']
# Row 1958: synchronized to 10.100.18.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1959: data_thread() got not answer from any [Thunderbird_B3] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B3]', 'datasource']
# Row 1960: data_thread() got not answer from any [Thunderbird_D5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D5]', 'datasource']
# Row 1961: [ib_sm_sweep.c:1831]: ********************** NEW SWEEP ********************
# ['[ib_sm_sweep.c:<*>]:', '**********************', 'NEW', 'SWEEP', '********************']
# Row 1962: data_thread() got not answer from any [Thunderbird_D8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D8]', 'datasource']
# Row 1963: data_thread() got not answer from any [Thunderbird_B4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B4]', 'datasource']
# Row 1964: [ib_sm_sweep.c:1455]: No topology change
# ['[ib_sm_sweep.c:<*>]:', 'No', 'topology', 'change']
# Row 1965: [ib_sm_sweep.c:1482]: No configuration change required
# ['[ib_sm_sweep.c:<*>]:', 'No', 'configuration', 'change', 'required']
# Row 1966: data_thread() got not answer from any [Thunderbird_D4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D4]', 'datasource']
# Row 1967: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1968: data_thread() got not answer from any [Thunderbird_A6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A6]', 'datasource']
# Row 1969: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1970: data_thread() got not answer from any [Thunderbird_C2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C2]', 'datasource']
# Row 1971: synchronized to 10.100.16.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1972: data_thread() got not answer from any [Thunderbird_D6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D6]', 'datasource']
# Row 1973: synchronized to 10.100.22.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1974: synchronized to 10.100.18.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1975: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1976: data_thread() got not answer from any [Thunderbird_A5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A5]', 'datasource']
# Row 1977: synchronized to 10.100.16.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1978: data_thread() got not answer from any [Thunderbird_A4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A4]', 'datasource']
# Row 1979: data_thread() got not answer from any [Thunderbird_C4] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_C4]', 'datasource']
# Row 1980: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1981: data_thread() got not answer from any [Thunderbird_B1] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B1]', 'datasource']
# Row 1982: [ib_sm_sweep.c:1831]: ********************** NEW SWEEP ********************
# ['[ib_sm_sweep.c:<*>]:', '**********************', 'NEW', 'SWEEP', '********************']
# Row 1983: data_thread() got not answer from any [Thunderbird_A3] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A3]', 'datasource']
# Row 1984: data_thread() got not answer from any [Thunderbird_B5] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B5]', 'datasource']
# Row 1985: synchronized to 10.100.24.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1986: synchronized to 10.100.30.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1987: data_thread() got not answer from any [Thunderbird_B2] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B2]', 'datasource']
# Row 1988: data_thread() got not answer from any [Thunderbird_B6] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_B6]', 'datasource']
# Row 1989: data_thread() got not answer from any [Thunderbird_A8] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_A8]', 'datasource']
# Row 1990: [ib_sm_sweep.c:1455]: No topology change
# ['[ib_sm_sweep.c:<*>]:', 'No', 'topology', 'change']
# Row 1991: [ib_sm_sweep.c:1482]: No configuration change required
# ['[ib_sm_sweep.c:<*>]:', 'No', 'configuration', 'change', 'required']
# Row 1992: synchronized to 10.100.12.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1993: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1994: synchronized to 10.100.16.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1995: synchronized to 10.100.22.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1996: data_thread() got not answer from any [Thunderbird_D7] datasource
# ['data_thread()', 'got', 'not', 'answer', 'from', 'any', '[Thunderbird_D7]', 'datasource']
# Row 1997: synchronized to 10.100.16.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1998: synchronized to 10.100.22.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']
# Row 1999: synchronized to 10.100.20.250, stratum 3
# ['synchronized', 'to', '<*>,', 'stratum', '<*>']

# %%
# for key, val in logTemplate.items():
#     print(f"{key}:\n{val}")


trust_df = pd.read_csv("./logs2k/HDFS/HDFS_2k.log_structured_corrected.csv")

grouped_indices = trust_df.groupby('EventTemplate').apply(lambda x: x.index.tolist())

# for key, val in grouped_indices.items():
#     print(f"{key}:\n{val}")

temp = []
print(len(grouped_indices), len(logTemplate))
for key, val in grouped_indices.items():
    if key in logTemplate.keys():
        temp.append(key)
        # print(f"Trust: {val}\nParse: {logTemplate[key]}")

for key, val in logTemplate.items():
    if key not in temp:
        print(f"{key}:\n{val}")
# Out:
# 14 267
# session closed for user <*>:
# [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 42, 96, 107, 112, 115, 126, 1568, 1578, 1581, 1586, 1591]
# session opened for user <*> by (uid=<*>):
# [1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 43, 1099, 1101, 1103, 1105, 1107]
# (<*>) CMD (run-parts /etc/cron.hourly):
# [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 44]
# data_thread() got not answer from any [Thunderbird_A8] datasource:
# [39, 104, 203, 268, 315, 353, 399, 462, 537, 599, 650, 708, 766, 819, 875, 930, 993, 1046, 1097, 1172, 1414, 1524, 1585, 1642, 1693, 1752, 1804, 1856, 1904, 1946, 1989]
# data_thread() got not answer from any [Thunderbird_B8] datasource:
# [40, 87, 172, 258, 310, 354, 416, 470, 549, 597, 647, 704, 763, 813, 874, 931, 985, 1038, 1090, 1151, 1422, 1468, 1549, 1625, 1672, 1713, 1763, 1816, 1863, 1905, 1945]
# data_thread() got not answer from any [Thunderbird_C5] datasource:
# [78, 162, 252, 295, 343, 405, 463, 541, 600, 651, 700, 746, 798, 853, 899, 967, 1015, 1077, 1140, 1378, 1416, 1545, 1618, 1676, 1736, 1800, 1861, 1901, 1947, 1987]
# data_thread() got not answer from any [Thunderbird_C1] datasource:
# [79, 153, 237, 288, 328, 371, 437, 498, 560, 615, 678, 736, 791, 849, 895, 955, 1011, 1067, 1122, 1361, 1423, 1533, 1601, 1657, 1712, 1760, 1817, 1864, 1903, 1951]
# data_thread() got not answer from any [Thunderbird_C4] datasource:
# [80, 149, 228, 276, 321, 369, 425, 476, 556, 616, 666, 718, 780, 827, 867, 924, 975, 1039, 1088, 1142, 1373, 1425, 1535, 1605, 1660, 1715, 1761, 1821, 1875, 1929, 1979]
# data_thread() got not answer from any [Thunderbird_D7] datasource:
# [81, 158, 239, 297, 347, 411, 465, 531, 580, 637, 706, 750, 811, 868, 926, 977, 1047, 1093, 1147, 1433, 1475, 1550, 1635, 1689, 1748, 1797, 1853, 1896, 1942, 1996]
# data_thread() got not answer from any [Thunderbird_A7] datasource:
# [82, 171, 256, 305, 342, 404, 461, 532, 589, 632, 694, 749, 809, 857, 909, 963, 1018, 1083, 1134, 1367, 1413, 1541, 1621, 1671, 1725, 1790, 1846, 1902, 1950]
# data_thread() got not answer from any [Thunderbird_D6] datasource:
# [85, 165, 241, 299, 341, 387, 449, 520, 581, 631, 692, 740, 799, 854, 906, 964, 1012, 1068, 1130, 1365, 1432, 1544, 1613, 1670, 1727, 1770, 1823, 1878, 1926, 1972]
# data_thread() got not answer from any [Thunderbird_B5] datasource:
# [86, 164, 244, 282, 333, 381, 448, 519, 587, 636, 691, 753, 807, 856, 904, 960, 1021, 1087, 1154, 1385, 1419, 1546, 1612, 1669, 1724, 1784, 1837, 1879, 1928, 1984]
# data_thread() got not answer from any [Thunderbird_D4] datasource:
# [88, 173, 251, 298, 340, 386, 445, 526, 588, 634, 688, 747, 803, 859, 913, 965, 1026, 1092, 1144, 1374, 1430, 1547, 1629, 1674, 1722, 1764, 1828, 1872, 1917, 1966]
# data_thread() got not answer from any [Thunderbird_C6] datasource:
# [89, 177, 254, 296, 346, 394, 468, 534, 598, 646, 705, 755, 808, 858, 915, 981, 1041, 1091, 1155, 1403, 1427, 1555, 1624, 1673, 1730, 1778, 1826, 1868, 1913, 1957]
# data_thread() got not answer from any [Thunderbird_D8] datasource:
# [92, 166, 257, 306, 355, 401, 453, 516, 575, 629, 695, 742, 792, 840, 884, 932, 992, 1052, 1098, 1158, 1434, 1460, 1551, 1616, 1664, 1719, 1775, 1825, 1867, 1916, 1962]
# unable to qualify my own domain name (eadmin1) -- using short name:
# [95, 1571]
# <*>: from=<*>, size=<*>, class=<*>, nrcpts=<*>, msgid=<*>, relay=#<*>#@localhost:
# [97, 108, 113, 116, 129, 1569, 1579, 1582, 1587, 1592]
# <*>: to=<*>, ctladdr=<*> (<*>), delay=<*>:<*>:<*>, xdelay=<*>:<*>:<*>, mailer=relay, pri=<*>, relay=[<*>] [<*>], dsn=<*>, stat=Deferred: Connection refused by [<*>]:
# [98, 109, 114, 117, 130, 1570, 1580, 1583, 1588, 1593]
# data_thread() got not answer from any [Thunderbird_A2] datasource:
# [99, 170, 243, 301, 338, 390, 440, 514, 574, 614, 662, 716, 779, 820, 869, 918, 972, 1020, 1078, 1146, 1384, 1408, 1557, 1636, 1682, 1741, 1812, 1845, 1891, 1940]
# unable to qualify my own domain name (badmin1) -- using short name:
# [100, 1574]
# unable to qualify my own domain name (cadmin1) -- using short name:
# [101, 1576]
# unable to qualify my own domain name (dadmin1) -- using short name:
# [103, 1577]
# unable to qualify my own domain name (aadmin1) -- using short name:
# [124, 1573]
# DHCPDISCOVER from <*> via eth1:
# [127, 188, 189, 206, 207]
# DHCPOFFER on <*> to <*> via eth1:
# [128, 190, 191, 208, 209]
# DHCPDISCOVER from <*> via eth1: network A_net: no free leases:
# [131, 132, 133, 193, 194, 196, 197, 199, 200, 211, 212, 214, 215, 217, 218]
# DHCPACK on <*> to <*> via eth1:
# [138, 187, 205]
# DHCPREQUEST for <*> (<*>) from <*> via eth1:
# [139, 192, 210]
# START: tftp pid=<*> from=<*>:
# [140]
# DHCPREQUEST for <*> (<*>) from <*> via eth1: unknown lease <*>:
# [141, 142, 143, 195, 198, 201, 213, 216, 219]
# RRD_update (<*> Nodes/cn304/pkts_out.rrd): illegal attempt to update using time <*> when last update time is <*> (minimum one second step):
# [403]
# kernel time sync disabled <*>:
# [458]
# time reset <*> s:
# [459]
# RRD_update (<*> Nodes/dn731/pkts_out.rrd): illegal attempt to update using time <*> when last update time is <*> (minimum one second step):
# [518, 578, 630, 942, 1004, 1124, 1405, 1532]
# Received SNMP packet(s) from #<*>#:
# [565]
# synchronized to LOCAL(<*>), stratum <*>:
# [953]
# kernel time sync enabled <*>:
# [956]
# synchronized to #<*>#, stratum <*>:
# [957]
# (<*>) CMD (<*> a):
# [1100]
# (<*>) CMD (<*> b):
# [1102]
# (<*>) CMD (<*> c):
# [1104]
# (<*>) CMD (<*> d):
# [1106]
# (<*>) CMD (<*> e):
# [1108]
# My unqualified host name (eadmin1) unknown; sleeping for retry:
# [1161]
# My unqualified host name (aadmin1) unknown; sleeping for retry:
# [1162]
# My unqualified host name (badmin1) unknown; sleeping for retry:
# [1163]
# My unqualified host name (cadmin1) unknown; sleeping for retry:
# [1167]
# My unqualified host name (dadmin1) unknown; sleeping for retry:
# [1169]
# <*> (Kernel Module GPG key):
# [1181]
# (supports S0 S4 S5):
# [1182]
# DSDT (v001 DELL PE BKC <*> MSFT <*>) @ <*>:
# [1183]
# FADT (v001 DELL PE BKC <*> MSFT <*>) @ <*>:
# [1184]
# HPET (v001 DELL PE BKC <*> MSFT <*>) @ <*>:
# [1185]
# HPET id: <*> base: <*>:
# [1186]
# INT_SRC_OVR (bus <*> bus_irq <*> global_irq <*> dfl dfl):
# [1187]
# INT_SRC_OVR (bus <*> bus_irq <*> global_irq <*> high level):
# [1188]
# IOAPIC (id[<*>] address[<*>] gsi_base[<*>]):
# [1189, 1190, 1191]
# IRQ0 used by override.:
# [1192]
# IRQ2 used by override.:
# [1193]
# IRQ9 used by override.:
# [1194]
# Interpreter enabled:
# [1195]
# LAPIC (acpi_id[<*>] lapic_id[<*>] enabled):
# [1196, 1197, 1198, 1199]
# LAPIC_NMI (acpi_id[<*>] high edge lint[<*>]):
# [1200, 1201, 1202, 1203]
# Local APIC address <*>:
# [1204]
# MADT (v001 DELL PE BKC <*> MSFT <*>) @ <*>:
# [1205]
# MCFG (v001 DELL PE BKC <*> MSFT <*>) @ <*>:
# [1206]
# PCI Interrupt Link [LNKA] (IRQs <*> <*> <*> <*> <*> <*> <*> <*>) <*>:
# [1207]
# PCI Interrupt Link [LNKB] (IRQs <*> <*> <*> <*> <*> <*> <*> <*>):
# [1208]
# PCI Interrupt Link [LNKC] (IRQs <*> <*> <*> <*> <*> <*> <*> <*>) <*>:
# [1209]
# PCI Interrupt Link [LNKD] (IRQs <*> <*> <*> <*> <*> <*> <*> <*>) <*>, disabled.:
# [1210]
# PCI Interrupt Link [LNKE] (IRQs <*> <*> <*> <*> <*> <*> <*> <*>) <*>, disabled.:
# [1211]
# PCI Interrupt Link [LNKF] (IRQs <*> <*> <*> <*> <*> <*> <*> <*>) <*>, disabled.:
# [1212]
# PCI Interrupt Link [LNKG] (IRQs <*> <*> <*> <*> <*> <*> <*> <*>) <*>, disabled.:
# [1213]
# PCI Interrupt Link [LNKH] (IRQs <*> <*> <*> <*> <*> <*> <*> <*>) <*>, disabled.:
# [1214]
# PCI Interrupt Routing Table [\_SB_.PCI0.PALO.DOBA._PRT]:
# [1215]
# PCI Interrupt Routing Table [\_SB_.PCI0.PALO.DOBB._PRT]:
# [1216]
# PCI Interrupt Routing Table [\_SB_.PCI0.PALO._PRT]:
# [1217]
# PCI Interrupt Routing Table [<*>]:
# [1218, 1219, 1223]
# PCI Interrupt Routing Table [\_SB_.PCI0.PBHI._PRT]:
# [1220]
# PCI Interrupt Routing Table [\_SB_.PCI0.PBLO._PRT]:
# [1221]
# PCI Interrupt Routing Table [\_SB_.PCI0.PICH._PRT]:
# [1222]
# PCI Interrupt Routing Table [\_SB_.PCI0._PRT]:
# [1224]
# PCI Root Bridge [PCI0] (<*>:<*>):
# [1225]
# PCI interrupt <*>:<*>:<*>[A] -> GSI <*> (level, low) -> IRQ <*>:
# [1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236]
# Power Button (FF) [PWRF]:
# [1237]
# Processor [CPU0] (supports C1):
# [1238]
# Processor [CPU1] (supports C1):
# [1239]
# Processor [CPU2] (supports C1):
# [1240]
# Processor [CPU3] (supports C1):
# [1241]
# RSDP (v000 DELL ) @ <*>:
# [1242]
# RSDT (v001 DELL PE BKC <*> MSFT <*>) @ <*>:
# [1243]
# SPCR (v001 DELL PE BKC <*> MSFT <*>) @ <*>:
# [1244]
# Subsystem revision <*>:
# [1245]
# Using IOAPIC for interrupt routing:
# [1246]
# Intel(R) Xeon(TM) CPU <*> stepping <*>:
# [1247]
# L2 cache: <*>:
# [1248, 1249, 1250, 1251, 1252]
# Physical Processor ID: <*>:
# [1253, 1254, 1255, 1256, 1257]
# Trace cache: <*> uops, L1 D cache: <*>:
# [1258, 1259, 1260, 1261, 1262]
# colour VGA+ <*>:
# [1263]
# mounted filesystem with ordered data mode.:
# [1264, 1265, 1266]
# sys_ia32.c,v <*> <*> <*>:<*>:<*> ak Exp $:
# [1267]
# apic_id <*>, version <*>, address <*>, GSI <*>:
# [1268, 1269, 1270]
# routing cache hash table of <*> buckets, <*>:
# [1271]
# PCI Hot Plug PCI Core version: <*>:
# [1272]
# <*>=LABEL=/ initrd=<*> console=tty0 console=ttyS0,<*> fastboot BOOT_IMAGE=<*>:
# [1273]
# Registered protocol family <*>:
# [1274, 1275, 1276, 1277, 1461]
# Using software bounce buffering for IO (SWIOTLB):
# [1278]
# Probing PCI hardware (bus <*>):
# [1279]
# Transparent bridge - <*>:<*>:<*>:
# [1280]
# Using ACPI for IRQ routing:
# [1281]
# Using MMCONFIG at <*>:
# [1282]
# Using configuration type <*>:
# [1283]
# Compressed image found at block <*>:
# [1284]
# Disabled at runtime.:
# [1285]
# Initializing.:
# [1286]
# Registering netfilter hooks:
# [1287]
# Starting in permissive mode:
# [1288]
# Unregistering netfilter hooks:
# [1289]
# Hash tables configured (established <*> bind <*>):
# [1290]
# Direct-Access ANSI SCSI revision: <*>:
# [1291]
# Processor ANSI SCSI revision: <*>:
# [1292]
# Disk quotas <*>:
# [1293]
# Mounted <*> (ext2 filesystem).:
# [1294]
# MegaRAID Model: LD <*> RAID1 <*> Rev: <*>:
# [1295]
# PE/PV Model: <*> SCSI BP Rev: <*>:
# [1296]
# initialized:
# [1297]
# initializing netlink socket (disabled):
# [1298]
# passed.:
# [1299]
# <*> (<*>) initialised: #<*>#@#<*>#:
# [1300]
# allocating divert_blk for eth0:
# [1301]
# allocating divert_blk for eth1:
# [1302]
# not allocating divert_blk for non-ethernet device lo:
# [1303]
# <*>:USB HID core driver:
# [1304]
# eth0: e1000_probe: Intel(R) <*> Network Connection:
# [1305]
# eth0: e1000_watchdog: NIC Link is Up <*> Mbps Full Duplex:
# [1306]
# eth1: e1000_probe: Intel(R) <*> Network Connection:
# [1307]
# no floppy controllers found:
# [1308]
# RNG not detected:
# [1309]
# Wait for ready failed before probe !:
# [1310, 1311, 1312, 1313, 1314, 1315]
# Assuming <*> system bus speed for PIO modes; override with idebus=xx:
# [1316]
# Unknown cmd fd(<*>) cmd(<*>){<*>} arg(<*>) on /dev/sda:
# [1317]
# (C) <*> Netfilter core team:
# [1318, 1319, 1320, 1321]
# Installing public key data:
# [1322]
# ... autorun DONE.:
# [1323, 1324]
# Autodetecting RAID arrays.:
# [1325, 1326]
# autorun ...:
# [1327, 1328]
# md driver <*> MAX_MD_DEVS=<*>, MD_SB_DISKS=<*>:
# [1329]
# #<*>#-rh1 (Release Date: Fri Dec <*> <*>:<*>:<*> EST <*>):
# [1330]
# #<*># (Release Date: Mon Sep <*> <*>:<*>:<*> EDT <*>):
# [1331]
# fw version:[<*>] bios version:[H418]:
# [1332]
# probe new device <*>:<*>:<*>:<*>: bus <*>:slot <*>:func <*>:
# [1333]
# <*> mouse device common for all mice:
# [1334]
# <*> (<*>):
# [1335]
# rpc.statd startup succeeded:
# [1336]
# portmap startup succeeded:
# [1337]
# Starting ts_fixup: succeeded:
# [1338]
# Version <*> Starting:
# [1339]
# LSI Logic MegaRAID driver:
# [1340]
# scanning scsi channel <*> [Phy <*>] for non-raid devices:
# [1341]
# scanning scsi channel <*> [virtual] for logical drives:
# [1342]
# asking for cache data failed:
# [1343]
# assuming drive cache: write through:
# [1344]
# sda1 sda2 sda3 sda4:
# [1345]
# Registering secondary module capability:
# [1346]
# i8042 AUX port at <*>,<*> irq <*>:
# [1347]
# i8042 KBD port at <*>,<*> irq <*>:
# [1348]
# syslog-ng startup succeeded:
# [1349]
# syslog-ng version <*> starting:
# [1350]
# Detected <*> MHz processor.:
# [1351]
# Using <*> MHz HPET timer.:
# [1352]
# Using HPET based timekeeping.:
# [1353]
# Creating Topspin /dev entries::
# [1354]
# registered new driver hiddev:
# [1355]
# registered new driver hub:
# [1356]
# registered new driver usbfs:
# [1357]
# registered new driver usbhid:
# [1358]
# probe of vesafb0 failed with error <*>:
# [1359]
# connection from "#<*>#":
# [1371, 1402]
# User #<*>#, coming from #<*>#, authenticated.:
# [1375, 1456]
# Now running on #<*>#'s privileges.:
# [1379, 1455]
# Mounting NFS filesystems: succeeded:
# [1382]
# Mounting other filesystems: failed:
# [1383]
# Warning: we failed to resolve data source name an14 an15 an16 an17 an18 an19 an20 an21 an22 an23 an24 an25 an26 an27 an28 an29 an30 an31 an32 an33 an34 an35 an36 an37 an38 an39 an40 an41 an42 an43 an44 an45 an46 an47 an48 an49 an50 an51 an52 an53 an54 an55 an56 an57 an58 an59 an60 an61 an62 an63 an64 an65 an66 an67 an68 an69 an70 an71 an72 an73 an74 an75 an76 an77 an78 an79 an80 an81 an82 an83 an84 an85 an86 an87 an88 an89 an90 an91 an92 an93 an94 an95 an96 an97 an98 an99 an100 an101 an102 an103 an104 an105 an106 an107 an108 an109 an110 an111 an112 an113 an114 an115 an116 an117 an118 an119 an120 an121 an122 an123 an124 an125 an126 an127 an128:
# [1386, 1387]
# Warning: we failed to resolve data source name an142 an143 an144 an145 an146 an147 an148 an149 an150 an151 an152 an153 an154 an155 an156 an157 an158 an159 an160 an161 an162 an163 an164 an165 an166 an167 an168 an169 an170 an171 an172 an173 an174 an175 an176 an177 an178 an179 an180 an181 an182 an183 an184 an185 an186 an187 an188 an189 an190 an191 an192 an193 an194 an195 an196 an197 an198 an199 an200 an201 an202 an203 an204 an205 an206 an207 an208 an209 an210 an211 an212 an213 an214 an215 an216 an217 an218 an219 an220 an221 an222 an223 an224 an225 an226 an227 an228 an229 an230 an231 an232 an233 an234 an235 an236 an237 an238 an239 an240 an241 an242 an243 an244 an245 an246 an247 an248 an249 an250 an251 an252 an253 an254 an255 an256:
# [1388]
# [1452]
# Warning: we failed to resolve trusted host name dadmin3 dadmin4:
# [1453]
# gmetad startup succeeded:
# [1454]
# not allocating divert_blk for non-ethernet device sit0:
# [1462]
# succeeded:
# [1463, 1483]
# Server listening on :: port <*>:
# [1464]
# error: Bind to port <*> on <*> failed: Address already in use.:
# [1465]
# Cannot open file /dev/logsurfer for writing (No such file or directory):
# [1469]
# Changing permissions on special file /dev/logsurfer:
# [1470]
# xinetd startup succeeded:
# [1484]
# Reading included configuration file: <*> [file=/etc/xinetd.conf] [line=<*>]:
# [1485]
# Reading included configuration file: <*>-udp [file=<*>-udp] [line=<*>]:
# [1486, 1489, 1491, 1501]
# Reading included configuration file: <*>-lpd [file=<*>-lpd] [line=<*>]:
# [1487]
# Reading included configuration file: <*> [file=<*> [line=<*>]:
# [1488, 1490, 1492, 1493, 1494, 1496, 1497, 1498, 1499, 1500]
# Reading included configuration file: <*>-telnet [file=<*>-telnet] [line=<*>]:
# [1495]
# Started working: <*> available service:
# [1502]
# removing chargen:
# [1503, 1504]
# removing daytime:
# [1505, 1506]
# removing echo:
# [1507, 1508]
# removing eklogin:
# [1509]
# removing ftp:
# [1510]
# removing klogin:
# [1511]
# removing kshell:
# [1512]
# removing ntalk:
# [1513]
# removing printer:
# [1514]
# removing rsync:
# [1515]
# removing telnet:
# [1516]
# removing time:
# [1517, 1518]
# xinetd Version <*> started with libwrap loadavg options compiled in.:
# [1519]
# Device: /dev/sda, Temperature changed <*> Celsius to <*> Celsius since last report:
# [1952]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_35460\1336923761.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_indices = trust_df.groupby('EventTemplate').apply(lambda x: x.index.tolist())

# %%
def processingSubToken(tok):
    # 1. Kiểm tra nếu toàn bộ token là số HEX hợp lệ (ít nhất 8 chữ số hex)
    if re.fullmatch(r'0x[0-9a-fA-F]+', tok) or re.fullmatch(r'[0-9a-fA-F]{8,}', tok):
        return True
    
    if not hasNumbers(tok):
        return False

    # 2. Kiểm tra nếu token là số (có thể âm, có thể thập phân)
    if re.fullmatch(r'-?\d+(\.\d+)?', tok):
        return True
    
    number_groups = re.findall(r'\d+', tok)
    if len(number_groups) > 1:
        return True
    
    matches = list(re.finditer(r'[a-zA-Z]+[0-9]+', tok))
    if len(matches) == 1:
        end = matches[0].end()
        if end == len(tok) or not tok[end].isalnum():
            return False  # tĩnh

    return True

token = ["abcd123s", "abcd123", "abcd", "123", "0x1234567890abcdef", "0x1234567890abcdefg", "0x12345678", "0x1234567", "0x1234567a"]
for tok in token:
    print(tok, processingSubToken(tok))
# Out:
# abcd123s True
# abcd123 False
# abcd False
# 123 True
# 0x1234567890abcdef True
# 0x1234567890abcdefg True
# 0x12345678 True
# 0x1234567 True
# 0x1234567a True
