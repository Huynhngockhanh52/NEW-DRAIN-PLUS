# %% [markdown]
# #### **0. CHUẨN BỊ**
#
# ##### **0.1. CẤU HÌNH CÁC THAM SỐ**

# %%
import re
import sys
sys.path.append('../')
import os
import pandas as pd
from collections import Counter, defaultdict
import datetime
from tqdm import tqdm
import string

pd.set_option('display.max_rows', None)

SETTING_PARAMS = {
    'Apache': {
        'log_file': './logs/Apache/Apache_full.log',
        'log_template': './logs/Apache/Apache_full.log_templates.csv',
        'log_structure': './logs/Apache/Apache_full.log_structured.csv',
        'log_format': '\[<Time>\] \[<Level>\] <Content>',
        'filters': [],
        'regexs': [r'\/(?:\w+\/){2,}\w+\.\w+$'],    
    },
    'HealthApp':{
        'log_file': './logs/HealthApp/HealthApp_full.log',
        'log_template': './logs/HealthApp/HealthApp_full.log_templates.csv',
        'log_structure': './logs/HealthApp/HealthApp_full.log_structured.csv',
        'log_format': '<Time>\|<Component>\|<Pid>\|<Content>',
        'filters': [],
        'regexs': [],  
    },
    'Mac': {
        'log_file': './logs/Mac/Mac_full.log',
        'log_template': './logs/Mac/Mac_full.log_templates.csv',
        'log_structure': './logs/Mac/Mac_full.log_structured.csv',
        'log_format': '<Month>  <Date> <Time> <User> <Component>\[<PID>\]( \(<Address>\))?: <Content>',
        'filters': [],
        'regexs': [r'([\w-]+\.){2,}[\w-]+'],  
    },
    'Linux': {
        'log_file': './logs/Linux/Linux_full.log',
        'log_template': './logs/Linux/Linux_full.log_templates.csv',
        'log_structure': './logs/Linux/Linux_full.log_structured.csv',
        'log_format': '<Month> <Date> <Time> <Level> <Component>(\[<PID>\])?: <Content>',
        'filters': [],
        'regexs': [r'(\d+\.){3}\d+', r'\d{2}:\d{2}:\d{2}'],  
    },
    'OpenSSH': {
        'log_file': './logs/OpenSSH/OpenSSH_full.log',
        'log_template': './logs/OpenSSH/OpenSSH_full.log_templates.csv',
        'log_structure': './logs/OpenSSH/OpenSSH_full.log_structured.csv',
        'log_format': '<Date> <Day> <Time> <Component> sshd\[<Pid>\]: <Content>',
        'filters': [],
        'regexs': [r"(\d+):"],    
    },
}

# %% [markdown]
# ##### **0.2. CLASS**

# %%
class LogCluster:
    def __init__(self, keyGroup, logTemplate, tokens, length, logIDL=None, dynamic_tokenL=None, static_tokenL=None):
        self.keyGroup = keyGroup
        self.logTemplate = logTemplate
        self.tokens = tokens
        self.length = length
        self.logIDL = logIDL if logIDL is not None else []
        self.dynamic_tokenL = dynamic_tokenL if dynamic_tokenL is not None else {}
        self.static_tokenL = static_tokenL if static_tokenL is not None else {}
        
    def __str__(self):
        dynamic_str = "Dynamic Tokens: {\n"
        for k, v in self.dynamic_tokenL.items():
            dynamic_str += f"  {k}: {v},\n"
        dynamic_str += "}"
        
        static_str = "Cover Tokens: {\n"
        for k, v in self.static_tokenL.items():
            static_str += f"  {k}: {v},\n"
        static_str += "}"
        return (
            f"Key: {self.keyGroup}\n"
            f"Template: {self.logTemplate}\n"
            f"Tokens: {self.tokens}\n"
            f"Length: {self.length}\n"
            f"Len LogIDs: {len(self.logIDL)}\n"
            f"{dynamic_str}\n"
            f"{static_str}\n"
        )

# %% [markdown]
# #### **1. Các phương thức sử dụng**
#
# ##### **1.1. Read data**
# - **`log_to_dataframe()`**
#
# - **`generate_logformat_regex()`**
#
# - **`load_data()`**

# %%
# =============================== READ DATA =============================== #
def log_to_dataframe(log_file, regex, headers):
    """ Phương thức chuyển đổi file log thành dataframe
    """ 
    log_messages = []
    linecount = 0
    with open(log_file, 'r', encoding="utf8") as fin:
        for line in fin.readlines():
            try:
                match = regex.search(line.strip())
                message = [match.group(header) for header in headers]
                log_messages.append(message)
                linecount += 1
            except Exception as e:
                pass
    logdf = pd.DataFrame(log_messages, columns=headers)
    logdf.insert(0, 'LineId', None)
    logdf['LineId'] = [i + 1 for i in range(linecount)]
    return logdf

def generate_logformat_regex(logformat):
    """ Phương thức tạo regex từ logformat, biểu thức định dạng của một event log: 
    Ex: 'log_format': '<Date> <Time> <Pid> <Level> <Component>: <Content>'
    """
    headers = []
    splitters = re.split(r'(<[^<>]+>)', logformat)
    regex = ''
    for k in range(len(splitters)):
        if k % 2 == 0:
            splitter = re.sub(' +', '\\\s+', splitters[k])
            regex += splitter
        else:
            header = splitters[k].strip('<').strip('>')
            regex += '(?P<%s>.*?)' % header
            headers.append(header)
    regex = re.compile('^' + regex + '$')
    return headers, regex

def load_data(logfile, logformat):
    """ Phương thức trả về một dataframe từ một file log chỉ định
    """
    log_headers, log_regex = generate_logformat_regex(logformat)
    logs_df = log_to_dataframe(logfile, log_regex, log_headers)
    return logs_df

# %% [markdown]
# ##### **1.2. PRE_PROCESSING_0**
# - **`pre0_hasNumbers()`**
# - **`pre0_regexAndFilter()`**
#
# - **`create_special_pattern()`**
# - **`process_line()`**

# %%
# ========================== PRE_PROCESSING_0 ========================== #
def pre0_hasNumbers(s):
    return any(char.isdigit() for char in s)

def pre0_regexAndFilter(line, regexs = [], filters = []):
    for currentFil in filters:
        line = re.sub(currentFil, '', line)
    for currentRex in regexs:
        line = re.sub(currentRex, "<*>", line)
    return line.strip()

# ======================= CÁC PHƯƠNG THỨC BỔ TRỢ ======================= #
def create_special_pattern(dict_special_token):
    """ Tạo biểu thức chính quy cho các từ điển yêu cầu """
    keywords = '|'.join([re.escape(k) for k in dict_special_token])
    return re.compile(rf"([{re.escape(string.punctuation)}])({keywords})\b", flags=re.IGNORECASE)


def process_line(line, regexs, filters, dict_special_token, pattern_special):
    """ Phương thức hỗ trợ xử lý từng dòng log """
    
    # ================== Xử lý regex và filter ================== #
    # tokens0 là list token sau khi tiền xử lý
    # tokens1 là list token sau khi đã xử lý hết
    # groups_token là chuỗi log để nhóm các log chung lại với nhau
    
    parsed = pre0_regexAndFilter(line['Content'], regexs=regexs, filters=filters)
    tokens0 = str(parsed).strip().split()

    tokens1 = []
    groups_token = []
    
    for token in tokens0:
        if token == "<*>":
            tokens1.append("<*>")
        if not pre0_hasNumbers(token) and str(token).lower() not in dict_special_token:
            temp = re.sub(pattern_special, r'\1<*>', token)
            groups_token.append(temp)
            tokens1.append(temp)
        else:
            tokens1.append("<*>")

    return pd.Series({
        # 'ParseTemplate0': parsed,
        # 'Tokens0': tokens0,
        'Tokens1': tokens1,
        'ParseTemplate1': f"{' '.join(groups_token)} : {len(tokens0)}"
    })

# %% [markdown]
# ##### **1.3. PHƯƠNG THỨC HỖ TRỢ NHÓM GROUP**
#
# - **`extractDynamicTok()`**

# %%
def extractDynamicTok(groups, tokens):
    dynamic_tokenL = defaultdict(list)
    split_lines = [row['Content'].strip().split() for _, row in groups.iterrows()]

    for pos, token in enumerate(tokens):
        if "<*>" in token:
            for line in split_lines:
                if pos < len(line):
                    dynamic_tokenL[pos].append(line[pos])
    return dict(dynamic_tokenL)

# %% [markdown]
# ##### **1.#. PHƯƠNG THỨC KHÁC**
#
# - **`write_df_to_txt()`**

# %%
def write_df_to_txt(df, filename):
    col_widths = [max(len(str(val)) for val in [col] + df[col].tolist()) for col in df.columns]

    with open(filename, 'w', encoding='utf-8') as f:
        header = '\t'.join(str(col).ljust(width) for col, width in zip(df.columns, col_widths))
        f.write(header + '\n')

        for row in df.itertuples(index=False):
            line = '\t'.join(str(val).ljust(width) for val, width in zip(row, col_widths))
            f.write(line + '\n')

# %% [markdown]
# #### **2. KHUNG LÀM VIỆC CHÍNH**

# %%
# CẤU HÌNH CÁC THAM SỐ:
datasets = SETTING_PARAMS['HealthApp']
DICT_SPECIAL_TOKEN = ['true', 'false', 'yes', 'no']

logs_df = load_data(datasets['log_file'], datasets['log_format'])

# ================================ PROCESSING 0 ================================ #
parse_df = logs_df.copy()
# parse_df['ParseTemplate0'] = ""
# parse_df['Tokens0'] = [[] for _ in range(len(parse_df))]
parse_df['ParseTemplate1'] = ""
parse_df['Tokens1'] = [[] for _ in range(len(parse_df))]

tqdm.pandas(desc="Tiền xử lý giai đoạn 0 và 1")
pattern_special = create_special_pattern(DICT_SPECIAL_TOKEN)

results = parse_df.progress_apply(
        lambda row: process_line(row, datasets['regexs'], datasets['filters'], DICT_SPECIAL_TOKEN, pattern_special),
        axis=1
    )

for col in results.columns:
    parse_df[col] = results[col]

# write_df_to_txt(parse_df, 'z_parse_df.txt')

# ================================ GROUP LOG ================================ #
PUNCTUATIONL = '(),<>:;{}[]~='
N_MERGE = 3

log_clusters_list = []

unique_groups = parse_df.groupby("ParseTemplate1")
print(len(unique_groups))

for key, group_val in unique_groups:
    tokens = group_val.iloc[0]['Tokens1']
    logTemplate = " ".join(tokens)
    logIDL = group_val.index.tolist()

    dynamic_tokenL = extractDynamicTok(group_val, tokens)
    
    cluster = LogCluster(
        keyGroup=key,
        logTemplate=logTemplate,
        tokens=tokens,
        length=len(tokens),
        logIDL=logIDL,
        dynamic_tokenL=dynamic_tokenL,
        static_tokenL=None
    )
    log_clusters_list.append(cluster)

# ================================ PROCESSING 1 ================================ #

# =============================== CÁC CÂU LỆNH IN KIỂM TRA ===============================
parse_df.head(100)
# Out:
# Tiền xử lý giai đoạn 0 và 1: 100%|██████████| 212394/212394 [00:27<00:00, 7598.02it/s]
# 161
#     LineId                   Time                 Component       Pid  \
# 0        1  20171223-22:15:29:606                  Step_LSC  30002312
# 1        2  20171223-22:15:29:633  Step_StandReportReceiver  30002312
# 2        3  20171223-22:15:29:635                  Step_LSC  30002312
# 3        4  20171223-22:15:29:635     Step_StandStepCounter  30002312
# 4        5  20171223-22:15:29:635              Step_SPUtils  30002312
# 5        6  20171223-22:15:29:636              Step_SPUtils  30002312
# 10                            onStandStepChanged 3579
# 11                            onStandStepChanged 3580
# 12   getTodayTotalDetailSteps = 1514038440000##700...
# 13  setTodayTotalDetailSteps=1514038440000##7008##...
# 14    calculateCaloriesWithCache totalCalories=126797
# 15       calculateAltitudeWithCache totalAltitude=240
# 16                      REPORT : 7008 5003 150111 240
# 17                            onStandStepChanged 3581
# 18   getTodayTotalDetailSteps = 1514038440000##700...
# 19  setTodayTotalDetailSteps=1514038440000##7009##...
# 20    calculateCaloriesWithCache totalCalories=126818
# 21       calculateAltitudeWithCache totalAltitude=240
# 22                      REPORT : 7009 5004 150132 240
# 23                            onStandStepChanged 3583
# 24   getTodayTotalDetailSteps = 1514038440000##700...
# 25  setTodayTotalDetailSteps=1514038440000##7011##...
# 26    calculateCaloriesWithCache totalCalories=126861
# 27       calculateAltitudeWithCache totalAltitude=240
# 28                      REPORT : 7011 5005 150175 240
# 29                            onStandStepChanged 3584
# 30   getTodayTotalDetailSteps = 1514038440000##701...
# 31  setTodayTotalDetailSteps=1514038440000##7012##...
# 32    calculateCaloriesWithCache totalCalories=126882
# 33       calculateAltitudeWithCache totalAltitude=240
# 34                      REPORT : 7012 5006 150197 240
# 35                            onStandStepChanged 3585
# 36   getTodayTotalDetailSteps = 1514038440000##701...
# 37  setTodayTotalDetailSteps=1514038440000##7013##...
# 38    calculateCaloriesWithCache totalCalories=126904
# 39       calculateAltitudeWithCache totalAltitude=240
# 40                      REPORT : 7013 5007 150218 240
# 41                            onStandStepChanged 3586
# 42   getTodayTotalDetailSteps = 1514038440000##701...
# 43  setTodayTotalDetailSteps=1514038440000##7014##...
# 44    calculateCaloriesWithCache totalCalories=126925
# 45       calculateAltitudeWithCache totalAltitude=240
# 46                      REPORT : 7014 5007 150239 240
# 47                            onStandStepChanged 3587
# 48   getTodayTotalDetailSteps = 1514038440000##701...
# 49  setTodayTotalDetailSteps=1514038440000##7015##...
# 50    calculateCaloriesWithCache totalCalories=126947
# 51       calculateAltitudeWithCache totalAltitude=240
# 52                      REPORT : 7015 5008 150261 240
# 53                            onStandStepChanged 3588
# 54  onReceive action: android.intent.action.SCREEN...
# 55                            onStandStepChanged 3589
# 56   getTodayTotalDetailSteps = 1514038440000##701...
# 57  setTodayTotalDetailSteps=1514038440000##7017##...
# 58    calculateCaloriesWithCache totalCalories=126989
# 59       calculateAltitudeWithCache totalAltitude=240
# 60                                    isScreenOn true
# 61              screen status unknown,think screen on
# 62                      REPORT : 7017 5010 150304 240
# 63  onReceive action: android.intent.action.SCREEN_ON
# 64  processHandleBroadcastAction action:android.in...
# 65                                  flush sensor data
# 66   getTodayTotalDetailSteps = 1514038440000##701...
# 67  setTodayTotalDetailSteps=1514038440000##7017##...
# 68                            onStandStepChanged 3589
# 69    calculateCaloriesWithCache totalCalories=126989
# 70       calculateAltitudeWithCache totalAltitude=240
# 71                      REPORT : 7017 5010 150304 240
# 72                            onStandStepChanged 3589
# 73                            onStandStepChanged 3590
# 74   getTodayTotalDetailSteps = 1514038440000##701...
# 75  setTodayTotalDetailSteps=1514038440000##7018##...
# 76    calculateCaloriesWithCache totalCalories=127011
# 77       calculateAltitudeWithCache totalAltitude=240
# 78                      REPORT : 7018 5010 150325 240
# 79                            onStandStepChanged 3591
# 80   getTodayTotalDetailSteps = 1514038440000##701...
# 81  setTodayTotalDetailSteps=1514038440000##7019##...
# 82    calculateCaloriesWithCache totalCalories=127032
# 83       calculateAltitudeWithCache totalAltitude=240
# 84                      REPORT : 7019 5011 150346 240
# 85                            onStandStepChanged 3592
# 86   getTodayTotalDetailSteps = 1514038440000##701...
# 87  setTodayTotalDetailSteps=1514038440000##7020##...
# 88    calculateCaloriesWithCache totalCalories=127054
# 89       calculateAltitudeWithCache totalAltitude=240
# 90                      REPORT : 7020 5012 150368 240
# 91                            onStandStepChanged 3593
# 92   getTodayTotalDetailSteps = 1514038440000##702...
# 93  setTodayTotalDetailSteps=1514038440000##7021##...
# 94    calculateCaloriesWithCache totalCalories=127075
# 95       calculateAltitudeWithCache totalAltitude=240
# 96                      REPORT : 7021 5012 150389 240
# 97                            onStandStepChanged 3594
# 98   getTodayTotalDetailSteps = 1514038440000##702...
# 99  setTodayTotalDetailSteps=1514038440000##7022##...
#
#                                        ParseTemplate1  \
# 0                              onStandStepChanged : 2
# 1   onReceive action: android.intent.action.SCREEN...
# 2   processHandleBroadcastAction action:android.in...
# 3                               flush sensor data : 3
# 4                      getTodayTotalDetailSteps = : 3
# 5                                                 : 1
# 6                              onStandStepChanged : 2
# 7                      calculateCaloriesWithCache : 2
# 8                      calculateAltitudeWithCache : 2
# 9                                        REPORT : : 6
# 10                             onStandStepChanged : 2
# 11                             onStandStepChanged : 2
# 12                     getTodayTotalDetailSteps = : 3
# 13                                                : 1
# 14                     calculateCaloriesWithCache : 2
# 15                     calculateAltitudeWithCache : 2
# 16                                       REPORT : : 6
# 17                             onStandStepChanged : 2
# 18                     getTodayTotalDetailSteps = : 3
# 19                                                : 1
# 20                     calculateCaloriesWithCache : 2
# 21                     calculateAltitudeWithCache : 2
# 22                                       REPORT : : 6
# 23                             onStandStepChanged : 2
# 24                     getTodayTotalDetailSteps = : 3
# 25                                                : 1
# 26                     calculateCaloriesWithCache : 2
# 27                     calculateAltitudeWithCache : 2
# 28                                       REPORT : : 6
# 29                             onStandStepChanged : 2
# 30                     getTodayTotalDetailSteps = : 3
# 31                                                : 1
# 32                     calculateCaloriesWithCache : 2
# 33                     calculateAltitudeWithCache : 2
# 34                                       REPORT : : 6
# 35                             onStandStepChanged : 2
# 36                     getTodayTotalDetailSteps = : 3
# 37                                                : 1
# 38                     calculateCaloriesWithCache : 2
# 39                     calculateAltitudeWithCache : 2
# 40                                       REPORT : : 6
# 41                             onStandStepChanged : 2
# 42                     getTodayTotalDetailSteps = : 3
# 43                                                : 1
# 44                     calculateCaloriesWithCache : 2
# 45                     calculateAltitudeWithCache : 2
# 46                                       REPORT : : 6
# 47                             onStandStepChanged : 2
# 48                     getTodayTotalDetailSteps = : 3
# 49                                                : 1
# 50                     calculateCaloriesWithCache : 2
# 51                     calculateAltitudeWithCache : 2
# 52                                       REPORT : : 6
# 53                             onStandStepChanged : 2
# 54  onReceive action: android.intent.action.SCREEN...
# 55                             onStandStepChanged : 2
# 56                     getTodayTotalDetailSteps = : 3
# 57                                                : 1
# 58                     calculateCaloriesWithCache : 2
# 59                     calculateAltitudeWithCache : 2
# 60                                     isScreenOn : 2
# 61          screen status unknown,think screen on : 5
# 62                                       REPORT : : 6
# 63  onReceive action: android.intent.action.SCREEN...
# 64  processHandleBroadcastAction action:android.in...
# 65                              flush sensor data : 3
# 66                     getTodayTotalDetailSteps = : 3
# 67                                                : 1
# 68                             onStandStepChanged : 2
# 69                     calculateCaloriesWithCache : 2
# 70                     calculateAltitudeWithCache : 2
# 71                                       REPORT : : 6
# 72                             onStandStepChanged : 2
# 73                             onStandStepChanged : 2
# 74                     getTodayTotalDetailSteps = : 3
# 75                                                : 1
# 76                     calculateCaloriesWithCache : 2
# 77                     calculateAltitudeWithCache : 2
# 78                                       REPORT : : 6
# 79                             onStandStepChanged : 2
# 80                     getTodayTotalDetailSteps = : 3
# 81                                                : 1
# 82                     calculateCaloriesWithCache : 2
# 83                     calculateAltitudeWithCache : 2
# 84                                       REPORT : : 6
# 85                             onStandStepChanged : 2
# 86                     getTodayTotalDetailSteps = : 3
# 87                                                : 1
# 88                     calculateCaloriesWithCache : 2
# 89                     calculateAltitudeWithCache : 2
# 90                                       REPORT : : 6
# 91                             onStandStepChanged : 2
# 92                     getTodayTotalDetailSteps = : 3
# 93                                                : 1
# 94                     calculateCaloriesWithCache : 2
# 95                     calculateAltitudeWithCache : 2
# 96                                       REPORT : : 6
# 97                             onStandStepChanged : 2
# 98                     getTodayTotalDetailSteps = : 3
# 99                                                : 1
#
#                                               Tokens1
# 0                           [onStandStepChanged, <*>]
# 1   [onReceive, action:, android.intent.action.SCR...
# 2   [processHandleBroadcastAction, action:android....
# 3                               [flush, sensor, data]
# 4                  [getTodayTotalDetailSteps, =, <*>]
# 5                                               [<*>]
# 6                           [onStandStepChanged, <*>]
# 7                   [calculateCaloriesWithCache, <*>]
# 8                   [calculateAltitudeWithCache, <*>]
# 9                     [REPORT, :, <*>, <*>, <*>, <*>]
# 10                          [onStandStepChanged, <*>]
# 11                          [onStandStepChanged, <*>]
# 12                 [getTodayTotalDetailSteps, =, <*>]
# 13                                              [<*>]
# 14                  [calculateCaloriesWithCache, <*>]
# 15                  [calculateAltitudeWithCache, <*>]
# 16                    [REPORT, :, <*>, <*>, <*>, <*>]
# 17                          [onStandStepChanged, <*>]
# 18                 [getTodayTotalDetailSteps, =, <*>]
# 19                                              [<*>]
# 20                  [calculateCaloriesWithCache, <*>]
# 21                  [calculateAltitudeWithCache, <*>]
# 22                    [REPORT, :, <*>, <*>, <*>, <*>]
# 23                          [onStandStepChanged, <*>]
# 24                 [getTodayTotalDetailSteps, =, <*>]
# 25                                              [<*>]
# 26                  [calculateCaloriesWithCache, <*>]
# 27                  [calculateAltitudeWithCache, <*>]
# 28                    [REPORT, :, <*>, <*>, <*>, <*>]
# 29                          [onStandStepChanged, <*>]
# 30                 [getTodayTotalDetailSteps, =, <*>]
# 31                                              [<*>]
# 32                  [calculateCaloriesWithCache, <*>]
# 33                  [calculateAltitudeWithCache, <*>]
# 34                    [REPORT, :, <*>, <*>, <*>, <*>]
# 35                          [onStandStepChanged, <*>]
# 36                 [getTodayTotalDetailSteps, =, <*>]
# 37                                              [<*>]
# 38                  [calculateCaloriesWithCache, <*>]
# 39                  [calculateAltitudeWithCache, <*>]
# 40                    [REPORT, :, <*>, <*>, <*>, <*>]
# 41                          [onStandStepChanged, <*>]
# 42                 [getTodayTotalDetailSteps, =, <*>]
# 43                                              [<*>]
# 44                  [calculateCaloriesWithCache, <*>]
# 45                  [calculateAltitudeWithCache, <*>]
# 46                    [REPORT, :, <*>, <*>, <*>, <*>]
# 47                          [onStandStepChanged, <*>]
# 48                 [getTodayTotalDetailSteps, =, <*>]
# 49                                              [<*>]
# 50                  [calculateCaloriesWithCache, <*>]
# 51                  [calculateAltitudeWithCache, <*>]
# 52                    [REPORT, :, <*>, <*>, <*>, <*>]
# 53                          [onStandStepChanged, <*>]
# 54  [onReceive, action:, android.intent.action.SCR...
# 55                          [onStandStepChanged, <*>]
# 56                 [getTodayTotalDetailSteps, =, <*>]
# 57                                              [<*>]
# 58                  [calculateCaloriesWithCache, <*>]
# 59                  [calculateAltitudeWithCache, <*>]
# 60                                  [isScreenOn, <*>]
# 61        [screen, status, unknown,think, screen, on]
# 62                    [REPORT, :, <*>, <*>, <*>, <*>]
# 63  [onReceive, action:, android.intent.action.SCR...
# 64  [processHandleBroadcastAction, action:android....
# 65                              [flush, sensor, data]
# 66                 [getTodayTotalDetailSteps, =, <*>]
# 67                                              [<*>]
# 68                          [onStandStepChanged, <*>]
# 69                  [calculateCaloriesWithCache, <*>]
# 70                  [calculateAltitudeWithCache, <*>]
# 71                    [REPORT, :, <*>, <*>, <*>, <*>]
# 72                          [onStandStepChanged, <*>]
# 73                          [onStandStepChanged, <*>]
# 74                 [getTodayTotalDetailSteps, =, <*>]
# 75                                              [<*>]
# 76                  [calculateCaloriesWithCache, <*>]
# 77                  [calculateAltitudeWithCache, <*>]
# 78                    [REPORT, :, <*>, <*>, <*>, <*>]
# 79                          [onStandStepChanged, <*>]
# 80                 [getTodayTotalDetailSteps, =, <*>]
# 81                                              [<*>]
# 82                  [calculateCaloriesWithCache, <*>]
# 83                  [calculateAltitudeWithCache, <*>]
# 84                    [REPORT, :, <*>, <*>, <*>, <*>]
# 85                          [onStandStepChanged, <*>]
# 86                 [getTodayTotalDetailSteps, =, <*>]
# 87                                              [<*>]
# 88                  [calculateCaloriesWithCache, <*>]
# 89                  [calculateAltitudeWithCache, <*>]
# 90                    [REPORT, :, <*>, <*>, <*>, <*>]
# 91                          [onStandStepChanged, <*>]
# 92                 [getTodayTotalDetailSteps, =, <*>]
# 93                                              [<*>]
# 94                  [calculateCaloriesWithCache, <*>]
# 95                  [calculateAltitudeWithCache, <*>]
# 96                    [REPORT, :, <*>, <*>, <*>, <*>]
# 97                          [onStandStepChanged, <*>]
# 98                 [getTodayTotalDetailSteps, =, <*>]
# 99                                              [<*>]

# %% [markdown]
# ##### **@.2. HOÀN CHỈNH**

# %%
# def parse_DrainDS(datasets):
#     logs_df = load_data(datasets['log_file'], datasets['log_format'])
    
    
#     # =============================== CÁC CÂU LỆNH IN KIỂM TRA ===============================
#     logs_df.head(100)
    
    
    
# # =============== CHẠY CHƯƠNG TRÌNH ==============
# parse_DrainDS(SETTING_PARAMS['Mac'])
